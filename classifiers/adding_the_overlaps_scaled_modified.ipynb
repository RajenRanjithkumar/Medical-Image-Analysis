# %%
#mask
import json
import cv2
import os
import pandas as pd 
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
import keras
from keras.preprocessing import image
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers, models

from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical

from keras.layers import Input
from keras.models import Model
from keras.layers import concatenate
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten 
from keras.layers import Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import to_categorical
import xml.etree.ElementTree as ET
from tensorflow.keras.callbacks import TensorBoard

from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import time
model_name = "mutiple_Conv1D_8_inputs_scaled_modified"
NAME = model_name+"-{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir = 'logs/{}'.format(NAME))

# %%
CATEGORIES = ["covid", "normal"]
DATADIR = "D:/Project2022/res/split_dataset/scaled_resized/train"

# %%
for categoty in CATEGORIES:
    path = os.path.join(DATADIR, categoty)  # path to Covid or Nprmal
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
        plt.imshow(img_array, cmap="gray")
        plt.show()

        #left half
        LH_img = img_array[: , :256]
        plt.imshow(LH_img, cmap="gray")
        plt.show()
        
        #Right half
        RH_img = img_array[: , 256:]
        plt.imshow(RH_img, cmap="gray")
        plt.show()

        # mid vertical
        mid_ver = img_array[:, 128:384]
        plt.imshow(mid_ver, cmap="gray")
        plt.show()

        #top half
        TH_img = img_array[:256 , :]
        plt.imshow(TH_img, cmap="gray")
        plt.show()

        #bottom half
        BH_img = img_array[256: , :]
        plt.imshow(BH_img, cmap="gray")
        plt.show()

        #mid horizontal
        mid_hor = img_array[128:384, :]
        plt.imshow(mid_hor, cmap="gray")
        plt.show()


        break
    break

# %%
def pre_process_dataset(dataset_path):

    df_data = pd.DataFrame()
    #raw_image = []
    row_sum = []
    coloumn_sum = []
    
    LH_sum = []
    Row_mid = []
    RH_sum = []
    
    TC_sum = []
    Col_mid = []
    BC_sum =[]

    label = []

    for categoty in CATEGORIES:
        path = os.path.join(dataset_path, categoty)  
        
        class_num = CATEGORIES.index(categoty)
        

        print("Loading dataset: class",categoty)
        for img in tqdm(os.listdir(path)):

            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
                row = img_array.sum(axis=0)
                coloumn = img_array.sum(axis=1)

                #Global inputs
                row_sum.append(row)
                coloumn_sum.append(coloumn)

                #row inputs
                LH_img = img_array[: , :256]
                LH_sum.append(LH_img.sum(1))

                row_mid = img_array[:, 128:384]
                Row_mid.append(row_mid.sum(1))

                RH_img = img_array[: , 256:]
                RH_sum.append(RH_img.sum(1))

                #coloumn inputs
                TC_img = img_array[:256 , :]
                TC_sum.append(TC_img.sum(0))

                col_mid = img_array[128:384, :]
                Col_mid.append(col_mid.sum(0)) 

                BC_img = img_array[256: , :]
                BC_sum.append(BC_img.sum(0))

                
                #raw_image.append(img_array)             

                label.append(class_num)
                
            except Exception as e:
                pass
    
    #df_data["raw data"] = raw_image
    df_data["row_sum"] = row_sum
    df_data["coloumn_sum"] = coloumn_sum

    df_data["LH_sum"] = LH_sum
    df_data["Row_mid"] = Row_mid
    df_data["RH_sum"] = RH_sum


    df_data["TC_sum"] = TC_sum
    df_data["Col_mid"] = Col_mid
    df_data["BC_sum"] = BC_sum

    df_data["label"] = label
    

    return df_data

# %%
dataset_df = pre_process_dataset(DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/5719 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/5514 [00:00<?, ?it/s]

# %%
dataset_df.head(-1)
# Out:
#                                                  row_sum  \
# 0      [26099, 25676, 25188, 24716, 24349, 24010, 236...
# 1      [73474, 73717, 73998, 74214, 74359, 74470, 746...
# 2      [76642, 76817, 77127, 77520, 77719, 77849, 779...
# 3      [53413, 53410, 53496, 53710, 53849, 54026, 542...
# 4      [48830, 49179, 49634, 50119, 50160, 50264, 503...
# ...                                                  ...
# 11227  [77073, 77674, 78399, 79040, 79015, 78901, 787...
# 11228  [68286, 68935, 69634, 70079, 69976, 69901, 699...
# 11229  [77895, 77209, 76363, 75413, 74768, 74269, 737...
# 11230  [68831, 68766, 68644, 68482, 68493, 68598, 688...
# 11231  [72012, 72076, 72155, 72206, 72260, 72365, 725...
#
#                                              coloumn_sum  \
# 0      [15188, 15165, 15034, 14946, 14851, 14789, 147...
# 1      [78050, 78059, 78168, 78281, 78422, 78550, 786...
# 2      [75406, 75193, 74807, 74522, 74382, 74313, 743...
# 3      [49764, 49674, 49607, 49614, 49681, 49754, 498...
# 4      [40579, 40502, 40367, 40241, 40157, 40100, 400...
# ...                                                  ...
# 11227  [69335, 69057, 68479, 67895, 67302, 66655, 659...
# 11228  [60614, 60424, 60035, 59813, 59764, 59777, 598...
# 11229  [65379, 64215, 61859, 59863, 58356, 57253, 566...
# 11230  [76030, 76013, 76063, 76113, 76181, 76248, 763...
# 11231  [39739, 39940, 40313, 40945, 41858, 42883, 440...
#
#                                                   LH_sum  \
# 0      [26099, 25676, 25188, 24716, 24349, 24010, 236...
# 1      [73474, 73717, 73998, 74214, 74359, 74470, 746...
# 2      [76642, 76817, 77127, 77520, 77719, 77849, 779...
# 3      [53413, 53410, 53496, 53710, 53849, 54026, 542...
# 4      [48830, 49179, 49634, 50119, 50160, 50264, 503...
# ...                                                  ...
# 11227  [77073, 77674, 78399, 79040, 79015, 78901, 787...
# 11228  [68286, 68935, 69634, 70079, 69976, 69901, 699...
# 11229  [77895, 77209, 76363, 75413, 74768, 74269, 737...
# 11230  [68831, 68766, 68644, 68482, 68493, 68598, 688...
# 11231  [72012, 72076, 72155, 72206, 72260, 72365, 725...
#
#                                                  Row_mid  \
# 0      [17257, 17308, 17206, 16999, 16791, 16593, 164...
# 1      [77740, 77757, 77889, 77900, 77824, 77769, 776...
# 2      [57051, 56886, 56925, 57015, 56670, 56043, 552...
# 3      [16925, 16914, 16893, 16670, 16451, 16281, 162...
# 4      [24655, 24666, 24556, 24521, 24443, 24219, 237...
# ...                                                  ...
# 11227  [50968, 51052, 51157, 51223, 51262, 51273, 511...
# 11228  [59468, 59371, 59349, 59337, 59307, 59343, 594...
# 11229  [45475, 46049, 46538, 46848, 47072, 47252, 473...
# 11230  [65699, 65613, 65534, 65435, 65288, 65150, 650...
# 11231  [51712, 51868, 52117, 52330, 52463, 52565, 525...
#
#                                                   RH_sum  \
# 0      [55047, 55336, 55679, 55849, 55961, 55943, 558...
# 1      [85422, 85439, 85490, 85738, 86159, 86663, 871...
# 2      [79862, 79614, 79340, 79161, 79080, 78984, 790...
# 3      [56771, 56859, 57095, 57166, 57177, 57220, 575...
# 4      [60037, 60186, 60265, 60663, 61459, 62813, 645...
# ...                                                  ...
# 11227  [79387, 78864, 78314, 77927, 77636, 77320, 770...
# 11228  [74329, 74503, 74887, 75443, 76056, 76493, 766...
# 11229  [74458, 74633, 74934, 75155, 75397, 75540, 756...
# 11230  [78803, 78765, 78653, 78493, 78316, 78102, 779...
# 11231  [74675, 74960, 75309, 75533, 75714, 75841, 760...
#
#                                                   TC_sum  \
# 0      [15188, 15165, 15034, 14946, 14851, 14789, 147...
# 1      [78050, 78059, 78168, 78281, 78422, 78550, 786...
# 2      [75406, 75193, 74807, 74522, 74382, 74313, 743...
# 3      [49764, 49674, 49607, 49614, 49681, 49754, 498...
# 4      [40579, 40502, 40367, 40241, 40157, 40100, 400...
# ...                                                  ...
# 11227  [69335, 69057, 68479, 67895, 67302, 66655, 659...
# 11228  [60614, 60424, 60035, 59813, 59764, 59777, 598...
# 11229  [65379, 64215, 61859, 59863, 58356, 57253, 566...
# 11230  [76030, 76013, 76063, 76113, 76181, 76248, 763...
# 11231  [39739, 39940, 40313, 40945, 41858, 42883, 440...
#
#                                                  Col_mid  \
# 0      [21553, 21452, 21389, 21353, 21375, 21402, 214...
# 1      [80761, 80846, 80960, 81062, 81138, 81227, 812...
# 2      [67445, 67451, 67515, 67602, 67720, 67816, 678...
# 3      [29631, 29718, 29789, 29884, 29953, 30033, 301...
# 4      [47174, 46966, 46706, 46388, 46022, 45673, 454...
# ...                                                  ...
# 11227  [58016, 58131, 58269, 58323, 58281, 58228, 581...
# 11228  [66958, 66770, 66528, 66328, 66130, 65942, 658...
# 11229  [53799, 53779, 53802, 53828, 53904, 53993, 541...
# 11230  [77646, 77611, 77659, 77713, 77779, 77813, 778...
# 11231  [56733, 56699, 56601, 56525, 56458, 56439, 564...
#
#                                                   BC_sum  label
# 0      [21073, 20901, 20722, 20493, 20225, 19897, 194...      0
# 1      [80046, 79912, 79781, 79654, 79494, 79366, 792...      0
# 2      [66811, 66740, 66607, 66396, 66054, 65654, 651...      0
# 3      [28171, 28202, 28304, 28359, 28393, 28397, 283...      0
# 4      [17165, 16952, 16759, 16618, 16559, 16619, 168...      0
# ...                                                  ...    ...
# 11227  [56939, 56877, 56834, 56809, 56732, 56732, 567...      1
# 11228  [46095, 46168, 46242, 46313, 46377, 46450, 465...      1
# 11229  [51190, 50941, 50566, 50164, 49703, 49345, 491...      1
# 11230  [72727, 72652, 72607, 72591, 72664, 72721, 727...      1
# 11231  [53085, 53073, 53085, 53114, 53119, 53148, 531...      1
#
# [11232 rows x 9 columns]

# %%
df_train, df_val = train_test_split(dataset_df, test_size=0.2, random_state=0)

# %%
df_train["label"].value_counts()
# Out:
# 0    4601
# 1    4385
# Name: label, dtype: int64

# %%
print("No of Training samples:",len(df_train))
print("No of Validation samples:",len(df_val))
# Out:
# No of Training samples: 8986
# No of Validation samples: 2247

# %%
df_train["Row_mid"][0].shape
# Out:
# (512,)

# %%
from sklearn import preprocessing

def process_data(dataset_df):
    
    row = dataset_df["row_sum"].values
    coloumn = dataset_df["coloumn_sum"].values

    LH = dataset_df["LH_sum"].values
    Row_mid = dataset_df["Row_mid"].values
    RH = dataset_df["RH_sum"].values


    TC = dataset_df["TC_sum"].values
    Col_mid = dataset_df["Col_mid"].values
    BC = dataset_df["BC_sum"].values

    # global
    X1 = [img.tolist() for img in row]
    X2 = [img.tolist() for img in coloumn]

    #row
    X3 = [img.tolist() for img in LH]
    X_row_mid = [img.tolist() for img in Row_mid]
    X4 = [img.tolist() for img in RH]

    #coloumn
    X5 = [img.tolist() for img in TC]
    X_col_mid = [img.tolist() for img in Col_mid]
    X6 = [img.tolist() for img in BC]


    X1 = np.array(X1)
    X2 = np.array(X2)

    X3 = np.array(X3)
    X_row_mid = np.array(X_row_mid)
    X4 = np.array(X4)


    X5 = np.array(X5)
    X_col_mid = np.array(X_col_mid)
    X6 = np.array(X6)

    #normalize the inputs
    X1 = preprocessing.normalize(X1)
    X2 = preprocessing.normalize(X2)

    X3 = preprocessing.normalize(X3)
    X_row_mid = preprocessing.normalize(X_row_mid)
    X4 = preprocessing.normalize(X4)

    X5 = preprocessing.normalize(X5)
    X_col_mid = preprocessing.normalize(X_col_mid)
    X6 = preprocessing.normalize(X6)

    #reshape the inputs
    X1 = np.expand_dims(X1, axis=-1)
    X2 = np.expand_dims(X2, axis=-1)

    X3 = np.expand_dims(X3, axis=-1)
    X_row_mid = np.expand_dims(X_row_mid, axis=-1)
    X4 = np.expand_dims(X4, axis=-1)

    X5 = np.expand_dims(X5, axis=-1)
    X_col_mid = np.expand_dims(X_col_mid, axis=-1)
    X6 = np.expand_dims(X6, axis=-1)



    y = np.array(dataset_df["label"].values)
    y = np.expand_dims(y, axis=-1)


    print("X1 shape", X1.shape)
    print("X2 shape", X2.shape)

    print("X3 shape", X3.shape)
    print("Mid rows shape", X_row_mid.shape)
    print("X4 shape", X4.shape)

    print("X5 shape", X5.shape)
    print("Mid Cols shape", X_col_mid.shape)
    print("X6 shape", X6.shape)

    print("y shape", y.shape)

    return X1, X2, X3, X_row_mid, X4, X5, X_col_mid, X6, y

# %%
print("Training samples:")
X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train, Y_train = process_data(df_train)

print("\nValidation samples:")
X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val, Y_val = process_data(df_val)
# Out:
# Training samples:
# X1 shape (8986, 512, 1)
# X2 shape (8986, 512, 1)
# X3 shape (8986, 512, 1)
# Mid rows shape (8986, 512, 1)
# X4 shape (8986, 512, 1)
# X5 shape (8986, 512, 1)
# Mid Cols shape (8986, 512, 1)
# X6 shape (8986, 512, 1)
# y shape (8986, 1)
#
# Validation samples:
# X1 shape (2247, 512, 1)
# X2 shape (2247, 512, 1)
# X3 shape (2247, 512, 1)
# Mid rows shape (2247, 512, 1)
# X4 shape (2247, 512, 1)
# X5 shape (2247, 512, 1)
# Mid Cols shape (2247, 512, 1)
# X6 shape (2247, 512, 1)
# y shape (2247, 1)

# %%
# first input model
row = Input(shape=(512,1))
conv11 = Conv1D(64, kernel_size=3, activation='relu')(row)
conv12 = Conv1D(64, kernel_size=3, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat_row = Flatten()(pool11)


# second input model
col = Input(shape=(512,1))
conv21 = Conv1D(64, kernel_size=3, activation='relu')(col)
conv22 = Conv1D(64, kernel_size=3, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat_col = Flatten()(pool21)

# merge input models
merge = concatenate([flat_row, flat_col])

hidden1 = Dense(100, activation='relu')(merge)
hidden_global = Dense(100, activation='relu')(hidden1)

#####################################################################

LH = Input(shape=(256,1))
conv31 = Conv1D(64, kernel_size=3, activation='relu')(LH)
conv32 = Conv1D(64, kernel_size=3, activation='relu')(conv31)
drop31 = Dropout(0.25)(conv32)
pool31 = MaxPooling1D(pool_size=2)(drop31)
flat3 = Flatten()(pool31)

row_mid = Input(shape=(256,1))
conv41 = Conv1D(64, kernel_size=3, activation='relu')(row_mid)
conv42 = Conv1D(64, kernel_size=3, activation='relu')(conv41)
drop41 = Dropout(0.25)(conv42)
pool41 = MaxPooling1D(pool_size=2)(drop41)
flat4 = Flatten()(pool41)

RH = Input(shape=(256,1))
conv51 = Conv1D(64, kernel_size=3, activation='relu')(RH)
conv52 = Conv1D(64, kernel_size=3, activation='relu')(conv51)
drop51 = Dropout(0.25)(conv52)
pool51 = MaxPooling1D(pool_size=2)(drop51)
flat5 = Flatten()(pool51)

# merge input models
merge_rows = concatenate([flat3, flat4, flat5])
hidden3 = Dense(100, activation='relu')(merge_rows)
hidden_rows = Dense(100, activation='relu')(hidden3)




TC = Input(shape=(256,1))
conv61 = Conv1D(64, kernel_size=3, activation='relu')(TC)
conv62 = Conv1D(64, kernel_size=3, activation='relu')(conv61)
drop61 = Dropout(0.25)(conv62)
pool61 = MaxPooling1D(pool_size=2)(drop61)
flat6 = Flatten()(pool61)

col_mid = Input(shape=(256,1))
conv71 = Conv1D(64, kernel_size=3, activation='relu')(col_mid)
conv72 = Conv1D(64, kernel_size=3, activation='relu')(conv71)
drop71 = Dropout(0.25)(conv72)
pool71 = MaxPooling1D(pool_size=2)(drop71)
flat7 = Flatten()(pool71)

BC = Input(shape=(256,1))
conv81 = Conv1D(64, kernel_size=3, activation='relu')(BC)
conv82 = Conv1D(64, kernel_size=3, activation='relu')(conv81)
drop81 = Dropout(0.25)(conv82)
pool81 = MaxPooling1D(pool_size=2)(drop81)
flat8 = Flatten()(pool81)



merge_cols = concatenate([flat6, flat7, flat8])
hidden5 = Dense(100, activation='relu')(merge_cols)
hidden_cols = Dense(100, activation='relu')(hidden5)

# merge input models
merge_row_col = concatenate([hidden_rows, hidden_cols])
merge_all = concatenate([hidden_global, merge_row_col])

output = Dense(1, activation='sigmoid')(merge_all)
model = Model(inputs=[row, col, LH, row_mid, RH, TC, col_mid, BC], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_4 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_5 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_6 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_7 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_8 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_1 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_2 (InputLayer)           [(None, 512, 1)]     0           []
#
#  conv1d_4 (Conv1D)              (None, 254, 64)      256         ['input_3[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 254, 64)      256         ['input_4[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 254, 64)      256         ['input_5[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 254, 64)      256         ['input_6[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 254, 64)      256         ['input_7[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 254, 64)      256         ['input_8[0][0]']
#
#  conv1d (Conv1D)                (None, 510, 64)      256         ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 510, 64)      256         ['input_2[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 252, 64)      12352       ['conv1d_4[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 252, 64)      12352       ['conv1d_6[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 252, 64)      12352       ['conv1d_8[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 252, 64)      12352       ['conv1d_10[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 252, 64)      12352       ['conv1d_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 252, 64)      12352       ['conv1d_14[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 508, 64)      12352       ['conv1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 508, 64)      12352       ['conv1d_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 252, 64)      0           ['conv1d_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 252, 64)      0           ['conv1d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 252, 64)      0           ['conv1d_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 252, 64)      0           ['conv1d_11[0][0]']
#
#  dropout_6 (Dropout)            (None, 252, 64)      0           ['conv1d_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 252, 64)      0           ['conv1d_15[0][0]']
#
#  dropout (Dropout)              (None, 508, 64)      0           ['conv1d_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 508, 64)      0           ['conv1d_3[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_3[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_5[0][0]']
#
#  max_pooling1d_6 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_6[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_7[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 254, 64)      0           ['dropout[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 254, 64)     0           ['dropout_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 8064)         0           ['max_pooling1d_2[0][0]']
#
#  flatten_3 (Flatten)            (None, 8064)         0           ['max_pooling1d_3[0][0]']
#
#  flatten_4 (Flatten)            (None, 8064)         0           ['max_pooling1d_4[0][0]']
#
#  flatten_5 (Flatten)            (None, 8064)         0           ['max_pooling1d_5[0][0]']
#
#  flatten_6 (Flatten)            (None, 8064)         0           ['max_pooling1d_6[0][0]']
#
#  flatten_7 (Flatten)            (None, 8064)         0           ['max_pooling1d_7[0][0]']
#
#  flatten (Flatten)              (None, 16256)        0           ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)            (None, 16256)        0           ['max_pooling1d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 24192)        0           ['flatten_2[0][0]',
#                                                                   'flatten_3[0][0]',
#                                                                   'flatten_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 24192)        0           ['flatten_5[0][0]',
#                                                                   'flatten_6[0][0]',
#                                                                   'flatten_7[0][0]']
#
#  concatenate (Concatenate)      (None, 32512)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 100)          2419300     ['concatenate_1[0][0]']
#
#  dense_4 (Dense)                (None, 100)          2419300     ['concatenate_2[0][0]']
#
#  dense (Dense)                  (None, 100)          3251300     ['concatenate[0][0]']
#
#  dense_3 (Dense)                (None, 100)          10100       ['dense_2[0][0]']
#
#  dense_5 (Dense)                (None, 100)          10100       ['dense_4[0][0]']
#
#  dense_1 (Dense)                (None, 100)          10100       ['dense[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 200)          0           ['dense_3[0][0]',
#                                                                   'dense_5[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 300)          0           ['dense_1[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  dense_6 (Dense)                (None, 1)            301         ['concatenate_4[0][0]']
#
# ==================================================================================================
# Total params: 8,221,365
# Trainable params: 8,221,365
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# first input model
visible1 = Input(shape=(512,1))
conv11 = Conv1D(64, kernel_size=3, activation='relu')(visible1)

conv12 = Conv1D(64, kernel_size=3, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat1 = Flatten()(pool11)


# second input model

visible2 = Input(shape=(512,1))
conv21 = Conv1D(64, kernel_size=3, activation='relu')(visible2)
conv22 = Conv1D(64, kernel_size=3, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat2 = Flatten()(pool21)


# merge input models
merge = concatenate([flat1, flat2])
# interpretation model
hidden1 = Dense(100, activation='relu')(merge)
hidden2 = Dense(100, activation='relu')(hidden1)

output = Dense(1, activation='sigmoid')(hidden2)
model = Model(inputs=[visible1, visible2], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())

# %% [markdown]
# ## Modified

# %%
# first input model
row = Input(shape=(512,1))
#kernel size 5
conv11 = Conv1D(64, kernel_size=5, activation='relu')(row)
#16
conv12 = Conv1D(32, kernel_size=5, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat_row = Flatten()(pool11)


# second input model
col = Input(shape=(512,1))
conv21 = Conv1D(64, kernel_size=5, activation='relu')(col)
conv22 = Conv1D(32, kernel_size=5, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat_col = Flatten()(pool21)

# merge input models
#merge = concatenate([flat_row, flat_col])

#hidden1 = Dense(100, activation='relu')(merge)
#hidden_global = Dense(100, activation='relu')(hidden1)

#####################################################################

LH = Input(shape=(512,1))
conv31 = Conv1D(64, kernel_size=5, activation='relu')(LH)
conv32 = Conv1D(32, kernel_size=5, activation='relu')(conv31)
drop31 = Dropout(0.25)(conv32)
pool31 = MaxPooling1D(pool_size=2)(drop31)
flat3 = Flatten()(pool31)

row_mid = Input(shape=(512,1))
conv41 = Conv1D(64, kernel_size=5, activation='relu')(row_mid)
conv42 = Conv1D(32, kernel_size=5, activation='relu')(conv41)
drop41 = Dropout(0.25)(conv42)
pool41 = MaxPooling1D(pool_size=2)(drop41)
flat4 = Flatten()(pool41)

RH = Input(shape=(512,1))
conv51 = Conv1D(64, kernel_size=5, activation='relu')(RH)
conv52 = Conv1D(32, kernel_size=5, activation='relu')(conv51)
drop51 = Dropout(0.25)(conv52)
pool51 = MaxPooling1D(pool_size=2)(drop51)
flat5 = Flatten()(pool51)


TC = Input(shape=(512,1))
conv61 = Conv1D(64, kernel_size=5, activation='relu')(TC)
conv62 = Conv1D(32, kernel_size=5, activation='relu')(conv61)
drop61 = Dropout(0.25)(conv62)
pool61 = MaxPooling1D(pool_size=2)(drop61)
flat6 = Flatten()(pool61)

col_mid = Input(shape=(512,1))
conv71 = Conv1D(64, kernel_size=5, activation='relu')(col_mid)
conv72 = Conv1D(32, kernel_size=5, activation='relu')(conv71)
drop71 = Dropout(0.25)(conv72)
pool71 = MaxPooling1D(pool_size=2)(drop71)
flat7 = Flatten()(pool71)

BC = Input(shape=(512,1))
conv81 = Conv1D(64, kernel_size=5, activation='relu')(BC)
conv82 = Conv1D(32, kernel_size=5, activation='relu')(conv81)
drop81 = Dropout(0.25)(conv82)
pool81 = MaxPooling1D(pool_size=2)(drop81)
flat8 = Flatten()(pool81)



merge_all = concatenate([flat_row, flat_col, flat3, flat4, flat5, flat6, flat7, flat8])
hidden_all_1 = Dense(128, activation='relu')(merge_all)
hidden_all_2 = Dense(64, activation='relu')(hidden_all_1)

output = Dense(1, activation='sigmoid')(hidden_all_2)
model = Model(inputs=[row, col, LH, row_mid, RH, TC, col_mid, BC], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_2 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_3 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_4 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_5 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_6 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_7 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_8 (InputLayer)           [(None, 512, 1)]     0           []
#
#  conv1d (Conv1D)                (None, 508, 64)      384         ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 508, 64)      384         ['input_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 508, 64)      384         ['input_3[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 508, 64)      384         ['input_4[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 508, 64)      384         ['input_5[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 508, 64)      384         ['input_6[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 508, 64)      384         ['input_7[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 508, 64)      384         ['input_8[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 504, 32)      10272       ['conv1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 504, 32)      10272       ['conv1d_2[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 504, 32)      10272       ['conv1d_4[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 504, 32)      10272       ['conv1d_6[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 504, 32)      10272       ['conv1d_8[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 504, 32)      10272       ['conv1d_10[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 504, 32)      10272       ['conv1d_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 504, 32)      10272       ['conv1d_14[0][0]']
#
#  dropout (Dropout)              (None, 504, 32)      0           ['conv1d_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 504, 32)      0           ['conv1d_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 504, 32)      0           ['conv1d_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 504, 32)      0           ['conv1d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 504, 32)      0           ['conv1d_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 504, 32)      0           ['conv1d_11[0][0]']
#
#  dropout_6 (Dropout)            (None, 504, 32)      0           ['conv1d_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 504, 32)      0           ['conv1d_15[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 252, 32)      0           ['dropout[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 252, 32)     0           ['dropout_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 252, 32)     0           ['dropout_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 252, 32)     0           ['dropout_3[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 252, 32)     0           ['dropout_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 252, 32)     0           ['dropout_5[0][0]']
#
#  max_pooling1d_6 (MaxPooling1D)  (None, 252, 32)     0           ['dropout_6[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 252, 32)     0           ['dropout_7[0][0]']
#
#  flatten (Flatten)              (None, 8064)         0           ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)            (None, 8064)         0           ['max_pooling1d_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 8064)         0           ['max_pooling1d_2[0][0]']
#
#  flatten_3 (Flatten)            (None, 8064)         0           ['max_pooling1d_3[0][0]']
#
#  flatten_4 (Flatten)            (None, 8064)         0           ['max_pooling1d_4[0][0]']
#
#  flatten_5 (Flatten)            (None, 8064)         0           ['max_pooling1d_5[0][0]']
#
#  flatten_6 (Flatten)            (None, 8064)         0           ['max_pooling1d_6[0][0]']
#
#  flatten_7 (Flatten)            (None, 8064)         0           ['max_pooling1d_7[0][0]']
#
#  concatenate (Concatenate)      (None, 64512)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]',
#                                                                   'flatten_2[0][0]',
#                                                                   'flatten_3[0][0]',
#                                                                   'flatten_4[0][0]',
#                                                                   'flatten_5[0][0]',
#                                                                   'flatten_6[0][0]',
#                                                                   'flatten_7[0][0]']
#
#  dense (Dense)                  (None, 128)          8257664     ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            65          ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 8,351,233
# Trainable params: 8,351,233
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
BATCH_SIZE = 128
EPOCHS = 500
history = model.fit(
    [X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train],
    Y_train,
    BATCH_SIZE,
    EPOCHS,
    validation_data=([X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val], Y_val),
    callbacks=[tensorboard])

model.save("D:/Project2022/models/"+model_name+".h5")
# Out:
# Epoch 1/500
# 71/71 [==============================] - 12s 82ms/step - loss: 0.5994 - accuracy: 0.6753 - val_loss: 0.5051 - val_accuracy: 0.7401
# Epoch 2/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.4509 - accuracy: 0.7938 - val_loss: 0.4404 - val_accuracy: 0.8015
# Epoch 3/500
# 71/71 [==============================] - 5s 72ms/step - loss: 0.4103 - accuracy: 0.8165 - val_loss: 0.3842 - val_accuracy: 0.8344
# Epoch 4/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.3838 - accuracy: 0.8323 - val_loss: 0.3918 - val_accuracy: 0.8442
# Epoch 5/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.3569 - accuracy: 0.8517 - val_loss: 0.3585 - val_accuracy: 0.8571
# Epoch 6/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.3413 - accuracy: 0.8590 - val_loss: 0.3429 - val_accuracy: 0.8589
# Epoch 7/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.3233 - accuracy: 0.8678 - val_loss: 0.3567 - val_accuracy: 0.8505
# Epoch 8/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.3442 - accuracy: 0.8558 - val_loss: 0.3285 - val_accuracy: 0.8696
# Epoch 9/500
# 71/71 [==============================] - 5s 72ms/step - loss: 0.3088 - accuracy: 0.8704 - val_loss: 0.3145 - val_accuracy: 0.8821
# Epoch 10/500
# 71/71 [==============================] - 5s 72ms/step - loss: 0.2997 - accuracy: 0.8764 - val_loss: 0.2986 - val_accuracy: 0.8847
# Epoch 11/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.2932 - accuracy: 0.8783 - val_loss: 0.3111 - val_accuracy: 0.8732
# Epoch 12/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.2764 - accuracy: 0.8898 - val_loss: 0.2977 - val_accuracy: 0.8807
# Epoch 13/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.2815 - accuracy: 0.8850 - val_loss: 0.3610 - val_accuracy: 0.8451
# Epoch 14/500
# 71/71 [==============================] - 5s 73ms/step - loss: 0.
500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.1543e-04 - accuracy: 1.0000 - val_loss: 0.3069 - val_accuracy: 0.9533
# Epoch 201/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.9619e-04 - accuracy: 1.0000 - val_loss: 0.3163 - val_accuracy: 0.9533
# Epoch 202/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.7637e-04 - accuracy: 1.0000 - val_loss: 0.3235 - val_accuracy: 0.9524
# Epoch 203/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.7559e-04 - accuracy: 1.0000 - val_loss: 0.3157 - val_accuracy: 0.9533
# Epoch 204/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.8559e-04 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9528
# Epoch 205/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.8888e-04 - accuracy: 1.0000 - val_loss: 0.3066 - val_accuracy: 0.9555
# Epoch 206/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.9495e-04 - accuracy: 1.0000 - val_loss: 0.3104 - val_accuracy: 0.9537
# Epoch 207/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.8020e-04 - accuracy: 1.0000 - val_loss: 0.3243 - val_accuracy: 0.9528
# Epoch 208/500
# 71/71 [==============================] - 5s 74ms/step - loss: 9.9979e-04 - accuracy: 0.9997 - val_loss: 0.3572 - val_accuracy: 0.9390
# Epoch 209/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.2089 - accuracy: 0.9432 - val_loss: 0.3343 - val_accuracy: 0.9101
# Epoch 210/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0762 - accuracy: 0.9711 - val_loss: 0.2132 - val_accuracy: 0.9372
# Epoch 211/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0159 - accuracy: 0.9959 - val_loss: 0.2357 - val_accuracy: 0.9435
# Epoch 212/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0086 - accuracy: 0.9986 - val_loss: 0.2358 - val_accuracy: 0.9502
# Epoch 213/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.2325 - val_accuracy: 0.9537
# Epoch 214/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.2481 - val_accuracy: 0.9510
# Epoch 215/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.2382 - val_accuracy: 0.9493
# Epoch 216/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9524
# Epoch 217/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9515
# Epoch 218/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2471 - val_accuracy: 0.9506
# Epoch 219/500
# 71/71 [==============================] - 5s 74ms/step - loss: 9.9474e-04 - accuracy: 1.0000 - val_loss: 0.2483 - val_accuracy: 0.9524
# Epoch 220/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.2540 - val_accuracy: 0.9493
# Epoch 221/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.2826 - val_accuracy: 0.9506
# Epoch 222/500
# 71/71 [==============================] - 5s 74ms/step - loss: 9.5995e-04 - accuracy: 1.0000 - val_loss: 0.2549 - val_accuracy: 0.9537
# Epoch 223/500
# 71/71 [==============================] - 5s 74ms/step - loss: 8.0865e-04 - accuracy: 1.0000 - val_loss: 0.2680 - val_accuracy: 0.9488
# Epoch 224/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.2728 - val_accuracy: 0.9430
# Epoch 225/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0734 - accuracy: 0.9737 - val_loss: 0.2924 - val_accuracy: 0.9404
# Epoch 226/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0366 - accuracy: 0.9881 - val_loss: 0.2489 - val_accuracy: 0.9390
# Epoch 227/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0212 - accuracy: 0.9922 - val_loss: 0.2271 - val_accuracy: 0.9475
# Epoch 228/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.2347 - val_accuracy: 0.9528
# Epoch 229/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.2280 - val_accuracy: 0.9537
# Epoch 230/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9537
# Epoch 231/500
# 71/71 [==============================] - 5s 74ms/step - loss: 7.5004e-04 - accuracy: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.9537
# Epoch 232/500
# 71/71 [==============================] - 5s 74ms/step - loss: 5.5462e-04 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.9533
# Epoch 233/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.2516 - val_accuracy: 0.9533
# Epoch 234/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.2635 - val_accuracy: 0.9515
# Epoch 235/500
# 71/71 [==============================] - 5s 74ms/step - loss: 6.8653e-04 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9537
# Epoch 236/500
# 71/71 [==============================] - 5s 75ms/step - loss: 4.6628e-04 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9546
# Epoch 237/500
# 71/71 [==============================] - 5s 74ms/step - loss: 4.6176e-04 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9542
# Epoch 238/500
# 71/71 [==============================] - 5s 75ms/step - loss: 3.5761e-04 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9546
# Epoch 239/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.3360e-04 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9555
# Epoch 240/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.9826e-04 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9546
# Epoch 241/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.8259e-04 - accuracy: 1.0000 - val_loss: 0.2692 - val_accuracy: 0.9551
# Epoch 242/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.3663e-04 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9537
# Epoch 243/500
# 71/71 [==============================] - 5s 75ms/step - loss: 2.8379e-04 - accuracy: 1.0000 - val_loss: 0.2874 - val_accuracy: 0.9506
# Epoch 244/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.2661 - val_accuracy: 0.9524
# Epoch 245/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.
- accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.9528
# Epoch 291/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.3938e-04 - accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 0.9533
# Epoch 292/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.1711e-04 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9533
# Epoch 293/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.8929e-04 - accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.9533
# Epoch 294/500
# 71/71 [==============================] - 5s 74ms/step - loss: 4.5502e-04 - accuracy: 1.0000 - val_loss: 0.2603 - val_accuracy: 0.9528
# Epoch 295/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.3723 - val_accuracy: 0.9350
# Epoch 296/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.1314 - accuracy: 0.9617 - val_loss: 0.2920 - val_accuracy: 0.9221
# Epoch 297/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0394 - accuracy: 0.9863 - val_loss: 0.2248 - val_accuracy: 0.9470
# Epoch 298/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.2053 - val_accuracy: 0.9546
# Epoch 299/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.2364 - val_accuracy: 0.9542
# Epoch 300/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2425 - val_accuracy: 0.9542
# Epoch 301/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.2452 - val_accuracy: 0.9551
# Epoch 302/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.2373 - val_accuracy: 0.9537
# Epoch 303/500
# 71/71 [==============================] - 5s 75ms/step - loss: 6.2498e-04 - accuracy: 1.0000 - val_loss: 0.2433 - val_accuracy: 0.9559
# Epoch 304/500
# 71/71 [==============================] - 5s 75ms/step - loss: 5.2301e-04 - accuracy: 1.0000 - val_loss: 0.2429 - val_accuracy: 0.9573
# Epoch 305/500
# 71/71 [==============================] - 5s 74ms/step - loss: 4.8573e-04 - accuracy: 1.0000 - val_loss: 0.2343 - val_accuracy: 0.9568
# Epoch 306/500
# 71/71 [==============================] - 5s 74ms/step - loss: 5.4503e-04 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.9568
# Epoch 307/500
# 71/71 [==============================] - 5s 74ms/step - loss: 4.2299e-04 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9555
# Epoch 308/500
# 71/71 [==============================] - 5s 74ms/step - loss: 4.4420e-04 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9573
# Epoch 309/500
# 71/71 [==============================] - 5s 74ms/step - loss: 5.8045e-04 - accuracy: 1.0000 - val_loss: 0.2601 - val_accuracy: 0.9564
# Epoch 310/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.1896e-04 - accuracy: 1.0000 - val_loss: 0.2505 - val_accuracy: 0.9559
# Epoch 311/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.8145e-04 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9555
# Epoch 312/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.9958e-04 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9559
# Epoch 313/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.8206e-04 - accuracy: 1.0000 - val_loss: 0.2604 - val_accuracy: 0.9551
# Epoch 314/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.3239 - val_accuracy: 0.9453
# Epoch 315/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0988 - accuracy: 0.9704 - val_loss: 0.3076 - val_accuracy: 0.9270
# Epoch 316/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0361 - accuracy: 0.9871 - val_loss: 0.2338 - val_accuracy: 0.9524
# Epoch 317/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0195 - accuracy: 0.9924 - val_loss: 0.2386 - val_accuracy: 0.9497
# Epoch 318/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.2428 - val_accuracy: 0.9506
# Epoch 319/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.2518 - val_accuracy: 0.9515
# Epoch 320/500
# 71/71 [==============================] - 5s 75ms/step - loss: 9.3359e-04 - accuracy: 1.0000 - val_loss: 0.2467 - val_accuracy: 0.9510
# Epoch 321/500
# 71/71 [==============================] - 5s 75ms/step - loss: 4.9652e-04 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9528
# Epoch 322/500
# 71/71 [==============================] - 5s 75ms/step - loss: 4.2148e-04 - accuracy: 1.0000 - val_loss: 0.2495 - val_accuracy: 0.9519
# Epoch 323/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.8835e-04 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9537
# Epoch 324/500
# 71/71 [==============================] - 5s 75ms/step - loss: 3.2415e-04 - accuracy: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9533
# Epoch 325/500
# 71/71 [==============================] - 5s 75ms/step - loss: 3.0397e-04 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9528
# Epoch 326/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.2000e-04 - accuracy: 1.0000 - val_loss: 0.2474 - val_accuracy: 0.9533
# Epoch 327/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.5942e-04 - accuracy: 1.0000 - val_loss: 0.2711 - val_accuracy: 0.9524
# Epoch 328/500
# 71/71 [==============================] - 5s 75ms/step - loss: 2.3751e-04 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9524
# Epoch 329/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.7356e-04 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9537
# Epoch 330/500
# 71/71 [==============================] - 5s 75ms/step - loss: 2.6003e-04 - accuracy: 1.0000 - val_loss: 0.2618 - val_accuracy: 0.9519
# Epoch 331/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.1437e-04 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9537
# Epoch 332/500
# ...
# Epoch 392/500
# 71/71 [==============================] - 5s 74ms/step - loss: 8.2656e-05 - accuracy: 1.0000 - val_loss: 0.2730 - val_accuracy: 0.9524
# Epoch 393/500
# 71/71 [==============================] - 5s 74ms/step - loss: 9.0569e-05 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9502
# Epoch 394/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.0379e-04 - accuracy: 1.0000 - val_loss: 0.2743 - val_accuracy: 0.9515
# Epoch 395/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.5409e-04 - accuracy: 1.0000 - val_loss: 0.2797 - val_accuracy: 0.9506
# Epoch 396/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.2077e-04 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9519
# Epoch 397/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.5048e-04 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9528
# Epoch 398/500
# 71/71 [==============================] - 5s 74ms/step - loss: 8.4993e-05 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.9524
# Epoch 399/500
# 71/71 [==============================] - 5s 74ms/step - loss: 7.3587e-05 - accuracy: 1.0000 - val_loss: 0.2839 - val_accuracy: 0.9515
# Epoch 400/500
# 71/71 [==============================] - 5s 74ms/step - loss: 6.0871e-05 - accuracy: 1.0000 - val_loss: 0.2934 - val_accuracy: 0.9515
# Epoch 401/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0432 - accuracy: 0.9917 - val_loss: 0.6868 - val_accuracy: 0.8665
# Epoch 402/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.1713 - accuracy: 0.9474 - val_loss: 0.2448 - val_accuracy: 0.9306
# Epoch 403/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0241 - accuracy: 0.9929 - val_loss: 0.1975 - val_accuracy: 0.9497
# Epoch 404/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.2354 - val_accuracy: 0.9448
# Epoch 405/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.2486 - val_accuracy: 0.9484
# Epoch 406/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.2885 - val_accuracy: 0.9462
# Epoch 407/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.2480 - val_accuracy: 0.9510
# Epoch 408/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.2630 - val_accuracy: 0.9475
# Epoch 409/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.2638 - val_accuracy: 0.9533
# Epoch 410/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.2439 - val_accuracy: 0.9502
# Epoch 411/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.2401 - val_accuracy: 0.9502
# Epoch 412/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.3149 - val_accuracy: 0.9439
# Epoch 413/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.2582 - val_accuracy: 0.9497
# Epoch 414/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.3161 - val_accuracy: 0.9484
# Epoch 415/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.2855 - val_accuracy: 0.9475
# Epoch 416/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.2875 - val_accuracy: 0.9466
# Epoch 417/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.3171 - val_accuracy: 0.9386
# Epoch 418/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0422 - accuracy: 0.9852 - val_loss: 0.3019 - val_accuracy: 0.9332
# Epoch 419/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.2839 - val_accuracy: 0.9479
# Epoch 420/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.2680 - val_accuracy: 0.9493
# Epoch 421/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.2620 - val_accuracy: 0.9439
# Epoch 422/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.2216 - val_accuracy: 0.9537
# Epoch 423/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.2288 - val_accuracy: 0.9573
# Epoch 424/500
# 71/71 [==============================] - 5s 75ms/step - loss: 4.5629e-04 - accuracy: 1.0000 - val_loss: 0.2448 - val_accuracy: 0.9524
# Epoch 425/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.1533e-04 - accuracy: 1.0000 - val_loss: 0.2356 - val_accuracy: 0.9551
# Epoch 426/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.4317e-04 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9542
# Epoch 427/500
# 71/71 [==============================] - 5s 74ms/step - loss: 2.1794e-04 - accuracy: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.9510
# Epoch 428/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.8599e-04 - accuracy: 1.0000 - val_loss: 0.2483 - val_accuracy: 0.9510
# Epoch 429/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.7371e-04 - accuracy: 1.0000 - val_loss: 0.2502 - val_accuracy: 0.9524
# Epoch 430/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.6084e-04 - accuracy: 1.0000 - val_loss: 0.2440 - val_accuracy: 0.9524
# Epoch 431/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.4072e-04 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.9524
# Epoch 432/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.2626e-04 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.9524
# Epoch 433/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.4017e-04 - accuracy: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9537
# Epoch 434/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.2318e-04 - accuracy: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9533
# Epoch 435/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0197 - accuracy: 0.9951 - val_loss: 0.5578 - val_accuracy: 0.9070
# Epoch 436/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0891 - accuracy: 0.9738 - val_loss: 0.2319 - val_accuracy: 0.9466
# Epoch 437/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 0.2717 - val_accuracy: 0.9462
# Epoch 438/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.2721 - val_accuracy: 0.9502
# Epoch 439/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.2438 - val_accuracy: 0.9466
# Epoch 440/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0
- accuracy: 1.0000 - val_loss: 0.2586 - val_accuracy: 0.9537
# Epoch 478/500
# 71/71 [==============================] - 5s 75ms/step - loss: 3.8411e-04 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9528
# Epoch 479/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.9856e-04 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9546
# Epoch 480/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.4653e-04 - accuracy: 1.0000 - val_loss: 0.2668 - val_accuracy: 0.9542
# Epoch 481/500
# 71/71 [==============================] - 5s 74ms/step - loss: 3.8275e-04 - accuracy: 1.0000 - val_loss: 0.2616 - val_accuracy: 0.9564
# Epoch 482/500
# 71/71 [==============================] - 5s 75ms/step - loss: 2.7466e-04 - accuracy: 1.0000 - val_loss: 0.2664 - val_accuracy: 0.9555
# Epoch 483/500
# 71/71 [==============================] - 5s 75ms/step - loss: 2.5187e-04 - accuracy: 1.0000 - val_loss: 0.2725 - val_accuracy: 0.9546
# Epoch 484/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.8821e-04 - accuracy: 1.0000 - val_loss: 0.2743 - val_accuracy: 0.9559
# Epoch 485/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.5832e-04 - accuracy: 1.0000 - val_loss: 0.2729 - val_accuracy: 0.9568
# Epoch 486/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.4694e-04 - accuracy: 1.0000 - val_loss: 0.2702 - val_accuracy: 0.9564
# Epoch 487/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.4844e-04 - accuracy: 1.0000 - val_loss: 0.2765 - val_accuracy: 0.9568
# Epoch 488/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.3396e-04 - accuracy: 1.0000 - val_loss: 0.2762 - val_accuracy: 0.9564
# Epoch 489/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.2471e-04 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.9559
# Epoch 490/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.2909e-04 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.9568
# Epoch 491/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.1571e-04 - accuracy: 1.0000 - val_loss: 0.2899 - val_accuracy: 0.9546
# Epoch 492/500
# 71/71 [==============================] - 5s 74ms/step - loss: 1.0722e-04 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.9551
# Epoch 493/500
# 71/71 [==============================] - 5s 75ms/step - loss: 1.3713e-04 - accuracy: 1.0000 - val_loss: 0.2839 - val_accuracy: 0.9537
# Epoch 494/500
# 71/71 [==============================] - 5s 74ms/step - loss: 7.0016e-04 - accuracy: 0.9997 - val_loss: 0.3132 - val_accuracy: 0.9475
# Epoch 495/500
# 71/71 [==============================] - 5s 75ms/step - loss: 0.0670 - accuracy: 0.9797 - val_loss: 0.3230 - val_accuracy: 0.9292
# Epoch 496/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0455 - accuracy: 0.9846 - val_loss: 0.2614 - val_accuracy: 0.9488
# Epoch 497/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 0.2364 - val_accuracy: 0.9448
# Epoch 498/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.2501 - val_accuracy: 0.9510
# Epoch 499/500
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2675 - val_accuracy: 0.9537
# Epoch 500/500
# 71/71 [==============================] - 5s 75ms/step - loss: 3.8059e-04 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9555

# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (from h5py) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
model = keras.models.load_model("D:/Project2022/models/"+model_name+".h5")

# %%
from keras_visualizer import visualizer
visualizer(model, format='png', view=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 21 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> from keras_visualizer import visualizer
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> visualizer(model, format='png', view=True)
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras_visualizer\__init__.py:130, in visualizer(model, filename, format, view)
#     128         c.node(str(n), label=f'Image\n{pxls[1]} x{pxls[2]} pixels\n{clrmap}', fontcolor='white', shape='square', style='filled', fillcolor=the_color)
#     129     else:
# --> 130         raise ValueError('Keras Visualizer: Layer not supported for visualizing')
#     132 # Hidden Layers
#     133 for i in range(0, hidden_layers_nr):
#
# ValueError: Keras Visualizer: Layer not supported for visualizing

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
pip install keras-visualizer
# Out:
# Collecting keras-visualizer
#   Downloading keras_visualizer-2.4-py3-none-any.whl (5.4 kB)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
model_name
# Out:
# 'mutiple_Conv1D_8_inputs_scaled_modified'

# %%
model.save("D:/Project2022/models/"+model_name+".h5")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> model.save("D:/Project2022/models/"+model_name+".h5")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\saving\hdf5_format.py:80, in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      54 """Saves a model to a HDF5 file.
#      55
#      56 The saved model contains:
#    (...)
#      76     ImportError: if h5py is not available.
#      77 """
#      79 if h5py is None:
# ---> 80     raise ImportError(
#      81         "`save_model()` using h5 format requires h5py. Could not "
#      82         "import h5py."
#      83     )
#      85 # TODO(psv) Add warning when we save models that contain non-serializable
#      86 # entities like metrics added using `add_metric` and losses added using
#      87 # `add_loss.`
#      88 if len(model.weights) != len(model._undeduplicated_weights):
#
# ImportError: `save_model()` using h5 format requires h5py. Could not import h5py.

# %%
#model = keras.models.load_model("D:/Project2022/models/image/raw_500.h5")

#from tensorflow import keras
bing = keras.models.load_model('D:/Project2022/models/image/raw_500.h5')
bing.save(model_name+".h5")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 26 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> #model = keras.models.load_model("D:/Project2022/models/image/raw_500.h5")
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> #from tensorflow import keras
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> bing = keras.models.load_model('D:/Project2022/models/image/raw_500.h5')
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> bing.save(model_name+".h5")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\saving\save.py:236, in load_model(filepath, custom_objects, compile, options)
#     234     else:
#     235         if h5py is None:
# --> 236             raise ImportError(
#     237                 "Filepath looks like a hdf5 file but h5py is "
#     238                 "not available."
#     239                 f" filepath={filepath_str}"
#     240             )
#     241         return hdf5_format.load_model_from_hdf5(
#     242             tf.io.gfile.GFile(filepath_str, mode="rb"),
#     243             custom_objects,
#     244             compile,
#     245         )
#     246 elif h5py is not None and isinstance(filepath, h5py.File):
#
# ImportError: Filepath looks like a hdf5 file but h5py is not available. filepath=D:/Project2022/models/image/raw_500.h5

# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (from h5py) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
model.save("D:/Project2022/models/image/delete.h5")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> import h5py
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> model.save("D:/Project2022/models/image/delete.h5")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\h5py\__init__.py:33, in <module>
#      30     else:
#      31         raise
# ---> 33 from . import version
#      35 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\h5py\version.py:15, in <module>
#      10 """
#      11     Versioning module for h5py.
#      12 """
#      14 from collections import namedtuple
# ---> 15 from . import h5 as _h5
#      16 import sys
#      17 import numpy
#
# File h5py\h5.pyx:1, in init h5py.h5()
#
# ImportError: DLL load failed while importing defs: The specified procedure could not be found.

# %% [markdown]
# # Evaluate the Model using test data

# %%
Test_DATADIR = "D:/Project2022/res/split_dataset/scaled_resized/test"
dataset_df = pre_process_dataset(Test_DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/1430 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/1379 [00:00<?, ?it/s]

# %%
print("No of test sample:", len(dataset_df))
# Out:
# No of test sample: 2809

# %%
X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test, Y_test = process_data(dataset_df)
# Out:
# X1 shape (2809, 512, 1)
# X2 shape (2809, 512, 1)
# X3 shape (2809, 512, 1)
# Mid rows shape (2809, 512, 1)
# X4 shape (2809, 512, 1)
# X5 shape (2809, 512, 1)
# Mid Cols shape (2809, 512, 1)
# X6 shape (2809, 512, 1)
# y shape (2809, 1)

# %%
# test loss, test accuracy
accuracy = model.evaluate([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test], Y_test, batch_size=100, verbose=0)

# %%
print("Test acuuracy", accuracy[1])
print("Test loss", accuracy[0])
# Out:
# Test acuuracy 0.9651121497154236
# Test loss 0.2103874236345291

# %%
#y_pred = model.predict_classes(X_test)
y_pred = (model.predict([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test]) > 0.5).astype("int32")
# Out:
# 88/88 [==============================] - 2s 10ms/step

# %%
print(classification_report(Y_test, y_pred, target_names=["covid", "Normal"]))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.97      0.96      0.97      1430
#       Normal       0.96      0.97      0.96      1379
#
#     accuracy                           0.97      2809
#    macro avg       0.97      0.97      0.97      2809
# weighted avg       0.97      0.97      0.97      2809

# %%
cm = confusion_matrix(Y_test, y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=["Covid","Normal"])
disp.plot()
plt.show()
