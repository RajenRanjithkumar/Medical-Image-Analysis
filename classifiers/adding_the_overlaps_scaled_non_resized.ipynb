# %%
#mask
import json
import cv2
import os
import pandas as pd 
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
import keras
from keras.preprocessing import image
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers, models

from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical

from keras.layers import Input
from keras.models import Model
from keras.layers import concatenate
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten 
from keras.layers import Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import to_categorical
import xml.etree.ElementTree as ET
from tensorflow.keras.callbacks import TensorBoard

from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import time
model_name = "non_resized_Conv1D_8_inputs_scaled"
NAME = model_name+"-{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir = 'logs/{}'.format(NAME))

# %%
CATEGORIES = ["covid", "normal"]
DATADIR = "D:/Project2022/res/split_dataset/scaled_resized/train"

# %%
for categoty in CATEGORIES:
    path = os.path.join(DATADIR, categoty)  # path to Covid or Nprmal
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        #img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
        plt.imshow(img_array, cmap="gray")
        plt.show()

        mid_h = int(img_array.shape[1]/4)
        mid_v = int(img_array.shape[0]/4)


        #left half
        LH_img = img_array[: , :int(img_array.shape[1]/2)]
        plt.imshow(LH_img, cmap="gray")
        plt.show()
        
        #Right half
        RH_img = img_array[: , int(img_array.shape[1]/2):]
        plt.imshow(RH_img, cmap="gray")
        plt.show()

        # mid vertical
        mid_ver = img_array[:, int((img_array.shape[1]/2)-mid_h):int((img_array.shape[1]/2)+mid_h)]
        plt.imshow(mid_ver, cmap="gray")
        plt.show()

        #top half
        TC_img = img_array[:int(img_array.shape[0]/2) , :]
        plt.imshow(TC_img, cmap="gray")
        plt.show()

        #bottom half
        BC_img =  img_array[int(img_array.shape[0]/2): , :]
        plt.imshow(BC_img, cmap="gray")
        plt.show()

        #mid horizontal
        mid_hor = img_array[int((img_array.shape[0]/2)-mid_v):int((img_array.shape[0]/2)+mid_v), :]
        plt.imshow(mid_hor, cmap="gray")
        plt.show()


        break
    break

# %%
def pre_process_dataset(dataset_path):

    df_data = pd.DataFrame()
    #raw_image = []
    row_sum = []
    coloumn_sum = []
    
    LH_sum = []
    Row_mid = []
    RH_sum = []
    
    TC_sum = []
    Col_mid = []
    BC_sum =[]

    label = []

    for categoty in CATEGORIES:
        path = os.path.join(dataset_path, categoty)  
        
        class_num = CATEGORIES.index(categoty)
        

        print("Loading dataset: class",categoty)
        for img in tqdm(os.listdir(path)):

            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                #img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
                row = img_array.sum(axis=0)
                coloumn = img_array.sum(axis=1)
                mid_h = int(img_array.shape[1]/4)
                mid_v = int(img_array.shape[0]/4)

                #Global inputs
                row_sum.append(row)
                coloumn_sum.append(coloumn)

                #row inputs
                LH_img = img_array[: , :int(img_array.shape[1]/2)]
                LH_sum.append(LH_img.sum(1))

                row_mid = img_array[:, int((img_array.shape[1]/2)-mid_h):int((img_array.shape[1]/2)+mid_h)]
                Row_mid.append(row_mid.sum(1))

                RH_img = img_array[: , int(img_array.shape[1]/2):]
                RH_sum.append(RH_img.sum(1))

                #coloumn inputs
                TC_img = img_array[:int(img_array.shape[0]/2) , :]
                TC_sum.append(TC_img.sum(0))

                col_mid = img_array[int((img_array.shape[0]/2)-mid_v):int((img_array.shape[0]/2)+mid_v), :]
                Col_mid.append(col_mid.sum(0)) 

                BC_img = img_array[int(img_array.shape[0]/2): , :]
                BC_sum.append(BC_img.sum(0))

                
                #raw_image.append(img_array)             

                label.append(class_num)
                
            except Exception as e:
                pass
    
    #df_data["raw data"] = raw_image
    df_data["row_sum"] = row_sum
    df_data["coloumn_sum"] = coloumn_sum

    df_data["LH_sum"] = LH_sum
    df_data["Row_mid"] = Row_mid
    df_data["RH_sum"] = RH_sum


    df_data["TC_sum"] = TC_sum
    df_data["Col_mid"] = Col_mid
    df_data["BC_sum"] = BC_sum

    df_data["label"] = label
    

    return df_data

# %%
dataset_df = pre_process_dataset(DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/5719 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/5514 [00:00<?, ?it/s]

# %%
dataset_df.head(-1)
# Out:
#                                                  row_sum  \
# 0      [26099, 25676, 25188, 24716, 24349, 24010, 236...
# 1      [73474, 73717, 73998, 74214, 74359, 74470, 746...
# 2      [76642, 76817, 77127, 77520, 77719, 77849, 779...
# 3      [53413, 53410, 53496, 53710, 53849, 54026, 542...
# 4      [48830, 49179, 49634, 50119, 50160, 50264, 503...
# ...                                                  ...
# 11227  [77073, 77674, 78399, 79040, 79015, 78901, 787...
# 11228  [68286, 68935, 69634, 70079, 69976, 69901, 699...
# 11229  [77895, 77209, 76363, 75413, 74768, 74269, 737...
# 11230  [68831, 68766, 68644, 68482, 68493, 68598, 688...
# 11231  [72012, 72076, 72155, 72206, 72260, 72365, 725...
#
#                                              coloumn_sum  \
# 0      [15188, 15165, 15034, 14946, 14851, 14789, 147...
# 1      [78050, 78059, 78168, 78281, 78422, 78550, 786...
# 2      [75406, 75193, 74807, 74522, 74382, 74313, 743...
# 3      [49764, 49674, 49607, 49614, 49681, 49754, 498...
# 4      [40579, 40502, 40367, 40241, 40157, 40100, 400...
# ...                                                  ...
# 11227  [69335, 69057, 68479, 67895, 67302, 66655, 659...
# 11228  [60614, 60424, 60035, 59813, 59764, 59777, 598...
# 11229  [65379, 64215, 61859, 59863, 58356, 57253, 566...
# 11230  [76030, 76013, 76063, 76113, 76181, 76248, 763...
# 11231  [39739, 39940, 40313, 40945, 41858, 42883, 440...
#
#                                                   LH_sum  \
# 0      [26099, 25676, 25188, 24716, 24349, 24010, 236...
# 1      [73474, 73717, 73998, 74214, 74359, 74470, 746...
# 2      [76642, 76817, 77127, 77520, 77719, 77849, 779...
# 3      [53413, 53410, 53496, 53710, 53849, 54026, 542...
# 4      [48830, 49179, 49634, 50119, 50160, 50264, 503...
# ...                                                  ...
# 11227  [77073, 77674, 78399, 79040, 79015, 78901, 787...
# 11228  [68286, 68935, 69634, 70079, 69976, 69901, 699...
# 11229  [77895, 77209, 76363, 75413, 74768, 74269, 737...
# 11230  [68831, 68766, 68644, 68482, 68493, 68598, 688...
# 11231  [72012, 72076, 72155, 72206, 72260, 72365, 725...
#
#                                                  Row_mid  \
# 0      [17257, 17308, 17206, 16999, 16791, 16593, 164...
# 1      [77740, 77757, 77889, 77900, 77824, 77769, 776...
# 2      [57051, 56886, 56925, 57015, 56670, 56043, 552...
# 3      [16925, 16914, 16893, 16670, 16451, 16281, 162...
# 4      [24655, 24666, 24556, 24521, 24443, 24219, 237...
# ...                                                  ...
# 11227  [50968, 51052, 51157, 51223, 51262, 51273, 511...
# 11228  [59468, 59371, 59349, 59337, 59307, 59343, 594...
# 11229  [45475, 46049, 46538, 46848, 47072, 47252, 473...
# 11230  [65699, 65613, 65534, 65435, 65288, 65150, 650...
# 11231  [51712, 51868, 52117, 52330, 52463, 52565, 525...
#
#                                                   RH_sum  \
# 0      [55047, 55336, 55679, 55849, 55961, 55943, 558...
# 1      [85422, 85439, 85490, 85738, 86159, 86663, 871...
# 2      [79862, 79614, 79340, 79161, 79080, 78984, 790...
# 3      [56771, 56859, 57095, 57166, 57177, 57220, 575...
# 4      [60037, 60186, 60265, 60663, 61459, 62813, 645...
# ...                                                  ...
# 11227  [79387, 78864, 78314, 77927, 77636, 77320, 770...
# 11228  [74329, 74503, 74887, 75443, 76056, 76493, 766...
# 11229  [74458, 74633, 74934, 75155, 75397, 75540, 756...
# 11230  [78803, 78765, 78653, 78493, 78316, 78102, 779...
# 11231  [74675, 74960, 75309, 75533, 75714, 75841, 760...
#
#                                                   TC_sum  \
# 0      [15188, 15165, 15034, 14946, 14851, 14789, 147...
# 1      [78050, 78059, 78168, 78281, 78422, 78550, 786...
# 2      [75406, 75193, 74807, 74522, 74382, 74313, 743...
# 3      [49764, 49674, 49607, 49614, 49681, 49754, 498...
# 4      [40579, 40502, 40367, 40241, 40157, 40100, 400...
# ...                                                  ...
# 11227  [69335, 69057, 68479, 67895, 67302, 66655, 659...
# 11228  [60614, 60424, 60035, 59813, 59764, 59777, 598...
# 11229  [65379, 64215, 61859, 59863, 58356, 57253, 566...
# 11230  [76030, 76013, 76063, 76113, 76181, 76248, 763...
# 11231  [39739, 39940, 40313, 40945, 41858, 42883, 440...
#
#                                                  Col_mid  \
# 0      [21553, 21452, 21389, 21353, 21375, 21402, 214...
# 1      [80761, 80846, 80960, 81062, 81138, 81227, 812...
# 2      [67445, 67451, 67515, 67602, 67720, 67816, 678...
# 3      [29631, 29718, 29789, 29884, 29953, 30033, 301...
# 4      [47174, 46966, 46706, 46388, 46022, 45673, 454...
# ...                                                  ...
# 11227  [58016, 58131, 58269, 58323, 58281, 58228, 581...
# 11228  [66958, 66770, 66528, 66328, 66130, 65942, 658...
# 11229  [53799, 53779, 53802, 53828, 53904, 53993, 541...
# 11230  [77646, 77611, 77659, 77713, 77779, 77813, 778...
# 11231  [56733, 56699, 56601, 56525, 56458, 56439, 564...
#
#                                                   BC_sum  label
# 0      [21073, 20901, 20722, 20493, 20225, 19897, 194...      0
# 1      [80046, 79912, 79781, 79654, 79494, 79366, 792...      0
# 2      [66811, 66740, 66607, 66396, 66054, 65654, 651...      0
# 3      [28171, 28202, 28304, 28359, 28393, 28397, 283...      0
# 4      [17165, 16952, 16759, 16618, 16559, 16619, 168...      0
# ...                                                  ...    ...
# 11227  [56939, 56877, 56834, 56809, 56732, 56732, 567...      1
# 11228  [46095, 46168, 46242, 46313, 46377, 46450, 465...      1
# 11229  [51190, 50941, 50566, 50164, 49703, 49345, 491...      1
# 11230  [72727, 72652, 72607, 72591, 72664, 72721, 727...      1
# 11231  [53085, 53073, 53085, 53114, 53119, 53148, 531...      1
#
# [11232 rows x 9 columns]

# %%
df_train, df_val = train_test_split(dataset_df, test_size=0.2, random_state=0)

# %%
df_train["label"].value_counts()
# Out:
# 0    4601
# 1    4385
# Name: label, dtype: int64

# %%
print("No of Training samples:",len(df_train))
print("No of Validation samples:",len(df_val))
# Out:
# No of Training samples: 8986
# No of Validation samples: 2247

# %%
df_train["Row_mid"][0].shape
# Out:
# (252,)

# %%
from sklearn import preprocessing

def process_data(dataset_df):
    
    row = dataset_df["row_sum"].values
    coloumn = dataset_df["coloumn_sum"].values

    LH = dataset_df["LH_sum"].values
    Row_mid = dataset_df["Row_mid"].values
    RH = dataset_df["RH_sum"].values


    TC = dataset_df["TC_sum"].values
    Col_mid = dataset_df["Col_mid"].values
    BC = dataset_df["BC_sum"].values

    # global
    X1 = [img.tolist() for img in row]
    X2 = [img.tolist() for img in coloumn]

    #row
    X3 = [img.tolist() for img in LH]
    X_row_mid = [img.tolist() for img in Row_mid]
    X4 = [img.tolist() for img in RH]

    #coloumn
    X5 = [img.tolist() for img in TC]
    X_col_mid = [img.tolist() for img in Col_mid]
    X6 = [img.tolist() for img in BC]


    X1 = np.array(X1)
    X2 = np.array(X2)

    X3 = np.array(X3)
    X_row_mid = np.array(X_row_mid)
    X4 = np.array(X4)


    X5 = np.array(X5)
    X_col_mid = np.array(X_col_mid)
    X6 = np.array(X6)

    #normalize the inputs
    X1 = preprocessing.normalize(X1)
    X2 = preprocessing.normalize(X2)

    X3 = preprocessing.normalize(X3)
    X_row_mid = preprocessing.normalize(X_row_mid)
    X4 = preprocessing.normalize(X4)

    X5 = preprocessing.normalize(X5)
    X_col_mid = preprocessing.normalize(X_col_mid)
    X6 = preprocessing.normalize(X6)

    #reshape the inputs
    X1 = np.expand_dims(X1, axis=-1)
    X2 = np.expand_dims(X2, axis=-1)

    X3 = np.expand_dims(X3, axis=-1)
    X_row_mid = np.expand_dims(X_row_mid, axis=-1)
    X4 = np.expand_dims(X4, axis=-1)

    X5 = np.expand_dims(X5, axis=-1)
    X_col_mid = np.expand_dims(X_col_mid, axis=-1)
    X6 = np.expand_dims(X6, axis=-1)



    y = np.array(dataset_df["label"].values)
    y = np.expand_dims(y, axis=-1)


    print("X1 shape", X1.shape)
    print("X2 shape", X2.shape)

    print("X3 shape", X3.shape)
    print("Mid rows shape", X_row_mid.shape)
    print("X4 shape", X4.shape)

    print("X5 shape", X5.shape)
    print("Mid Cols shape", X_col_mid.shape)
    print("X6 shape", X6.shape)

    print("y shape", y.shape)

    return X1, X2, X3, X_row_mid, X4, X5, X_col_mid, X6, y

# %%
print("Training samples:")
X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train, Y_train = process_data(df_train)

print("\nValidation samples:")
X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val, Y_val = process_data(df_val)
# Out:
# Training samples:
# X1 shape (8986, 367, 1)
# X2 shape (8986, 252, 1)
# X3 shape (8986, 252, 1)
# Mid rows shape (8986, 252, 1)
# X4 shape (8986, 252, 1)
# X5 shape (8986, 367, 1)
# Mid Cols shape (8986, 367, 1)
# X6 shape (8986, 367, 1)
# y shape (8986, 1)
#
# Validation samples:
# X1 shape (2247, 367, 1)
# X2 shape (2247, 252, 1)
# X3 shape (2247, 252, 1)
# Mid rows shape (2247, 252, 1)
# X4 shape (2247, 252, 1)
# X5 shape (2247, 367, 1)
# Mid Cols shape (2247, 367, 1)
# X6 shape (2247, 367, 1)
# y shape (2247, 1)

# %%
# first input model
row = Input(shape=(512,1))
conv11 = Conv1D(64, kernel_size=3, activation='relu')(row)
conv12 = Conv1D(64, kernel_size=3, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat_row = Flatten()(pool11)


# second input model
col = Input(shape=(512,1))
conv21 = Conv1D(64, kernel_size=3, activation='relu')(col)
conv22 = Conv1D(64, kernel_size=3, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat_col = Flatten()(pool21)

# merge input models
merge = concatenate([flat_row, flat_col])

hidden1 = Dense(100, activation='relu')(merge)
hidden_global = Dense(100, activation='relu')(hidden1)

#####################################################################

LH = Input(shape=(256,1))
conv31 = Conv1D(64, kernel_size=3, activation='relu')(LH)
conv32 = Conv1D(64, kernel_size=3, activation='relu')(conv31)
drop31 = Dropout(0.25)(conv32)
pool31 = MaxPooling1D(pool_size=2)(drop31)
flat3 = Flatten()(pool31)

row_mid = Input(shape=(256,1))
conv41 = Conv1D(64, kernel_size=3, activation='relu')(row_mid)
conv42 = Conv1D(64, kernel_size=3, activation='relu')(conv41)
drop41 = Dropout(0.25)(conv42)
pool41 = MaxPooling1D(pool_size=2)(drop41)
flat4 = Flatten()(pool41)

RH = Input(shape=(256,1))
conv51 = Conv1D(64, kernel_size=3, activation='relu')(RH)
conv52 = Conv1D(64, kernel_size=3, activation='relu')(conv51)
drop51 = Dropout(0.25)(conv52)
pool51 = MaxPooling1D(pool_size=2)(drop51)
flat5 = Flatten()(pool51)

# merge input models
merge_rows = concatenate([flat3, flat4, flat5])
hidden3 = Dense(100, activation='relu')(merge_rows)
hidden_rows = Dense(100, activation='relu')(hidden3)




TC = Input(shape=(256,1))
conv61 = Conv1D(64, kernel_size=3, activation='relu')(TC)
conv62 = Conv1D(64, kernel_size=3, activation='relu')(conv61)
drop61 = Dropout(0.25)(conv62)
pool61 = MaxPooling1D(pool_size=2)(drop61)
flat6 = Flatten()(pool61)

col_mid = Input(shape=(256,1))
conv71 = Conv1D(64, kernel_size=3, activation='relu')(col_mid)
conv72 = Conv1D(64, kernel_size=3, activation='relu')(conv71)
drop71 = Dropout(0.25)(conv72)
pool71 = MaxPooling1D(pool_size=2)(drop71)
flat7 = Flatten()(pool71)

BC = Input(shape=(256,1))
conv81 = Conv1D(64, kernel_size=3, activation='relu')(BC)
conv82 = Conv1D(64, kernel_size=3, activation='relu')(conv81)
drop81 = Dropout(0.25)(conv82)
pool81 = MaxPooling1D(pool_size=2)(drop81)
flat8 = Flatten()(pool81)



merge_cols = concatenate([flat6, flat7, flat8])
hidden5 = Dense(100, activation='relu')(merge_cols)
hidden_cols = Dense(100, activation='relu')(hidden5)

# merge input models
merge_row_col = concatenate([hidden_rows, hidden_cols])
merge_all = concatenate([hidden_global, merge_row_col])

output = Dense(1, activation='sigmoid')(merge_all)
model = Model(inputs=[row, col, LH, row_mid, RH, TC, col_mid, BC], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_4 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_5 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_6 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_7 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_8 (InputLayer)           [(None, 256, 1)]     0           []
#
#  input_1 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_2 (InputLayer)           [(None, 512, 1)]     0           []
#
#  conv1d_4 (Conv1D)              (None, 254, 64)      256         ['input_3[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 254, 64)      256         ['input_4[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 254, 64)      256         ['input_5[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 254, 64)      256         ['input_6[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 254, 64)      256         ['input_7[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 254, 64)      256         ['input_8[0][0]']
#
#  conv1d (Conv1D)                (None, 510, 64)      256         ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 510, 64)      256         ['input_2[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 252, 64)      12352       ['conv1d_4[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 252, 64)      12352       ['conv1d_6[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 252, 64)      12352       ['conv1d_8[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 252, 64)      12352       ['conv1d_10[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 252, 64)      12352       ['conv1d_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 252, 64)      12352       ['conv1d_14[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 508, 64)      12352       ['conv1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 508, 64)      12352       ['conv1d_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 252, 64)      0           ['conv1d_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 252, 64)      0           ['conv1d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 252, 64)      0           ['conv1d_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 252, 64)      0           ['conv1d_11[0][0]']
#
#  dropout_6 (Dropout)            (None, 252, 64)      0           ['conv1d_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 252, 64)      0           ['conv1d_15[0][0]']
#
#  dropout (Dropout)              (None, 508, 64)      0           ['conv1d_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 508, 64)      0           ['conv1d_3[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_3[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_5[0][0]']
#
#  max_pooling1d_6 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_6[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 126, 64)     0           ['dropout_7[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 254, 64)      0           ['dropout[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 254, 64)     0           ['dropout_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 8064)         0           ['max_pooling1d_2[0][0]']
#
#  flatten_3 (Flatten)            (None, 8064)         0           ['max_pooling1d_3[0][0]']
#
#  flatten_4 (Flatten)            (None, 8064)         0           ['max_pooling1d_4[0][0]']
#
#  flatten_5 (Flatten)            (None, 8064)         0           ['max_pooling1d_5[0][0]']
#
#  flatten_6 (Flatten)            (None, 8064)         0           ['max_pooling1d_6[0][0]']
#
#  flatten_7 (Flatten)            (None, 8064)         0           ['max_pooling1d_7[0][0]']
#
#  flatten (Flatten)              (None, 16256)        0           ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)            (None, 16256)        0           ['max_pooling1d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 24192)        0           ['flatten_2[0][0]',
#                                                                   'flatten_3[0][0]',
#                                                                   'flatten_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 24192)        0           ['flatten_5[0][0]',
#                                                                   'flatten_6[0][0]',
#                                                                   'flatten_7[0][0]']
#
#  concatenate (Concatenate)      (None, 32512)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 100)          2419300     ['concatenate_1[0][0]']
#
#  dense_4 (Dense)                (None, 100)          2419300     ['concatenate_2[0][0]']
#
#  dense (Dense)                  (None, 100)          3251300     ['concatenate[0][0]']
#
#  dense_3 (Dense)                (None, 100)          10100       ['dense_2[0][0]']
#
#  dense_5 (Dense)                (None, 100)          10100       ['dense_4[0][0]']
#
#  dense_1 (Dense)                (None, 100)          10100       ['dense[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 200)          0           ['dense_3[0][0]',
#                                                                   'dense_5[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 300)          0           ['dense_1[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  dense_6 (Dense)                (None, 1)            301         ['concatenate_4[0][0]']
#
# ==================================================================================================
# Total params: 8,221,365
# Trainable params: 8,221,365
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# first input model
visible1 = Input(shape=(512,1))
conv11 = Conv1D(64, kernel_size=3, activation='relu')(visible1)

conv12 = Conv1D(64, kernel_size=3, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat1 = Flatten()(pool11)


# second input model

visible2 = Input(shape=(512,1))
conv21 = Conv1D(64, kernel_size=3, activation='relu')(visible2)
conv22 = Conv1D(64, kernel_size=3, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat2 = Flatten()(pool21)


# merge input models
merge = concatenate([flat1, flat2])
# interpretation model
hidden1 = Dense(100, activation='relu')(merge)
hidden2 = Dense(100, activation='relu')(hidden1)

output = Dense(1, activation='sigmoid')(hidden2)
model = Model(inputs=[visible1, visible2], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())

# %% [markdown]
# ## Modified

# %%
# first input model
row = Input(shape=(367,1))
#kernel size 5
conv11 = Conv1D(64, kernel_size=5, activation='relu')(row)
#16
conv12 = Conv1D(32, kernel_size=5, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat_row = Flatten()(pool11)


# second input model
col = Input(shape=(252,1))
conv21 = Conv1D(64, kernel_size=5, activation='relu')(col)
conv22 = Conv1D(32, kernel_size=5, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat_col = Flatten()(pool21)

# merge input models
#merge = concatenate([flat_row, flat_col])

#hidden1 = Dense(100, activation='relu')(merge)
#hidden_global = Dense(100, activation='relu')(hidden1)

#####################################################################

LH = Input(shape=(252,1))
conv31 = Conv1D(64, kernel_size=5, activation='relu')(LH)
conv32 = Conv1D(32, kernel_size=5, activation='relu')(conv31)
drop31 = Dropout(0.25)(conv32)
pool31 = MaxPooling1D(pool_size=2)(drop31)
flat3 = Flatten()(pool31)

row_mid = Input(shape=(252,1))
conv41 = Conv1D(64, kernel_size=5, activation='relu')(row_mid)
conv42 = Conv1D(32, kernel_size=5, activation='relu')(conv41)
drop41 = Dropout(0.25)(conv42)
pool41 = MaxPooling1D(pool_size=2)(drop41)
flat4 = Flatten()(pool41)

RH = Input(shape=(252,1))
conv51 = Conv1D(64, kernel_size=5, activation='relu')(RH)
conv52 = Conv1D(32, kernel_size=5, activation='relu')(conv51)
drop51 = Dropout(0.25)(conv52)
pool51 = MaxPooling1D(pool_size=2)(drop51)
flat5 = Flatten()(pool51)


TC = Input(shape=(367,1))
conv61 = Conv1D(64, kernel_size=5, activation='relu')(TC)
conv62 = Conv1D(32, kernel_size=5, activation='relu')(conv61)
drop61 = Dropout(0.25)(conv62)
pool61 = MaxPooling1D(pool_size=2)(drop61)
flat6 = Flatten()(pool61)

col_mid = Input(shape=(367,1))
conv71 = Conv1D(64, kernel_size=5, activation='relu')(col_mid)
conv72 = Conv1D(32, kernel_size=5, activation='relu')(conv71)
drop71 = Dropout(0.25)(conv72)
pool71 = MaxPooling1D(pool_size=2)(drop71)
flat7 = Flatten()(pool71)

BC = Input(shape=(367,1))
conv81 = Conv1D(64, kernel_size=5, activation='relu')(BC)
conv82 = Conv1D(32, kernel_size=5, activation='relu')(conv81)
drop81 = Dropout(0.25)(conv82)
pool81 = MaxPooling1D(pool_size=2)(drop81)
flat8 = Flatten()(pool81)



merge_all = concatenate([flat_row, flat_col, flat3, flat4, flat5, flat6, flat7, flat8])
hidden_all_1 = Dense(128, activation='relu')(merge_all)
hidden_all_2 = Dense(64, activation='relu')(hidden_all_1)

output = Dense(1, activation='sigmoid')(hidden_all_2)
model = Model(inputs=[row, col, LH, row_mid, RH, TC, col_mid, BC], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 367, 1)]     0           []
#
#  input_2 (InputLayer)           [(None, 252, 1)]     0           []
#
#  input_3 (InputLayer)           [(None, 252, 1)]     0           []
#
#  input_4 (InputLayer)           [(None, 252, 1)]     0           []
#
#  input_5 (InputLayer)           [(None, 252, 1)]     0           []
#
#  input_6 (InputLayer)           [(None, 367, 1)]     0           []
#
#  input_7 (InputLayer)           [(None, 367, 1)]     0           []
#
#  input_8 (InputLayer)           [(None, 367, 1)]     0           []
#
#  conv1d (Conv1D)                (None, 363, 64)      384         ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 248, 64)      384         ['input_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 248, 64)      384         ['input_3[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 248, 64)      384         ['input_4[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 248, 64)      384         ['input_5[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 363, 64)      384         ['input_6[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 363, 64)      384         ['input_7[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 363, 64)      384         ['input_8[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 359, 32)      10272       ['conv1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 244, 32)      10272       ['conv1d_2[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 244, 32)      10272       ['conv1d_4[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 244, 32)      10272       ['conv1d_6[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 244, 32)      10272       ['conv1d_8[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 359, 32)      10272       ['conv1d_10[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 359, 32)      10272       ['conv1d_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 359, 32)      10272       ['conv1d_14[0][0]']
#
#  dropout (Dropout)              (None, 359, 32)      0           ['conv1d_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 244, 32)      0           ['conv1d_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 244, 32)      0           ['conv1d_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 244, 32)      0           ['conv1d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 244, 32)      0           ['conv1d_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 359, 32)      0           ['conv1d_11[0][0]']
#
#  dropout_6 (Dropout)            (None, 359, 32)      0           ['conv1d_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 359, 32)      0           ['conv1d_15[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 179, 32)      0           ['dropout[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 122, 32)     0           ['dropout_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 122, 32)     0           ['dropout_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 122, 32)     0           ['dropout_3[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 122, 32)     0           ['dropout_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 179, 32)     0           ['dropout_5[0][0]']
#
#  max_pooling1d_6 (MaxPooling1D)  (None, 179, 32)     0           ['dropout_6[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 179, 32)     0           ['dropout_7[0][0]']
#
#  flatten (Flatten)              (None, 5728)         0           ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)            (None, 3904)         0           ['max_pooling1d_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 3904)         0           ['max_pooling1d_2[0][0]']
#
#  flatten_3 (Flatten)            (None, 3904)         0           ['max_pooling1d_3[0][0]']
#
#  flatten_4 (Flatten)            (None, 3904)         0           ['max_pooling1d_4[0][0]']
#
#  flatten_5 (Flatten)            (None, 5728)         0           ['max_pooling1d_5[0][0]']
#
#  flatten_6 (Flatten)            (None, 5728)         0           ['max_pooling1d_6[0][0]']
#
#  flatten_7 (Flatten)            (None, 5728)         0           ['max_pooling1d_7[0][0]']
#
#  concatenate (Concatenate)      (None, 38528)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]',
#                                                                   'flatten_2[0][0]',
#                                                                   'flatten_3[0][0]',
#                                                                   'flatten_4[0][0]',
#                                                                   'flatten_5[0][0]',
#                                                                   'flatten_6[0][0]',
#                                                                   'flatten_7[0][0]']
#
#  dense (Dense)                  (None, 128)          4931712     ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            65          ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 5,025,281
# Trainable params: 5,025,281
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
BATCH_SIZE = 128
EPOCHS = 500
history = model.fit(
    [X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train],
    Y_train,
    BATCH_SIZE,
    EPOCHS,
    validation_data=([X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val], Y_val),
    callbacks=[tensorboard])

model.save("D:/Project2022/models/"+model_name+".h5")
# Out:
# Epoch 1/500
# 71/71 [==============================] - 16s 68ms/step - loss: 0.5916 - accuracy: 0.6957 - val_loss: 0.5059 - val_accuracy: 0.7641
# Epoch 2/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.4403 - accuracy: 0.7962 - val_loss: 0.4248 - val_accuracy: 0.8149
# Epoch 3/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.4000 - accuracy: 0.8231 - val_loss: 0.3717 - val_accuracy: 0.8500
# Epoch 4/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.3706 - accuracy: 0.8429 - val_loss: 0.3508 - val_accuracy: 0.8660
# Epoch 5/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.3582 - accuracy: 0.8479 - val_loss: 0.3410 - val_accuracy: 0.8585
# Epoch 6/500
# 71/71 [==============================] - 4s 49ms/step - loss: 0.3442 - accuracy: 0.8584 - val_loss: 0.3251 - val_accuracy: 0.8683
# Epoch 7/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.3259 - accuracy: 0.8700 - val_loss: 0.3195 - val_accuracy: 0.8709
# Epoch 8/500
# 71/71 [==============================] - 3s 49ms/step - loss: 0.3131 - accuracy: 0.8690 - val_loss: 0.3140 - val_accuracy: 0.8816
# Epoch 9/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2989 - accuracy: 0.8780 - val_loss: 0.3079 - val_accuracy: 0.8754
# Epoch 10/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.3033 - accuracy: 0.8761 - val_loss: 0.3077 - val_accuracy: 0.8767
# Epoch 11/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2822 - accuracy: 0.8855 - val_loss: 0.3352 - val_accuracy: 0.8496
# Epoch 12/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2751 - accuracy: 0.8870 - val_loss: 0.2852 - val_accuracy: 0.8834
# Epoch 13/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2805 - accuracy: 0.8833 - val_loss: 0.2896 - val_accuracy: 0.8892
# Epoch 14/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2628 - accuracy: 0.8919 - val_loss: 0.2627 - val_accuracy: 0.9008
# Epoch 15/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2697 - accuracy: 0.8878 - val_loss: 0.2817 - val_accuracy: 0.8936
# Epoch 16/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2487 - accuracy: 0.8996 - val_loss: 0.2809 - val_accuracy: 0.8976
# Epoch 17/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2359 - accuracy: 0.9037 - val_loss: 0.2483 - val_accuracy: 0.9012
# Epoch 18/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2369 - accuracy: 0.9056 - val_loss: 0.2987 - val_accuracy: 0.8785
# Epoch 19/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2254 - accuracy: 0.9091 - val_loss: 0.2342 - val_accuracy: 0.9132
# Epoch 20/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2207 - accuracy: 0.9111 - val_loss: 0.2583 - val_accuracy: 0.8976
# Epoch 21/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2047 - accuracy: 0.9211 - val_loss: 0.2421 - val_accuracy: 0.8990
# Epoch 22/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.2010 - accuracy: 0.9183 - val_loss: 0.2261 - val_accuracy: 0.9083
# Epoch 23/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1999 - accuracy: 0.9190 - val_loss: 0.2339 - val_accuracy: 0.9061
# Epoch 24/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1873 - accuracy: 0.9244 - val_loss: 0.3136 - val_accuracy: 0.8741
# Epoch 25/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1762 - accuracy: 0.9302 - val_loss: 0.2623 - val_accuracy: 0.8936
# Epoch 26/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.1733 - accuracy: 0.9274 - val_loss: 0.2477 - val_accuracy: 0.9052
# Epoch 27/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1767 - accuracy: 0.9300 - val_loss: 0.2186 - val_accuracy: 0.9159
# Epoch 28/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1648 - accuracy: 0.9342 - val_loss: 0.2056 - val_accuracy: 0.9186
# Epoch 29/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1540 - accuracy: 0.9380 - val_loss: 0.2303 - val_accuracy: 0.9052
# Epoch 30/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1527 - accuracy: 0.9371 - val_loss: 0.2123 - val_accuracy: 0.9168
# Epoch 31/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1435 - accuracy: 0.9427 - val_loss: 0.1989 - val_accuracy: 0.9226
# Epoch 32/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1464 - accuracy: 0.9411 - val_loss: 0.2376 - val_accuracy: 0.9137
# Epoch 33/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1435 - accuracy: 0.9431 - val_loss: 0.2137 - val_accuracy: 0.9137
# Epoch 34/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1432 - accuracy: 0.9421 - val_loss: 0.2062 - val_accuracy: 0.9252
# Epoch 35/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1256 - accuracy: 0.9499 - val_loss: 0.2217 - val_accuracy: 0.9141
# Epoch 36/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.1316 - accuracy: 0.9466 - val_loss: 0.1966 - val_accuracy: 0.9279
# Epoch 37/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1342 - accuracy: 0.9464 - val_loss: 0.1888 - val_accuracy: 0.9306
# Epoch 38/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1175 - accuracy: 0.9530 - val_loss: 0.2199 - val_accuracy: 0.9212
# Epoch 39/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.1123 - accuracy: 0.9563 - val_loss: 0.1935 - val_accuracy: 0.9310
# Epoch 40/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1211 - accuracy: 0.9517 - val_loss: 0.2005 - val_accuracy: 0.9288
# Epoch 41/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.1034 - accuracy: 0.9593 - val_loss: 0.1924 - val_accuracy: 0.9292
# Epoch 42/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.0945 - accuracy: 0.9635 - val_loss: 0.2089 - val_accuracy: 0.9288
# Epoch 43/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1015 - accuracy: 0.9588 - val_loss: 0.1973 - val_accuracy: 0.9297
# Epoch 44/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.0970 - accuracy: 0.9607 - val_loss: 0.2059 - val_accuracy: 0.9275
# Epoch 45/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1048 - accuracy: 0.9569 - val_loss: 0.2763 - val_accuracy: 0.9092
# Epoch 46/500
# 71/71 [==============================] - 4s 50ms/step - loss: 0.1305 - accuracy: 0.9497 - val_loss: 0.1992 - val_accuracy: 0.9315
# Epoch 47/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0844 - accuracy: 0.9681 - val_loss: 0.1938 - val_accuracy: 0.9310
# Epoch 48/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0770 - accuracy: 0.9693 - val_loss: 0.1886 - val_accuracy: 0.9359
# Epoch 49/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0827 - accuracy: 0.9671 - val_loss: 0.1664 - val_accuracy: 0.9426
# Epoch 50/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0700 - accuracy: 0.9725 - val_loss: 0.2135 - val_accuracy: 0.9319
# Epoch 51/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0809 - accuracy: 0.9684 - val_loss: 0.2424 - val_accuracy: 0.9057
# Epoch 52/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0773 - accuracy: 0.9688 - val_loss: 0.1678 - val_accuracy: 0.9417
# Epoch 53/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0748 - accuracy: 0.9702 - val_loss: 0.1968 - val_accuracy: 0.9377
# Epoch 54/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0638 - accuracy: 0.9757 - val_loss: 0.2423 - val_accuracy: 0.9346
# Epoch 55/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0981 - accuracy: 0.9625 - val_loss: 0.2261 - val_accuracy: 0.9350
# Epoch 56/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0667 - accuracy: 0.9753 - val_loss: 0.1836 - val_accuracy: 0.9390
# Epoch 57/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0653 - accuracy: 0.9748 - val_loss: 0.2056 - val_accuracy: 0.9395
# Epoch 58/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0589 - accuracy: 0.9763 - val_loss: 0.1992 - val_accuracy: 0.9310
# Epoch 59/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0626 - accuracy: 0.9747 - val_loss: 0.2021 - val_accuracy: 0.9310
# Epoch 60/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0698 - accuracy: 0.9734 - val_loss: 0.2164 - val_accuracy: 0.9346
# Epoch 61/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0804 - accuracy: 0.9690 - val_loss: 0.1754 - val_accuracy: 0.9430
# Epoch 62/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0465 - accuracy: 0.9829 - val_loss: 0.1885 - val_accuracy: 0.9395
# Epoch 63/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0442 - accuracy: 0.9852 - val_loss: 0.1680 - val_accuracy: 0.9479
# Epoch 64/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0414 - accuracy: 0.9843 - val_loss: 0.1971 - val_accuracy: 0.9386
# Epoch 65/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0428 - accuracy: 0.9850 - val_loss: 0.2522 - val_accuracy: 0.9310
# Epoch 66/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0420 - accuracy: 0.9838 - val_loss: 0.1875 - val_accuracy: 0.9435
# Epoch 67/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0599 - accuracy: 0.9767 - val_loss: 0.2607 - val_accuracy: 0.9110
# Epoch 68/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0635 - accuracy: 0.9755 - val_loss: 0.1981 - val_accuracy: 0.9381
# Epoch 69/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0563 - accuracy: 0.9777 - val_loss: 0.1951 - val_accuracy: 0.9390
# Epoch 70/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0403 - accuracy: 0.9851 - val_loss: 0.2018 - val_accuracy: 0.9470
# Epoch 71/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0418 - accuracy: 0.9836 - val_loss: 0.2202 - val_accuracy: 0.9430
# Epoch 72/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.2081 - val_accuracy: 0.9439
# Epoch 73/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0372 - accuracy: 0.9851 - val_loss: 0.1980 - val_accuracy: 0.9430
# Epoch 74/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0328 - accuracy: 0.9884 - val_loss: 0.2341 - val_accuracy: 0.9404
# Epoch 75/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0253 - accuracy: 0.9911 - val_loss: 0.2056 - val_accuracy: 0.9488
# Epoch 76/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0509 - accuracy: 0.9820 - val_loss: 0.2289 - val_accuracy: 0.9435
# Epoch 77/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0374 - accuracy: 0.9874 - val_loss: 0.2453 - val_accuracy: 0.9310
# Epoch 78/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0642 - accuracy: 0.9763 - val_loss: 0.2174 - val_accuracy: 0.9421
# Epoch 79/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0767 - accuracy: 0.9722 - val_loss: 0.2223 - val_accuracy: 0.9381
# Epoch 80/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0316 - accuracy: 0.9889 - val_loss: 0.1944 - val_accuracy: 0.9479
# Epoch 81/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.2042 - val_accuracy: 0.9510
# Epoch 82/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.2202 - val_accuracy: 0.9448
# Epoch 83/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0232 - accuracy: 0.9918 - val_loss: 0.2053 - val_accuracy: 0.9510
# Epoch 84/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0203 - accuracy: 0.9931 - val_loss: 0.1859 - val_accuracy: 0.9510
# Epoch 85/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0134 - accuracy: 0.9963 - val_loss: 0.1925 - val_accuracy: 0.9546
# Epoch 86/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.1862 - val_accuracy: 0.9506
# Epoch 87/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.2118 - val_accuracy: 0.9479
# Epoch 88/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0234 - accuracy: 0.9914 - val_loss: 0.2603 - val_accuracy: 0.9368
# Epoch 89/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0376 - accuracy: 0.9858 - val_loss: 0.2439 - val_accuracy: 0.9413
# Epoch 90/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 0.2166 - val_accuracy: 0.9497
# Epoch 91/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.2471 - val_accuracy: 0.9413
# Epoch 92/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0621 - accuracy: 0.9775 - val_loss: 0.2422 - val_accuracy: 0.9350
# Epoch 93/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0269 - accuracy: 0.9897 - val_loss: 0.2148 - val_accuracy: 0.9493
# Epoch 94/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 0.1937 - val_accuracy: 0.9537
# Epoch 95/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.3356 - val_accuracy: 0.9297
# Epoch 96/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0319 - accuracy: 0.9872 - val_loss: 0.2593 - val_accuracy: 0.9430
# Epoch 97/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0324 - accuracy: 0.9884 - val_loss: 0.2550 - val_accuracy: 0.9408
# Epoch 98/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0491 - accuracy: 0.9816 - val_loss: 0.2288 - val_accuracy: 0.9421
# Epoch 99/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0183 - accuracy: 0.9943 - val_loss: 0.2365 - val_accuracy: 0.9484
# Epoch 100/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.2345 - val_accuracy: 0.9466
# Epoch 101/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.2427 - val_accuracy: 0.9435
# Epoch 102/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0685 - accuracy: 0.9784 - val_loss: 0.1913 - val_accuracy: 0.9524
# Epoch 103/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.2663 - val_accuracy: 0.9395
# Epoch 104/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0144 - accuracy: 0.9944 - val_loss: 0.2012 - val_accuracy: 0.9537
# Epoch 105/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.2059 - val_accuracy: 0.9537
# Epoch 106/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.2040 - val_accuracy: 0.9542
# Epoch 107/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0043 - accuracy: 0.9996 - val_loss: 0.1988 - val_accuracy: 0.9564
# Epoch 108/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.2152 - val_accuracy: 0.9524
# Epoch 109/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.2306 - val_accuracy: 0.9528
# Epoch 110/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.2306 - val_accuracy: 0.9542
# Epoch 111/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.2250 - val_accuracy: 0.9542
# Epoch 112/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0395 - accuracy: 0.9854 - val_loss: 0.3101 - val_accuracy: 0.9377
# Epoch 113/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0818 - accuracy: 0.9715 - val_loss: 0.3674 - val_accuracy: 0.9257
# Epoch 114/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0435 - accuracy: 0.9844 - val_loss: 0.1968 - val_accuracy: 0.9510
# Epoch 115/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.1893 - val_accuracy: 0.9546
# Epoch 116/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.1973 - val_accuracy: 0.9533
# Epoch 117/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.2094 - val_accuracy: 0.9555
# Epoch 118/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9542
# Epoch 119/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.2058 - val_accuracy: 0.9582
# Epoch 120/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.2119 - val_accuracy: 0.9555
# Epoch 121/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.2220 - val_accuracy: 0.9555
# Epoch 122/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.2835 - val_accuracy: 0.9488
# Epoch 123/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.2412 - val_accuracy: 0.9493
# Epoch 124/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.2411 - val_accuracy: 0.9537
# Epoch 125/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.2244 - val_accuracy: 0.9573
# Epoch 126/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0141 - accuracy: 0.9942 - val_loss: 0.2149 - val_accuracy: 0.9470
# Epoch 127/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0588 - accuracy: 0.9817 - val_loss: 0.3128 - val_accuracy: 0.9306
# Epoch 128/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0649 - accuracy: 0.9776 - val_loss: 0.2614 - val_accuracy: 0.9435
# Epoch 129/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0384 - accuracy: 0.9872 - val_loss: 0.2248 - val_accuracy: 0.9444
# Epoch 130/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0827 - accuracy: 0.9734 - val_loss: 0.2624 - val_accuracy: 0.9377
# Epoch 131/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.1822 - val_accuracy: 0.9542
# Epoch 132/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0049 - accuracy: 0.9996 - val_loss: 0.1764 - val_accuracy: 0.9564
# Epoch 133/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.1925 - val_accuracy: 0.9524
# Epoch 134/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.1897 - val_accuracy: 0.9551
# Epoch 135/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1873 - val_accuracy: 0.9559
# Epoch 136/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.1936 - val_accuracy: 0.9555
# Epoch 137/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9582
# Epoch 138/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9564
# Epoch 139/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9586
# Epoch 140/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2176 - val_accuracy: 0.9573
# Epoch 141/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9564
# Epoch 142/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.5228e-04 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9573
# Epoch 143/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.4708e-04 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9582
# Epoch 144/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.2258 - val_accuracy: 0.9564
# Epoch 145/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.2291 - val_accuracy: 0.9528
# Epoch 146/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0261 - accuracy: 0.9921 - val_loss: 0.3322 - val_accuracy: 0.9181
# Epoch 147/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0806 - accuracy: 0.9718 - val_loss: 0.1943 - val_accuracy: 0.9488
# Epoch 148/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0515 - accuracy: 0.9821 - val_loss: 0.2020 - val_accuracy: 0.9475
# Epoch 149/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.1877 - val_accuracy: 0.9551
# Epoch 150/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 0.1761 - val_accuracy: 0.9542
# Epoch 151/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.1995 - val_accuracy: 0.9533
# Epoch 152/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9568
# Epoch 153/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9577
# Epoch 154/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9599
# Epoch 155/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9599
# Epoch 156/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.7981e-04 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9586
# Epoch 157/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.2820e-04 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9599
# Epoch 158/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.4227e-04 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9604
# Epoch 159/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.2891e-04 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9577
# Epoch 160/500
# 71/71 [==============================] - 4s 51ms/step - loss: 5.5279e-04 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9591
# Epoch 161/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.2646e-04 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9586
# Epoch 162/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.2359e-04 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9582
# Epoch 163/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.6776e-04 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9582
# Epoch 164/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.5650e-04 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9599
# Epoch 165/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.5272e-04 - accuracy: 1.0000 - val_loss: 0.2021 - val_accuracy: 0.9608
# Epoch 166/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.1197e-04 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9604
# Epoch 167/500
# 71/71 [==============================] - 4s 51ms/step - loss: 2.5293e-04 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9599
# Epoch 168/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7322e-04 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9604
# Epoch 169/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.3346 - val_accuracy: 0.9346
# Epoch 170/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.1565 - accuracy: 0.9545 - val_loss: 0.1773 - val_accuracy: 0.9435
# Epoch 171/500
# 71/71 [==============================] - 4s 51ms/step - loss: 0.0318 - accuracy: 0.9879 - val_loss: 0.2224 - val_accuracy: 0.9439
# Epoch 172/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 0.2052 - val_accuracy: 0.9488
# Epoch 173/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.2287 - val_accuracy: 0.9488
# Epoch 174/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.2072 - val_accuracy: 0.9528
# Epoch 175/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.1951 - val_accuracy: 0.9533
# Epoch 176/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.2263 - val_accuracy: 0.9462
# Epoch 177/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.2169 - val_accuracy: 0.9524
# Epoch 178/500
# 71/71 [==============================] - 4s 53ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.2087 - val_accuracy: 0.9528
# Epoch 179/500
# 71/71 [==============================] - 4s 55ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.2040 - val_accuracy: 0.9577
# Epoch 180/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9573
# Epoch 181/500
# 71/71 [==============================] - 4s 55ms/step - loss: 6.7938e-04 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9595
# Epoch 182/500
# 71/71 [==============================] - 4s 57ms/step - loss: 5.2205e-04 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9591
# Epoch 183/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.2030e-04 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9595
# Epoch 184/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.4208e-04 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.9564
# Epoch 185/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.6137e-04 - accuracy: 1.0000 - val_loss: 0.2140 - val_accuracy: 0.9591
# Epoch 186/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.2408 - val_accuracy: 0.9573
# Epoch 187/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.2182 - val_accuracy: 0.9582
# Epoch 188/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.2122 - val_accuracy: 0.9568
# Epoch 189/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.2305 - val_accuracy: 0.9519
# Epoch 190/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0922 - accuracy: 0.9694 - val_loss: 0.3426 - val_accuracy: 0.9230
# Epoch 191/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0470 - accuracy: 0.9844 - val_loss: 0.2511 - val_accuracy: 0.9426
# Epoch 192/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0400 - accuracy: 0.9872 - val_loss: 0.2110 - val_accuracy: 0.9506
# Epoch 193/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0086 - accuracy: 0.9982 - val_loss: 0.2021 - val_accuracy: 0.9528
# Epoch 194/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.1940 - val_accuracy: 0.9559
# Epoch 195/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.1978 - val_accuracy: 0.9586
# Epoch 196/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.2358e-04 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9573
# Epoch 197/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.1507e-04 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9568
# Epoch 198/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.9237e-04 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9577
# Epoch 199/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.9107e-04 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9564
# Epoch 200/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.4237e-04 - accuracy: 1.0000 - val_loss: 0.2021 - val_accuracy: 0.9573
# Epoch 201/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.7746e-04 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9573
# Epoch 202/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.4359e-04 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9586
# Epoch 203/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7153e-04 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9586
# Epoch 204/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.5411e-04 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9595
# Epoch 205/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8529e-04 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9599
# Epoch 206/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.4145e-04 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9595
# Epoch 207/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7084e-04 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9586
# Epoch 208/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8053e-04 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9582
# Epoch 209/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2682e-04 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9599
# Epoch 210/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.9817e-04 - accuracy: 1.0000 - val_loss: 0.2164 - val_accuracy: 0.9595
# Epoch 211/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2731e-04 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9617
# Epoch 212/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8127e-04 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.9599
# Epoch 213/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.6151e-04 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.9573
# Epoch 214/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.1270e-04 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9599
# Epoch 215/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.2777 - val_accuracy: 0.9506
# Epoch 216/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.1182 - accuracy: 0.9631 - val_loss: 0.2898 - val_accuracy: 0.9279
# Epoch 217/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0461 - accuracy: 0.9832 - val_loss: 0.1765 - val_accuracy: 0.9568
# Epoch 218/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.2050 - val_accuracy: 0.9599
# Epoch 219/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.1999 - val_accuracy: 0.9582
# Epoch 220/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.2315 - val_accuracy: 0.9542
# Epoch 221/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.2186 - val_accuracy: 0.9577
# Epoch 222/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9599
# Epoch 223/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.6950e-04 - accuracy: 1.0000 - val_loss: 0.2247 - val_accuracy: 0.9564
# Epoch 224/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.6553e-04 - accuracy: 1.0000 - val_loss: 0.2171 - val_accuracy: 0.9586
# Epoch 225/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.2769e-04 - accuracy: 1.0000 - val_loss: 0.2150 - val_accuracy: 0.9564
# Epoch 226/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7561e-04 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9577
# Epoch 227/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.7583e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9591
# Epoch 228/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.8874e-04 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9564
# Epoch 229/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.4027e-04 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9582
# Epoch 230/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2196e-04 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9604
# Epoch 231/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.4200e-04 - accuracy: 1.0000 - val_loss: 0.2239 - val_accuracy: 0.9604
# Epoch 232/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.1935e-04 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9586
# Epoch 233/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2734e-04 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9586
# Epoch 234/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2704e-04 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9604
# Epoch 235/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.0560e-04 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9604
# Epoch 236/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.0269e-04 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.9608
# Epoch 237/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.5180e-04 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9604
# Epoch 238/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.5839e-04 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9595
# Epoch 239/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.9856e-04 - accuracy: 1.0000 - val_loss: 0.2341 - val_accuracy: 0.9604
# Epoch 240/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.8544e-04 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9586
# Epoch 241/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2919e-04 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9595
# Epoch 242/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.9482e-04 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9604
# Epoch 243/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2569e-04 - accuracy: 1.0000 - val_loss: 0.2429 - val_accuracy: 0.9577
# Epoch 244/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0644 - accuracy: 0.9852 - val_loss: 0.5515 - val_accuracy: 0.8883
# Epoch 245/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.1464 - accuracy: 0.9540 - val_loss: 0.1969 - val_accuracy: 0.9439
# Epoch 246/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0252 - accuracy: 0.9905 - val_loss: 0.1788 - val_accuracy: 0.9542
# Epoch 247/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0073 - accuracy: 0.9988 - val_loss: 0.2064 - val_accuracy: 0.9546
# Epoch 248/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.2141 - val_accuracy: 0.9515
# Epoch 249/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 0.2318 - val_accuracy: 0.9510
# Epoch 250/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.2188 - val_accuracy: 0.9542
# Epoch 251/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.1904 - val_accuracy: 0.9573
# Epoch 252/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.1911 - val_accuracy: 0.9564
# Epoch 253/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.3065e-04 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9568
# Epoch 254/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.3913e-04 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9586
# Epoch 255/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.7774e-04 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9577
# Epoch 256/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.7019e-04 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9595
# Epoch 257/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.3517e-04 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 0.9559
# Epoch 258/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.2245 - val_accuracy: 0.9568
# Epoch 259/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.2211 - val_accuracy: 0.9568
# Epoch 260/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.2354 - val_accuracy: 0.9502
# Epoch 261/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0638 - accuracy: 0.9783 - val_loss: 0.3047 - val_accuracy: 0.9386
# Epoch 262/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0356 - accuracy: 0.9869 - val_loss: 0.2630 - val_accuracy: 0.9510
# Epoch 263/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0121 - accuracy: 0.9955 - val_loss: 0.1939 - val_accuracy: 0.9546
# Epoch 264/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0236 - accuracy: 0.9910 - val_loss: 0.2169 - val_accuracy: 0.9568
# Epoch 265/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.1848 - val_accuracy: 0.9586
# Epoch 266/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.2371 - val_accuracy: 0.9555
# Epoch 267/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.2094 - val_accuracy: 0.9586
# Epoch 268/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.2192 - val_accuracy: 0.9568
# Epoch 269/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0546 - accuracy: 0.9815 - val_loss: 0.2314 - val_accuracy: 0.9488
# Epoch 270/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0365 - accuracy: 0.9891 - val_loss: 0.2029 - val_accuracy: 0.9546
# Epoch 271/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.2169 - val_accuracy: 0.9591
# Epoch 272/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.1977 - val_accuracy: 0.9631
# Epoch 273/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.7468e-04 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9617
# Epoch 274/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.2745e-04 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9608
# Epoch 275/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.4979e-04 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9617
# Epoch 276/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.7998e-04 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9626
# Epoch 277/500
# 71/71 [==============================] - 4s 51ms/step - loss: 3.5975e-04 - accuracy: 1.0000 - val_loss: 0.2197 - val_accuracy: 0.9599
# Epoch 278/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.3934e-04 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9613
# Epoch 279/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8335e-04 - accuracy: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9622
# Epoch 280/500
# 71/71 [==============================] - 4s 51ms/step - loss: 2.6716e-04 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9604
# Epoch 281/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2748e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9608
# Epoch 282/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.4494e-04 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9613
# Epoch 283/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.0177e-04 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9617
# Epoch 284/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.1747e-04 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9608
# Epoch 285/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.5952e-04 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9608
# Epoch 286/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.5482e-04 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9622
# Epoch 287/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.2185e-04 - accuracy: 0.9997 - val_loss: 0.2422 - val_accuracy: 0.9582
# Epoch 288/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.2502 - val_accuracy: 0.9573
# Epoch 289/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.1065 - accuracy: 0.9682 - val_loss: 0.2674 - val_accuracy: 0.9399
# Epoch 290/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0326 - accuracy: 0.9874 - val_loss: 0.1748 - val_accuracy: 0.9559
# Epoch 291/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.1841 - val_accuracy: 0.9577
# Epoch 292/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.1745 - val_accuracy: 0.9617
# Epoch 293/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.1819 - val_accuracy: 0.9582
# Epoch 294/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.1903 - val_accuracy: 0.9604
# Epoch 295/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.9970e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9622
# Epoch 296/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.8717e-04 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9591
# Epoch 297/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.4825e-04 - accuracy: 1.0000 - val_loss: 0.1937 - val_accuracy: 0.9599
# Epoch 298/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.1477e-04 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9626
# Epoch 299/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.5083e-04 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9617
# Epoch 300/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.0546e-04 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9613
# Epoch 301/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.3575e-04 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9622
# Epoch 302/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8861e-04 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9595
# Epoch 303/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.6097e-04 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9617
# Epoch 304/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.5029e-04 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9608
# Epoch 305/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8870e-04 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9617
# Epoch 306/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.6848e-04 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9617
# Epoch 307/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.7451e-04 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9613
# Epoch 308/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.1638e-04 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9617
# Epoch 309/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.8115e-04 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9622
# Epoch 310/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.0636e-04 - accuracy: 0.9999 - val_loss: 0.2209 - val_accuracy: 0.9604
# Epoch 311/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0098 - accuracy: 0.9972 - val_loss: 0.2692 - val_accuracy: 0.9506
# Epoch 312/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0301 - accuracy: 0.9891 - val_loss: 0.2997 - val_accuracy: 0.9395
# Epoch 313/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0739 - accuracy: 0.9759 - val_loss: 0.2714 - val_accuracy: 0.9421
# Epoch 314/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0251 - accuracy: 0.9911 - val_loss: 0.2216 - val_accuracy: 0.9542
# Epoch 315/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.2200 - val_accuracy: 0.9573
# Epoch 316/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.2508 - val_accuracy: 0.9488
# Epoch 317/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.2062 - val_accuracy: 0.9577
# Epoch 318/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.4649e-04 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9582
# Epoch 319/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.2009e-04 - accuracy: 1.0000 - val_loss: 0.2200 - val_accuracy: 0.9582
# Epoch 320/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.4207e-04 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9613
# Epoch 321/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.2083e-04 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9622
# Epoch 322/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.4762e-04 - accuracy: 1.0000 - val_loss: 0.2191 - val_accuracy: 0.9604
# Epoch 323/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.5279e-04 - accuracy: 1.0000 - val_loss: 0.2146 - val_accuracy: 0.9608
# Epoch 324/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2036e-04 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9617
# Epoch 325/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7406e-04 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9586
# Epoch 326/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.7122e-04 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9608
# Epoch 327/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.0485e-04 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9591
# Epoch 328/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.8221e-04 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9604
# Epoch 329/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.5957e-04 - accuracy: 1.0000 - val_loss: 0.2208 - val_accuracy: 0.9617
# Epoch 330/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.3309e-04 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9604
# Epoch 331/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.8219e-04 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9604
# ...
# Epoch 393/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.7891e-04 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9599
# Epoch 394/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.6576e-04 - accuracy: 1.0000 - val_loss: 0.2358 - val_accuracy: 0.9595
# Epoch 395/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.3447e-04 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9586
# Epoch 396/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.6942e-04 - accuracy: 1.0000 - val_loss: 0.2399 - val_accuracy: 0.9595
# Epoch 397/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.3947e-04 - accuracy: 1.0000 - val_loss: 0.2440 - val_accuracy: 0.9608
# Epoch 398/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.3728e-04 - accuracy: 1.0000 - val_loss: 0.2419 - val_accuracy: 0.9608
# Epoch 399/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.0508e-04 - accuracy: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.9595
# Epoch 400/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.0558e-05 - accuracy: 1.0000 - val_loss: 0.2461 - val_accuracy: 0.9599
# Epoch 401/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.0650e-05 - accuracy: 1.0000 - val_loss: 0.2400 - val_accuracy: 0.9599
# Epoch 402/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.5582e-05 - accuracy: 1.0000 - val_loss: 0.2428 - val_accuracy: 0.9604
# Epoch 403/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.0568e-04 - accuracy: 1.0000 - val_loss: 0.2394 - val_accuracy: 0.9626
# Epoch 404/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.1359e-05 - accuracy: 1.0000 - val_loss: 0.2396 - val_accuracy: 0.9608
# Epoch 405/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.2203e-05 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9604
# Epoch 406/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.5251e-04 - accuracy: 1.0000 - val_loss: 0.2634 - val_accuracy: 0.9577
# Epoch 407/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0508 - accuracy: 0.9859 - val_loss: 0.2395 - val_accuracy: 0.9399
# Epoch 408/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0545 - accuracy: 0.9822 - val_loss: 0.2794 - val_accuracy: 0.9466
# Epoch 409/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0307 - accuracy: 0.9885 - val_loss: 0.2427 - val_accuracy: 0.9551
# Epoch 410/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.2529 - val_accuracy: 0.9564
# Epoch 411/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.2455 - val_accuracy: 0.9528
# Epoch 412/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.2368 - val_accuracy: 0.9577
# Epoch 413/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.2451 - val_accuracy: 0.9582
# Epoch 414/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.6706e-04 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 0.9577
# Epoch 415/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.2283 - val_accuracy: 0.9568
# Epoch 416/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.7425e-04 - accuracy: 1.0000 - val_loss: 0.2339 - val_accuracy: 0.9631
# Epoch 417/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.6594e-04 - accuracy: 1.0000 - val_loss: 0.2349 - val_accuracy: 0.9613
# Epoch 418/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.3804e-04 - accuracy: 1.0000 - val_loss: 0.2319 - val_accuracy: 0.9613
# Epoch 419/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.1257e-04 - accuracy: 1.0000 - val_loss: 0.2442 - val_accuracy: 0.9640
# Epoch 420/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.0522e-04 - accuracy: 0.9999 - val_loss: 0.2266 - val_accuracy: 0.9599
# Epoch 421/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.6889e-04 - accuracy: 0.9998 - val_loss: 0.2300 - val_accuracy: 0.9608
# Epoch 422/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.4555e-04 - accuracy: 1.0000 - val_loss: 0.2335 - val_accuracy: 0.9631
# Epoch 423/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.4419e-04 - accuracy: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.9622
# Epoch 424/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.6458e-05 - accuracy: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.9622
# Epoch 425/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.1585e-04 - accuracy: 1.0000 - val_loss: 0.2372 - val_accuracy: 0.9608
# Epoch 426/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.2258e-04 - accuracy: 1.0000 - val_loss: 0.2431 - val_accuracy: 0.9617
# Epoch 427/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.3565e-05 - accuracy: 1.0000 - val_loss: 0.2464 - val_accuracy: 0.9608
# Epoch 428/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.2701e-05 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.9626
# Epoch 429/500
# 71/71 [==============================] - 4s 52ms/step - loss: 9.6830e-05 - accuracy: 1.0000 - val_loss: 0.2446 - val_accuracy: 0.9626
# Epoch 430/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.1083e-05 - accuracy: 1.0000 - val_loss: 0.2450 - val_accuracy: 0.9635
# Epoch 431/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.2131e-04 - accuracy: 1.0000 - val_loss: 0.2413 - val_accuracy: 0.9626
# Epoch 432/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.0239e-04 - accuracy: 1.0000 - val_loss: 0.2507 - val_accuracy: 0.9626
# Epoch 433/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.9655e-04 - accuracy: 1.0000 - val_loss: 0.2538 - val_accuracy: 0.9613
# Epoch 434/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.2340e-04 - accuracy: 1.0000 - val_loss: 0.2492 - val_accuracy: 0.9613
# Epoch 435/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.0798e-04 - accuracy: 1.0000 - val_loss: 0.2604 - val_accuracy: 0.9622
# Epoch 436/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.3227e-05 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9613
# Epoch 437/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.5384e-05 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9613
# Epoch 438/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.1186e-05 - accuracy: 1.0000 - val_loss: 0.2592 - val_accuracy: 0.9599
# Epoch 439/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.6528e-05 - accuracy: 1.0000 - val_loss: 0.2594 - val_accuracy: 0.9604
# Epoch 440/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.9419e-05 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9608
# Epoch 441/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.3562e-05 - accuracy: 1.0000 - val_loss: 0.2714 - val_accuracy: 0.9608
# Epoch 442/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.5590e-05 - accuracy: 1.0000 - val_loss: 0.2697 - val_accuracy: 0.9595
# Epoch 443/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.7414e-05 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9608
# Epoch 444/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.1847e-05 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9604
# Epoch 445/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.0668e-05 - accuracy: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9599
# Epoch 446/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.1979e-05 - accuracy: 1.0000 - val_loss: 0.2728 - val_accuracy: 0.9595
# Epoch 447/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.5947e-05 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9595
# Epoch 448/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.8152e-05 - accuracy: 1.0000 - val_loss: 0.2706 - val_accuracy: 0.9599
# Epoch 449/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.4994e-05 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9604
# Epoch 450/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7463e-05 - accuracy: 1.0000 - val_loss: 0.2749 - val_accuracy: 0.9604
# Epoch 451/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.7650e-05 - accuracy: 1.0000 - val_loss: 0.2422 - val_accuracy: 0.9613
# Epoch 452/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.3496e-05 - accuracy: 1.0000 - val_loss: 0.2475 - val_accuracy: 0.9640
# Epoch 453/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7942e-05 - accuracy: 1.0000 - val_loss: 0.2538 - val_accuracy: 0.9604
# Epoch 454/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.4292e-05 - accuracy: 1.0000 - val_loss: 0.2460 - val_accuracy: 0.9626
# Epoch 455/500
# 71/71 [==============================] - 4s 51ms/step - loss: 5.2082e-05 - accuracy: 1.0000 - val_loss: 0.2577 - val_accuracy: 0.9599
# Epoch 456/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.5223e-05 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9604
# Epoch 457/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.2523e-05 - accuracy: 1.0000 - val_loss: 0.2735 - val_accuracy: 0.9591
# Epoch 458/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.3455e-05 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9599
# Epoch 459/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.4750e-05 - accuracy: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.9595
# Epoch 460/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.6860e-05 - accuracy: 1.0000 - val_loss: 0.2671 - val_accuracy: 0.9604
# Epoch 461/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.1317 - accuracy: 0.9686 - val_loss: 0.3723 - val_accuracy: 0.9092
# Epoch 462/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0765 - accuracy: 0.9742 - val_loss: 0.1733 - val_accuracy: 0.9564
# Epoch 463/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0095 - accuracy: 0.9984 - val_loss: 0.1902 - val_accuracy: 0.9559
# Epoch 464/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.2148 - val_accuracy: 0.9595
# Epoch 465/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.1922 - val_accuracy: 0.9608
# Epoch 466/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9604
# Epoch 467/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.8179e-04 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9608
# Epoch 468/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.9164e-04 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9613
# Epoch 469/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.0091e-04 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9631
# Epoch 470/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.2456e-04 - accuracy: 1.0000 - val_loss: 0.2026 - val_accuracy: 0.9617
# Epoch 471/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.7344e-04 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9608
# Epoch 472/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.2065e-04 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9595
# Epoch 473/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8028e-04 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9608
# Epoch 474/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.5051e-04 - accuracy: 1.0000 - val_loss: 0.2181 - val_accuracy: 0.9622
# Epoch 475/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.4882e-04 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9608
# Epoch 476/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.2023e-04 - accuracy: 1.0000 - val_loss: 0.2324 - val_accuracy: 0.9595
# Epoch 477/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.8884e-04 - accuracy: 1.0000 - val_loss: 0.2335 - val_accuracy: 0.9617
# Epoch 478/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.1608e-04 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9599
# Epoch 479/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.6047e-04 - accuracy: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9608
# Epoch 480/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.4143e-04 - accuracy: 0.9999 - val_loss: 0.2225 - val_accuracy: 0.9617
# Epoch 481/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.4713e-04 - accuracy: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.9568
# Epoch 482/500
# 71/71 [==============================] - 4s 52ms/step - loss: 5.9861e-04 - accuracy: 1.0000 - val_loss: 0.2417 - val_accuracy: 0.9599
# Epoch 483/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.5707e-04 - accuracy: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.9626
# Epoch 484/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.8372e-04 - accuracy: 0.9999 - val_loss: 0.2495 - val_accuracy: 0.9631
# Epoch 485/500
# 71/71 [==============================] - 4s 52ms/step - loss: 2.1101e-04 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9626
# Epoch 486/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.3803e-04 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9613
# Epoch 487/500
# 71/71 [==============================] - 4s 52ms/step - loss: 1.1241e-04 - accuracy: 1.0000 - val_loss: 0.2371 - val_accuracy: 0.9622
# Epoch 488/500
# 71/71 [==============================] - 4s 52ms/step - loss: 8.5342e-05 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9622
# Epoch 489/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.7790e-05 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9617
# Epoch 490/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.8883e-05 - accuracy: 1.0000 - val_loss: 0.2420 - val_accuracy: 0.9626
# Epoch 491/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.4825e-05 - accuracy: 1.0000 - val_loss: 0.2465 - val_accuracy: 0.9626
# Epoch 492/500
# 71/71 [==============================] - 4s 52ms/step - loss: 6.6179e-05 - accuracy: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.9622
# Epoch 493/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0240 - accuracy: 0.9945 - val_loss: 0.6252 - val_accuracy: 0.9057
# Epoch 494/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0907 - accuracy: 0.9725 - val_loss: 0.2152 - val_accuracy: 0.9448
# Epoch 495/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0166 - accuracy: 0.9939 - val_loss: 0.2067 - val_accuracy: 0.9599
# Epoch 496/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.1930 - val_accuracy: 0.9577
# Epoch 497/500
# 71/71 [==============================] - 4s 52ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.2009 - val_accuracy: 0.9595
# Epoch 498/500
# 71/71 [==============================] - 4s 52ms/step - loss: 7.9144e-04 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9595
# Epoch 499/500
# 71/71 [==============================] - 4s 52ms/step - loss: 4.8628e-04 - accuracy: 1.0000 - val_loss: 0.2170 - val_accuracy: 0.9613
# Epoch 500/500
# 71/71 [==============================] - 4s 52ms/step - loss: 3.7916e-04 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9599

# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\ranji\appdata\roaming\python\python39\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (from h5py) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
model_name = "mutiple_Conv1D_8_inputs_scaled_modified"
model = keras.models.load_model("D:/Project2022/models/"+model_name+".h5")

# %%
from keras_visualizer import visualizer
visualizer(model, format='png', view=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 21 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> from keras_visualizer import visualizer
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> visualizer(model, format='png', view=True)
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras_visualizer\__init__.py:130, in visualizer(model, filename, format, view)
#     128         c.node(str(n), label=f'Image\n{pxls[1]} x{pxls[2]} pixels\n{clrmap}', fontcolor='white', shape='square', style='filled', fillcolor=the_color)
#     129     else:
# --> 130         raise ValueError('Keras Visualizer: Layer not supported for visualizing')
#     132 # Hidden Layers
#     133 for i in range(0, hidden_layers_nr):
#
# ValueError: Keras Visualizer: Layer not supported for visualizing

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
pip install keras-visualizer
# Out:
# Collecting keras-visualizer
#   Downloading keras_visualizer-2.4-py3-none-any.whl (5.4 kB)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
model_name
# Out:
# 'mutiple_Conv1D_8_inputs_scaled_modified'

# %%
model.save("D:/Project2022/models/"+model_name+".h5")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> model.save("D:/Project2022/models/"+model_name+".h5")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\saving\hdf5_format.py:80, in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      54 """Saves a model to a HDF5 file.
#      55
#      56 The saved model contains:
#    (...)
#      76     ImportError: if h5py is not available.
#      77 """
#      79 if h5py is None:
# ---> 80     raise ImportError(
#      81         "`save_model()` using h5 format requires h5py. Could not "
#      82         "import h5py."
#      83     )
#      85 # TODO(psv) Add warning when we save models that contain non-serializable
#      86 # entities like metrics added using `add_metric` and losses added using
#      87 # `add_loss.`
#      88 if len(model.weights) != len(model._undeduplicated_weights):
#
# ImportError: `save_model()` using h5 format requires h5py. Could not import h5py.

# %%
#model = keras.models.load_model("D:/Project2022/models/image/raw_500.h5")

#from tensorflow import keras
bing = keras.models.load_model('D:/Project2022/models/image/raw_500.h5')
bing.save(model_name+".h5")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 26 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> #model = keras.models.load_model("D:/Project2022/models/image/raw_500.h5")
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> #from tensorflow import keras
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> bing = keras.models.load_model('D:/Project2022/models/image/raw_500.h5')
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> bing.save(model_name+".h5")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\saving\save.py:236, in load_model(filepath, custom_objects, compile, options)
#     234     else:
#     235         if h5py is None:
# --> 236             raise ImportError(
#     237                 "Filepath looks like a hdf5 file but h5py is "
#     238                 "not available."
#     239                 f" filepath={filepath_str}"
#     240             )
#     241         return hdf5_format.load_model_from_hdf5(
#     242             tf.io.gfile.GFile(filepath_str, mode="rb"),
#     243             custom_objects,
#     244             compile,
#     245         )
#     246 elif h5py is not None and isinstance(filepath, h5py.File):
#
# ImportError: Filepath looks like a hdf5 file but h5py is not available. filepath=D:/Project2022/models/image/raw_500.h5

# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (from h5py) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
model.save("D:/Project2022/models/image/delete.h5")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Project2022\Code\project2022\classifiers\adding_the_overlaps_scaled_modified.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> import h5py
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/classifiers/adding_the_overlaps_scaled_modified.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> model.save("D:/Project2022/models/image/delete.h5")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\h5py\__init__.py:33, in <module>
#      30     else:
#      31         raise
# ---> 33 from . import version
#      35 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\h5py\version.py:15, in <module>
#      10 """
#      11     Versioning module for h5py.
#      12 """
#      14 from collections import namedtuple
# ---> 15 from . import h5 as _h5
#      16 import sys
#      17 import numpy
#
# File h5py\h5.pyx:1, in init h5py.h5()
#
# ImportError: DLL load failed while importing defs: The specified procedure could not be found.

# %% [markdown]
# # Evaluate the Model using test data

# %%
Test_DATADIR = "D:/Project2022/res/split_dataset/scaled_resized/test"
dataset_df = pre_process_dataset(Test_DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/1430 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/1379 [00:00<?, ?it/s]

# %%
print("No of test sample:", len(dataset_df))
# Out:
# No of test sample: 2809

# %%
X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test, Y_test = process_data(dataset_df)
# Out:
# X1 shape (2809, 367, 1)
# X2 shape (2809, 252, 1)
# X3 shape (2809, 252, 1)
# Mid rows shape (2809, 252, 1)
# X4 shape (2809, 252, 1)
# X5 shape (2809, 367, 1)
# Mid Cols shape (2809, 367, 1)
# X6 shape (2809, 367, 1)
# y shape (2809, 1)

# %%
# test loss, test accuracy
accuracy = model.evaluate([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test], Y_test, batch_size=100, verbose=0)

# %%
print("Test acuuracy", accuracy[1])
print("Test loss", accuracy[0])
# Out:
# Test acuuracy 0.9619081616401672
# Test loss 0.20270198583602905

# %%
#y_pred = model.predict_classes(X_test)
y_pred = (model.predict([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test]) > 0.5).astype("int32")
# Out:
# 88/88 [==============================] - 2s 10ms/step

# %%
print(classification_report(Y_test, y_pred, target_names=["covid", "Normal"]))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.97      0.96      0.96      1430
#       Normal       0.96      0.97      0.96      1379
#
#     accuracy                           0.96      2809
#    macro avg       0.96      0.96      0.96      2809
# weighted avg       0.96      0.96      0.96      2809

# %%
cm = confusion_matrix(Y_test, y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=["Covid","Normal"])
disp.plot()
plt.show()
