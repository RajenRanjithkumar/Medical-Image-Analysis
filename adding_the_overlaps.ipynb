# %%
#mask
import json
import cv2
import os
import pandas as pd 
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
import keras
from keras.preprocessing import image
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers, models

from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical

from keras.layers import Input
from keras.models import Model
from keras.layers import concatenate
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten 
from keras.layers import Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import to_categorical
import xml.etree.ElementTree as ET
from tensorflow.keras.callbacks import TensorBoard

from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import time

# %%
model_name = "mutiple_Conv1D_8_inputs"
NAME = model_name+"-{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir = 'logs/{}'.format(NAME))

# %%
CATEGORIES = ["covid", "normal"]
DATADIR = "D:/Project2022/res/split_dataset/original/train"

# %%
for categoty in CATEGORIES:
    path = os.path.join(DATADIR, categoty)  # path to Covid or Nprmal
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap="gray")
        plt.show()

        #left half
        LH_img = img_array[: , :256]
        plt.imshow(LH_img, cmap="gray")
        plt.show()
        
        #Right half
        RH_img = img_array[: , 256:]
        plt.imshow(RH_img, cmap="gray")
        plt.show()

        # mid vertical
        mid_ver = img_array[:, 128:384]
        plt.imshow(mid_ver, cmap="gray")
        plt.show()

        #top half
        TH_img = img_array[:256 , :]
        plt.imshow(TH_img, cmap="gray")
        plt.show()

        #bottom half
        BH_img = img_array[256: , :]
        plt.imshow(BH_img, cmap="gray")
        plt.show()

        #mid horizontal
        mid_hor = img_array[128:384, :]
        plt.imshow(mid_hor, cmap="gray")
        plt.show()

        

        



        break
    break

# %%
def pre_process_dataset(dataset_path):

    df_data = pd.DataFrame()
    #raw_image = []
    row_sum = []
    coloumn_sum = []
    
    LH_sum = []
    Row_mid = []
    RH_sum = []
    
    TC_sum = []
    Col_mid = []
    BC_sum =[]

    label = []

    for categoty in CATEGORIES:
        path = os.path.join(dataset_path, categoty)  
        
        class_num = CATEGORIES.index(categoty)
        

        print("Loading dataset: class",categoty)
        for img in tqdm(os.listdir(path)):

            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
                row = img_array.sum(axis=0)
                coloumn = img_array.sum(axis=1)

                #Global inputs
                row_sum.append(row)
                coloumn_sum.append(coloumn)

                #row inputs
                LH_img = img_array[: , :256]
                LH_sum.append(LH_img.sum(0))

                row_mid = img_array[:, 128:384]
                Row_mid.append(row_mid.sum(0))

                RH_img = img_array[: , 256:]
                RH_sum.append(RH_img.sum(0))

                #coloumn inputs
                TC_img = img_array[:256 , :]
                TC_sum.append(TC_img.sum(1))

                col_mid = img_array[128:384, :]
                Col_mid.append(col_mid.sum(1)) 

                BC_img = img_array[256: , :]
                BC_sum.append(BC_img.sum(1))

                
                #raw_image.append(img_array)

                

                label.append(class_num)
                
            except Exception as e:
                pass
    
    #df_data["raw data"] = raw_image
    df_data["row_sum"] = row_sum
    df_data["coloumn_sum"] = coloumn_sum

    df_data["LH_sum"] = LH_sum
    df_data["Row_mid"] = Row_mid
    df_data["RH_sum"] = RH_sum


    df_data["TC_sum"] = TC_sum
    df_data["Col_mid"] = Col_mid
    df_data["BC_sum"] = BC_sum

    df_data["label"] = label
    

    return df_data

# %%
dataset_df = pre_process_dataset(DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/5719 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/5514 [00:00<?, ?it/s]

# %%
dataset_df.head(-1)
# Out:
#                                                  row_sum  \
# 0      [4576, 8086, 10445, 12245, 14048, 15508, 16670...
# 1      [12508, 12672, 12653, 12882, 13104, 13177, 133...
# 2      [2156, 2300, 2172, 2163, 2207, 2268, 2194, 237...
# 3      [2417, 2502, 2556, 2661, 2882, 3103, 3152, 301...
# 4      [3923, 3983, 4025, 4110, 4234, 4291, 4367, 496...
# ...                                                  ...
# 11227  [2447, 4284, 5494, 6403, 7413, 8614, 9983, 116...
# 11228  [4569, 7949, 10169, 11881, 13539, 14927, 16013...
# 11229  [4699, 8209, 10486, 12146, 13832, 15253, 16404...
# 11230  [2588, 4518, 5787, 6754, 7737, 8537, 9185, 100...
# 11231  [2603, 4487, 5751, 6688, 7616, 8377, 8990, 977...
#
#                                              coloumn_sum  \
# 0      [2494, 4356, 5604, 6526, 7444, 8223, 8843, 962...
# 1      [1016, 1052, 1036, 1028, 1015, 1028, 1031, 101...
# 2      [988, 1056, 1045, 1068, 1046, 1081, 1018, 1114...
# 3      [960, 989, 980, 984, 984, 980, 984, 994, 990, ...
# 4      [1088, 1108, 1106, 1074, 1077, 1078, 1076, 109...
# ...                                                  ...
# 11227  [2397, 4198, 5402, 6309, 7215, 7968, 8560, 930...
# 11228  [2307, 4041, 5192, 6059, 6926, 7651, 8239, 895...
# 11229  [2365, 4126, 5306, 6204, 7084, 7833, 8422, 917...
# 11230  [2566, 4496, 5788, 6760, 7733, 8551, 9195, 999...
# 11231  [2424, 4242, 5450, 6360, 7271, 8018, 8612, 939...
#
#                                                   LH_sum  \
# 0      [4576, 8086, 10445, 12245, 14048, 15508, 16670...
# 1      [12508, 12672, 12653, 12882, 13104, 13177, 133...
# 11227  [46506, 46655, 46467, 46063, 45562, 45394, 451...
# 11228  [58834, 59198, 59230, 59424, 59347, 59661, 597...
# 11229  [59953, 60893, 61089, 61254, 61161, 61371, 613...
# 11230  [50962, 51815, 52388, 52343, 52107, 52478, 527...
# 11231  [58141, 58230, 58281, 58534, 58701, 58900, 589...
#
#                                                   BC_sum  label
# 0      [61881, 61711, 61798, 62068, 62007, 61499, 607...      0
# 1      [38214, 38653, 38426, 38475, 38430, 38314, 382...      0
# 2      [24752, 25099, 25581, 26425, 26581, 27024, 274...      0
# 3      [50344, 50358, 50392, 50397, 50474, 50588, 504...      0
# 4      [37613, 37486, 37545, 37442, 37380, 37297, 372...      0
# ...                                                  ...    ...
# 11227  [57285, 57842, 57883, 57494, 56788, 55967, 555...      1
# 11228  [56652, 56666, 56784, 56930, 57206, 57566, 579...      1
# 11229  [57250, 57148, 56975, 56855, 56838, 56921, 570...      1
# 11230  [53367, 53429, 52751, 51621, 50987, 51075, 513...      1
# 11231  [61528, 61283, 61140, 61086, 61153, 61229, 610...      1
#
# [11232 rows x 9 columns]

# %%
df_train, df_val = train_test_split(dataset_df, test_size=0.2, random_state=0)

# %%
df_train["label"].value_counts()
# Out:
# 0    4601
# 1    4385
# Name: label, dtype: int64

# %%
print("No of Training samples:",len(df_train))
print("No of Validation samples:",len(df_val))
# Out:
# No of Training samples: 8986
# No of Validation samples: 2247

# %%
df_train["Row_mid"][0].shape
# Out:
# (256,)

# %%
from sklearn import preprocessing

def process_data(dataset_df):
    
    row = dataset_df["row_sum"].values
    coloumn = dataset_df["coloumn_sum"].values

    LH = dataset_df["LH_sum"].values
    Row_mid = dataset_df["Row_mid"].values
    RH = dataset_df["RH_sum"].values


    TC = dataset_df["TC_sum"].values
    Col_mid = dataset_df["Col_mid"].values
    BC = dataset_df["BC_sum"].values

    # global
    X1 = [img.tolist() for img in row]
    X2 = [img.tolist() for img in coloumn]

    #row
    X3 = [img.tolist() for img in LH]
    X_row_mid = [img.tolist() for img in Row_mid]
    X4 = [img.tolist() for img in RH]

    #coloumn
    X5 = [img.tolist() for img in TC]
    X_col_mid = [img.tolist() for img in Col_mid]
    X6 = [img.tolist() for img in BC]


    X1 = np.array(X1)
    X2 = np.array(X2)

    X3 = np.array(X3)
    X_row_mid = np.array(X_row_mid)
    X4 = np.array(X4)


    X5 = np.array(X5)
    X_col_mid = np.array(X_col_mid)
    X6 = np.array(X6)

    #normalize the inputs
    X1 = preprocessing.normalize(X1)
    X2 = preprocessing.normalize(X2)

    X3 = preprocessing.normalize(X3)
    X_row_mid = preprocessing.normalize(X_row_mid)
    X4 = preprocessing.normalize(X4)

    X5 = preprocessing.normalize(X5)
    X_col_mid = preprocessing.normalize(X_col_mid)
    X6 = preprocessing.normalize(X6)

    #reshape the inputs
    X1 = np.expand_dims(X1, axis=-1)
    X2 = np.expand_dims(X2, axis=-1)

    X3 = np.expand_dims(X3, axis=-1)
    X_row_mid = np.expand_dims(X_row_mid, axis=-1)
    X4 = np.expand_dims(X4, axis=-1)

    X5 = np.expand_dims(X5, axis=-1)
    X_col_mid = np.expand_dims(X_col_mid, axis=-1)
    X6 = np.expand_dims(X6, axis=-1)



    y = np.array(dataset_df["label"].values)
    y = np.expand_dims(y, axis=-1)


    print("X1 shape", X1.shape)
    print("X2 shape", X2.shape)

    print("X3 shape", X3.shape)
    print("Mid rows shape", X_row_mid.shape)
    print("X4 shape", X4.shape)

    print("X5 shape", X5.shape)
    print("Mid Cols shape", X_col_mid.shape)
    print("X6 shape", X6.shape)

    print("y shape", y.shape)

    return X1, X2, X3, X_row_mid, X4, X5, X_col_mid, X6, y

# %%
print("Training samples:")
X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train, Y_train = process_data(df_train)

print("\nValidation samples:")
X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val, Y_val = process_data(df_val)
# Out:
# Training samples:
# X1 shape (8986, 512, 1)
# X2 shape (8986, 512, 1)
# X3 shape (8986, 256, 1)
# Mid rows shape (8986, 256, 1)
# X4 shape (8986, 256, 1)
# X5 shape (8986, 256, 1)
# Mid Cols shape (8986, 256, 1)
# X6 shape (8986, 256, 1)
# y shape (8986, 1)
#
# Validation samples:
# X1 shape (2247, 512, 1)
# X2 shape (2247, 512, 1)
# X3 shape (2247, 256, 1)
# Mid rows shape (2247, 256, 1)
# X4 shape (2247, 256, 1)
# X5 shape (2247, 256, 1)
# Mid Cols shape (2247, 256, 1)
# X6 shape (2247, 256, 1)
# y shape (2247, 1)

# %%
# first input model
row = Input(shape=(512,1))
conv11 = Conv1D(64, kernel_size=3, activation='relu')(row)
conv12 = Conv1D(64, kernel_size=3, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat_row = Flatten()(pool11)


# second input model
col = Input(shape=(512,1))
conv21 = Conv1D(64, kernel_size=3, activation='relu')(col)
conv22 = Conv1D(64, kernel_size=3, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat_col = Flatten()(pool21)

# merge input models
merge = concatenate([flat_row, flat_col])

hidden1 = Dense(100, activation='relu')(merge)
hidden_global = Dense(100, activation='relu')(hidden1)

#####################################################################

LH = Input(shape=(256,1))
conv31 = Conv1D(64, kernel_size=3, activation='relu')(LH)
conv32 = Conv1D(64, kernel_size=3, activation='relu')(conv31)
drop31 = Dropout(0.25)(conv32)
pool31 = MaxPooling1D(pool_size=2)(drop31)
flat3 = Flatten()(pool31)

row_mid = Input(shape=(256,1))
conv41 = Conv1D(64, kernel_size=3, activation='relu')(row_mid)
conv42 = Conv1D(64, kernel_size=3, activation='relu')(conv41)
drop41 = Dropout(0.25)(conv42)
pool41 = MaxPooling1D(pool_size=2)(drop41)
flat4 = Flatten()(pool41)

RH = Input(shape=(256,1))
conv51 = Conv1D(64, kernel_size=3, activation='relu')(RH)
conv52 = Conv1D(64, kernel_size=3, activation='relu')(conv51)
drop51 = Dropout(0.25)(conv52)
pool51 = MaxPooling1D(pool_size=2)(drop51)
flat5 = Flatten()(pool51)

# merge input models
merge_rows = concatenate([flat3, flat4, flat5])
hidden3 = Dense(100, activation='relu')(merge_rows)
hidden_rows = Dense(100, activation='relu')(hidden3)




TC = Input(shape=(256,1))
conv61 = Conv1D(64, kernel_size=3, activation='relu')(TC)
conv62 = Conv1D(64, kernel_size=3, activation='relu')(conv61)
drop61 = Dropout(0.25)(conv62)
pool61 = MaxPooling1D(pool_size=2)(drop61)
flat6 = Flatten()(pool61)

col_mid = Input(shape=(256,1))
conv71 = Conv1D(64, kernel_size=3, activation='relu')(col_mid)
conv72 = Conv1D(64, kernel_size=3, activation='relu')(conv71)
drop71 = Dropout(0.25)(conv72)
pool71 = MaxPooling1D(pool_size=2)(drop71)
flat7 = Flatten()(pool71)

BC = Input(shape=(256,1))
conv81 = Conv1D(64, kernel_size=3, activation='relu')(BC)
conv82 = Conv1D(64, kernel_size=3, activation='relu')(conv81)
drop81 = Dropout(0.25)(conv82)
pool81 = MaxPooling1D(pool_size=2)(drop81)
flat8 = Flatten()(pool81)



merge_cols = concatenate([flat6, flat7, flat8])
hidden5 = Dense(100, activation='relu')(merge_cols)
hidden_cols = Dense(100, activation='relu')(hidden5)

# merge input models
merge_row_col = concatenate([hidden_rows, hidden_cols])
merge_all = concatenate([hidden_global, merge_row_col])

output = Dense(1, activation='sigmoid')(merge_all)
model = Model(inputs=[row, col, LH, row_mid, RH, TC, col_mid, BC], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 256, 1)]     0           []
#
#  input_16 (InputLayer)          [(None, 256, 1)]     0           []
#
#  input_17 (InputLayer)          [(None, 256, 1)]     0           []
#
#  input_18 (InputLayer)          [(None, 256, 1)]     0           []
#
#  input_19 (InputLayer)          [(None, 256, 1)]     0           []
#
#  input_20 (InputLayer)          [(None, 256, 1)]     0           []
#
#  input_13 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_14 (InputLayer)          [(None, 512, 1)]     0           []
#
#  conv1d_16 (Conv1D)             (None, 254, 64)      256         ['input_15[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 254, 64)      256         ['input_16[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 254, 64)      256         ['input_17[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 254, 64)      256         ['input_18[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 254, 64)      256         ['input_19[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 254, 64)      256         ['input_20[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 510, 64)      256         ['input_13[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 510, 64)      256         ['input_14[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 252, 64)      12352       ['conv1d_16[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 252, 64)      12352       ['conv1d_18[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 252, 64)      12352       ['conv1d_20[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 252, 64)      12352       ['conv1d_22[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 252, 64)      12352       ['conv1d_24[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 252, 64)      12352       ['conv1d_26[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 508, 64)      12352       ['conv1d_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 508, 64)      12352       ['conv1d_14[0][0]']
#
#  dropout_12 (Dropout)           (None, 252, 64)      0           ['conv1d_17[0][0]']
#
#  dropout_13 (Dropout)           (None, 252, 64)      0           ['conv1d_19[0][0]']
#
#  dropout_14 (Dropout)           (None, 252, 64)      0           ['conv1d_21[0][0]']
#
#  dropout_15 (Dropout)           (None, 252, 64)      0           ['conv1d_23[0][0]']
#
#  dropout_16 (Dropout)           (None, 252, 64)      0           ['conv1d_25[0][0]']
#
#  dropout_17 (Dropout)           (None, 252, 64)      0           ['conv1d_27[0][0]']
#
#  dropout_10 (Dropout)           (None, 508, 64)      0           ['conv1d_13[0][0]']
#
#  dropout_11 (Dropout)           (None, 508, 64)      0           ['conv1d_15[0][0]']
#
#  max_pooling1d_14 (MaxPooling1D  (None, 126, 64)     0           ['dropout_12[0][0]']
#  )
#
#  max_pooling1d_15 (MaxPooling1D  (None, 126, 64)     0           ['dropout_13[0][0]']
#  )
#
#  max_pooling1d_16 (MaxPooling1D  (None, 126, 64)     0           ['dropout_14[0][0]']
#  )
#
#  max_pooling1d_17 (MaxPooling1D  (None, 126, 64)     0           ['dropout_15[0][0]']
#  )
#
#  max_pooling1d_18 (MaxPooling1D  (None, 126, 64)     0           ['dropout_16[0][0]']
#  )
#
#  max_pooling1d_19 (MaxPooling1D  (None, 126, 64)     0           ['dropout_17[0][0]']
#  )
#
#  max_pooling1d_12 (MaxPooling1D  (None, 254, 64)     0           ['dropout_10[0][0]']
#  )
#
#  max_pooling1d_13 (MaxPooling1D  (None, 254, 64)     0           ['dropout_11[0][0]']
#  )
#
#  flatten_14 (Flatten)           (None, 8064)         0           ['max_pooling1d_14[0][0]']
#
#  flatten_15 (Flatten)           (None, 8064)         0           ['max_pooling1d_15[0][0]']
#
#  flatten_16 (Flatten)           (None, 8064)         0           ['max_pooling1d_16[0][0]']
#
#  flatten_17 (Flatten)           (None, 8064)         0           ['max_pooling1d_17[0][0]']
#
#  flatten_18 (Flatten)           (None, 8064)         0           ['max_pooling1d_18[0][0]']
#
#  flatten_19 (Flatten)           (None, 8064)         0           ['max_pooling1d_19[0][0]']
#
#  flatten_12 (Flatten)           (None, 16256)        0           ['max_pooling1d_12[0][0]']
#
#  flatten_13 (Flatten)           (None, 16256)        0           ['max_pooling1d_13[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 24192)        0           ['flatten_14[0][0]',
#                                                                   'flatten_15[0][0]',
#                                                                   'flatten_16[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 24192)        0           ['flatten_17[0][0]',
#                                                                   'flatten_18[0][0]',
#                                                                   'flatten_19[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 32512)        0           ['flatten_12[0][0]',
#                                                                   'flatten_13[0][0]']
#
#  dense_10 (Dense)               (None, 100)          2419300     ['concatenate_11[0][0]']
#
#  dense_12 (Dense)               (None, 100)          2419300     ['concatenate_12[0][0]']
#
#  dense_8 (Dense)                (None, 100)          3251300     ['concatenate_10[0][0]']
#
#  dense_11 (Dense)               (None, 100)          10100       ['dense_10[0][0]']
#
#  dense_13 (Dense)               (None, 100)          10100       ['dense_12[0][0]']
#
#  dense_9 (Dense)                (None, 100)          10100       ['dense_8[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 200)          0           ['dense_11[0][0]',
#                                                                   'dense_13[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 300)          0           ['dense_9[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  dense_14 (Dense)               (None, 1)            301         ['concatenate_14[0][0]']
#
# ==================================================================================================
# Total params: 8,221,365
# Trainable params: 8,221,365
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# first input model
visible1 = Input(shape=(512,1))
conv11 = Conv1D(64, kernel_size=3, activation='relu')(visible1)

conv12 = Conv1D(64, kernel_size=3, activation='relu')(conv11)
drop11 = Dropout(0.25)(conv12)
pool11 = MaxPooling1D(pool_size=2)(drop11)
flat1 = Flatten()(pool11)


# second input model

visible2 = Input(shape=(512,1))
conv21 = Conv1D(64, kernel_size=3, activation='relu')(visible2)
conv22 = Conv1D(64, kernel_size=3, activation='relu')(conv21)
drop21 = Dropout(0.25)(conv22)
pool21 = MaxPooling1D(pool_size=2)(drop21)
flat2 = Flatten()(pool21)


# merge input models
merge = concatenate([flat1, flat2])
# interpretation model
hidden1 = Dense(100, activation='relu')(merge)
hidden2 = Dense(100, activation='relu')(hidden1)

output = Dense(1, activation='sigmoid')(hidden2)
model = Model(inputs=[visible1, visible2], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 512, 1)]     0           []
#
#  input_8 (InputLayer)           [(None, 512, 1)]     0           []
#
#  conv1d_12 (Conv1D)             (None, 510, 64)      256         ['input_7[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 510, 64)      256         ['input_8[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 508, 64)      12352       ['conv1d_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 508, 64)      12352       ['conv1d_14[0][0]']
#
#  dropout_6 (Dropout)            (None, 508, 64)      0           ['conv1d_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 508, 64)      0           ['conv1d_15[0][0]']
#
#  max_pooling1d_6 (MaxPooling1D)  (None, 254, 64)     0           ['dropout_6[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 254, 64)     0           ['dropout_7[0][0]']
#
#  flatten_6 (Flatten)            (None, 16256)        0           ['max_pooling1d_6[0][0]']
#
#  flatten_7 (Flatten)            (None, 16256)        0           ['max_pooling1d_7[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32512)        0           ['flatten_6[0][0]',
#                                                                   'flatten_7[0][0]']
#
#  dense_7 (Dense)                (None, 100)          3251300     ['concatenate_5[0][0]']
#
#  dense_8 (Dense)                (None, 100)          10100       ['dense_7[0][0]']
#
#  dense_9 (Dense)                (None, 1)            101         ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 3,286,717
# Trainable params: 3,286,717
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
BATCH_SIZE = 128
EPOCHS = 500
history = model.fit(
    [X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train],
    Y_train,
    BATCH_SIZE,
    EPOCHS,
    validation_data=([X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val], Y_val),
    callbacks=[tensorboard])

model.save("D:/Project2022/models/"+model_name+".h5")
# Out:
# Epoch 1/500
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000149A6EFF438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000149A6EFF438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 71/71 [==============================] - ETA: 0s - loss: 0.5691 - accuracy: 0.7048WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000149A6A6B048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000149A6A6B048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 71/71 [==============================] - 11s 74ms/step - loss: 0.5691 - accuracy: 0.7048 - val_loss: 0.4903 - val_accuracy: 0.7721
# Epoch 2/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.4496 - accuracy: 0.7990 - val_loss: 0.4113 - val_accuracy: 0.8247
# Epoch 3/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.3961 - accuracy: 0.8260 - val_loss: 0.3916 - val_accuracy: 0.8367
# Epoch 4/500
# 71/71 [==============================] - 4s 55ms/step - loss: 0.3828 - accuracy: 0.8369 - val_loss: 0.3644 - val_accuracy: 0.8545
# Epoch 5/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.3623 - accuracy: 0.8471 - val_loss: 0.3515 - val_accuracy: 0.8558
# Epoch 6/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.3542 - accuracy: 0.8520 - val_loss: 0.3755 - val_accuracy: 0.8509
# Epoch 7/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.3403 - accuracy: 0.8617 - val_loss: 0.3330 - val_accuracy: 0.8660
# Epoch 8/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.3241 - accuracy: 0.8698 - val_loss: 0.3236 - val_accuracy: 0.8696
# Epoch 9/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.3300 - accuracy: 0.8636 - val_loss: 0.3215 - val_accuracy: 0.8754
# Epoch 10/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.3110 - accuracy: 0.8737 - val_loss: 0.3174 - val_accuracy: 0.8807
# Epoch 11/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.3017 - accuracy: 0.8765 - val_loss: 0.3030 - val_accuracy: 0.8807
# Epoch 12/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2974 - accuracy: 0.8837 - val_loss: 0.3417 - val_accuracy: 0.8709
# Epoch 13/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2809 - accuracy: 0.8888 - val_loss: 0.3012 - val_accuracy: 0.8830
# Epoch 14/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2882 - accuracy: 0.8853 - val_loss: 0.3160 - val_accuracy: 0.8856
# Epoch 15/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2639 - accuracy: 0.8974 - val_loss: 0.2784 - val_accuracy: 0.9025
# Epoch 16/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2716 - accuracy: 0.8929 - val_loss: 0.2987 - val_accuracy: 0.8874
# Epoch 17/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2480 - accuracy: 0.9051 - val_loss: 0.2471 - val_accuracy: 0.9137
# Epoch 18/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2323 - accuracy: 0.9110 - val_loss: 0.2497 - val_accuracy: 0.9079
# Epoch 19/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2249 - accuracy: 0.9148 - val_loss: 0.2280 - val_accuracy: 0.9221
# Epoch 20/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2159 - accuracy: 0.9161 - val_loss: 0.2209 - val_accuracy: 0.9212
# Epoch 21/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2042 - accuracy: 0.9237 - val_loss: 0.2063 - val_accuracy: 0.9248
# Epoch 22/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.2022 - accuracy: 0.9229 - val_loss: 0.2178 - val_accuracy: 0.9266
# Epoch 23/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.1847 - accuracy: 0.9310 - val_loss: 0.2084 - val_accuracy: 0.9275
# Epoch 24/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.1909 - accuracy: 0.9261 - val_loss: 0.2209 - val_accuracy: 0.9163
# Epoch 25/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.1734 - accuracy: 0.9345 - val_loss: 0.2257 - val_accuracy: 0.9186
# Epoch 26/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.1762 - accuracy: 0.9286 - val_loss: 0.1853 - val_accuracy: 0.9372
# Epoch 27/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.1690 - accuracy: 0.9353 - val_loss: 0.1845 - val_accuracy: 0.9386
# Epoch 28/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1654 - accuracy: 0.9377 - val_loss: 0.1955 - val_accuracy: 0.9372
# Epoch 29/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1483 - accuracy: 0.9448 - val_loss: 0.1859 - val_accuracy: 0.9355
# Epoch 30/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1532 - accuracy: 0.9426 - val_loss: 0.1654 - val_accuracy: 0.9470
# Epoch 31/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.1342 - accuracy: 0.9494 - val_loss: 0.1818 - val_accuracy: 0.9421
# Epoch 32/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1379 - accuracy: 0.9470 - val_loss: 0.1715 - val_accuracy: 0.9421
# Epoch 33/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1316 - accuracy: 0.9484 - val_loss: 0.1634 - val_accuracy: 0.9470
# Epoch 34/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1396 - accuracy: 0.9454 - val_loss: 0.1905 - val_accuracy: 0.9332
# Epoch 35/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1258 - accuracy: 0.9542 - val_loss: 0.1625 - val_accuracy: 0.9453
# Epoch 36/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1215 - accuracy: 0.9535 - val_loss: 0.1554 - val_accuracy: 0.9484
# Epoch 37/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1259 - accuracy: 0.9534 - val_loss: 0.1695 - val_accuracy: 0.9381
# Epoch 38/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1261 - accuracy: 0.9519 - val_loss: 0.1671 - val_accuracy: 0.9453
# Epoch 39/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1239 - accuracy: 0.9506 - val_loss: 0.1623 - val_accuracy: 0.9426
# Epoch 40/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1162 - accuracy: 0.9563 - val_loss: 0.1480 - val_accuracy: 0.9542
# Epoch 41/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1211 - accuracy: 0.9530 - val_loss: 0.1503 - val_accuracy: 0.9533
# Epoch 42/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1101 - accuracy: 0.9593 - val_loss: 0.1384 - val_accuracy: 0.9573
# Epoch 43/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1001 - accuracy: 0.9619 - val_loss: 0.1665 - val_accuracy: 0.9475
# Epoch 44/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1071 - accuracy: 0.9587 - val_loss: 0.1971 - val_accuracy: 0.9404
# Epoch 45/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0976 - accuracy: 0.9621 - val_loss: 0.1726 - val_accuracy: 0.9484
# Epoch 46/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0976 - accuracy: 0.9617 - val_loss: 0.1585 - val_accuracy: 0.9444
# Epoch 47/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1002 - accuracy: 0.9631 - val_loss: 0.1671 - val_accuracy: 0.9462
# Epoch 48/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1008 - accuracy: 0.9618 - val_loss: 0.1414 - val_accuracy: 0.9586
# Epoch 49/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0919 - accuracy: 0.9629 - val_loss: 0.1478 - val_accuracy: 0.9586
# Epoch 50/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0811 - accuracy: 0.9697 - val_loss: 0.1338 - val_accuracy: 0.9591
# Epoch 51/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0804 - accuracy: 0.9693 - val_loss: 0.1538 - val_accuracy: 0.9555
# Epoch 52/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0828 - accuracy: 0.9676 - val_loss: 0.1537 - val_accuracy: 0.9555
# Epoch 53/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0766 - accuracy: 0.9711 - val_loss: 0.1369 - val_accuracy: 0.9586
# Epoch 54/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0866 - accuracy: 0.9671 - val_loss: 0.1345 - val_accuracy: 0.9599
# Epoch 55/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0832 - accuracy: 0.9665 - val_loss: 0.1628 - val_accuracy: 0.9564
# Epoch 56/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0878 - accuracy: 0.9661 - val_loss: 0.1320 - val_accuracy: 0.9608
# Epoch 57/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0674 - accuracy: 0.9747 - val_loss: 0.1353 - val_accuracy: 0.9613
# Epoch 58/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0680 - accuracy: 0.9735 - val_loss: 0.1302 - val_accuracy: 0.9648
# Epoch 59/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0648 - accuracy: 0.9764 - val_loss: 0.1388 - val_accuracy: 0.9599
# Epoch 60/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0727 - accuracy: 0.9720 - val_loss: 0.1496 - val_accuracy: 0.9439
# Epoch 61/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0723 - accuracy: 0.9715 - val_loss: 0.1396 - val_accuracy: 0.9582
# Epoch 62/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0600 - accuracy: 0.9777 - val_loss: 0.1457 - val_accuracy: 0.9608
# Epoch 63/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0582 - accuracy: 0.9791 - val_loss: 0.1401 - val_accuracy: 0.9644
# Epoch 64/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0618 - accuracy: 0.9763 - val_loss: 0.1583 - val_accuracy: 0.9622
# Epoch 65/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0801 - accuracy: 0.9704 - val_loss: 0.1659 - val_accuracy: 0.9502
# Epoch 66/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0734 - accuracy: 0.9723 - val_loss: 0.1466 - val_accuracy: 0.9595
# Epoch 67/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0666 - accuracy: 0.9740 - val_loss: 0.1289 - val_accuracy: 0.9626
# Epoch 68/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0498 - accuracy: 0.9828 - val_loss: 0.1379 - val_accuracy: 0.9644
# Epoch 69/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0435 - accuracy: 0.9840 - val_loss: 0.1330 - val_accuracy: 0.9648
# Epoch 70/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0514 - accuracy: 0.9816 - val_loss: 0.1292 - val_accuracy: 0.9680
# Epoch 71/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0448 - accuracy: 0.9844 - val_loss: 0.1349 - val_accuracy: 0.9617
# Epoch 72/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0451 - accuracy: 0.9831 - val_loss: 0.1293 - val_accuracy: 0.9666
# Epoch 73/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0447 - accuracy: 0.9834 - val_loss: 0.1176 - val_accuracy: 0.9720
# Epoch 74/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0389 - accuracy: 0.9860 - val_loss: 0.1406 - val_accuracy: 0.9631
# Epoch 75/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0538 - accuracy: 0.9800 - val_loss: 0.1406 - val_accuracy: 0.9626
# Epoch 76/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0441 - accuracy: 0.9841 - val_loss: 0.1234 - val_accuracy: 0.9666
# Epoch 77/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0515 - accuracy: 0.9810 - val_loss: 0.1915 - val_accuracy: 0.9502
# Epoch 78/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0504 - accuracy: 0.9820 - val_loss: 0.1592 - val_accuracy: 0.9613
# Epoch 79/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0377 - accuracy: 0.9862 - val_loss: 0.1257 - val_accuracy: 0.9666
# Epoch 80/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0336 - accuracy: 0.9884 - val_loss: 0.1288 - val_accuracy: 0.9657
# Epoch 81/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0325 - accuracy: 0.9885 - val_loss: 0.1295 - val_accuracy: 0.9702
# Epoch 82/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0272 - accuracy: 0.9904 - val_loss: 0.1489 - val_accuracy: 0.9706
# Epoch 83/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0233 - accuracy: 0.9929 - val_loss: 0.1379 - val_accuracy: 0.9680
# Epoch 84/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.1310 - val_accuracy: 0.9688
# Epoch 85/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0312 - accuracy: 0.9901 - val_loss: 0.1559 - val_accuracy: 0.9697
# Epoch 86/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 0.1426 - val_accuracy: 0.9729
# Epoch 87/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0284 - accuracy: 0.9904 - val_loss: 0.1422 - val_accuracy: 0.9720
# Epoch 88/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0203 - accuracy: 0.9929 - val_loss: 0.1658 - val_accuracy: 0.9671
# Epoch 89/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0383 - accuracy: 0.9865 - val_loss: 0.1497 - val_accuracy: 0.9604
# Epoch 90/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0601 - accuracy: 0.9771 - val_loss: 0.1667 - val_accuracy: 0.9613
# Epoch 91/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0485 - accuracy: 0.9821 - val_loss: 0.1319 - val_accuracy: 0.9666
# Epoch 92/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0298 - accuracy: 0.9909 - val_loss: 0.1715 - val_accuracy: 0.9706
# Epoch 93/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.1357 - val_accuracy: 0.9662
# Epoch 94/500
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0436 - accuracy: 0.9845 - val_loss: 0.1655 - val_accuracy: 0.9626
# Epoch 95/500
# 71/71 [==============================] - 4s 54ms/step - loss: 0.0356 - accuracy: 0.9872 - val_loss: 0.1162 - val_accuracy: 0.9751
# Epoch 96/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0146 - accuracy: 0.9969 - val_loss: 0.1105 - val_accuracy: 0.9711
# Epoch 97/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0255 - accuracy: 0.9911 - val_loss: 0.1384 - val_accuracy: 0.9693
# Epoch 98/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0295 - accuracy: 0.9890 - val_loss: 0.1164 - val_accuracy: 0.9751
# Epoch 99/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.1104 - val_accuracy: 0.9764
# Epoch 100/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.0983 - val_accuracy: 0.9773
# Epoch 101/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0149 - accuracy: 0.9959 - val_loss: 0.1260 - val_accuracy: 0.9737
# Epoch 102/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0110 - accuracy: 0.9976 - val_loss: 0.1146 - val_accuracy: 0.9733
# Epoch 103/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.1064 - val_accuracy: 0.9769
# Epoch 104/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0129 - accuracy: 0.9952 - val_loss: 0.1284 - val_accuracy: 0.9675
# Epoch 105/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0348 - accuracy: 0.9863 - val_loss: 0.1479 - val_accuracy: 0.9671
# Epoch 106/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.1367 - val_accuracy: 0.9742
# Epoch 107/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0172 - accuracy: 0.9933 - val_loss: 0.1225 - val_accuracy: 0.9742
# Epoch 108/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.1101 - val_accuracy: 0.9742
# Epoch 109/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0216 - accuracy: 0.9920 - val_loss: 0.1670 - val_accuracy: 0.9595
# Epoch 110/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0318 - accuracy: 0.9898 - val_loss: 0.2701 - val_accuracy: 0.9537
# Epoch 111/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0607 - accuracy: 0.9806 - val_loss: 0.1269 - val_accuracy: 0.9724
# Epoch 112/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0529 - accuracy: 0.9829 - val_loss: 0.1154 - val_accuracy: 0.9742
# Epoch 113/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 0.1178 - val_accuracy: 0.9786
# Epoch 114/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.1172 - val_accuracy: 0.9746
# Epoch 115/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.1123 - val_accuracy: 0.9773
# Epoch 116/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.1149 - val_accuracy: 0.9733
# Epoch 117/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0406 - accuracy: 0.9851 - val_loss: 0.1539 - val_accuracy: 0.9635
# Epoch 118/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0327 - accuracy: 0.9878 - val_loss: 0.1337 - val_accuracy: 0.9688
# Epoch 119/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0229 - accuracy: 0.9907 - val_loss: 0.1195 - val_accuracy: 0.9751
# Epoch 120/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.1491 - val_accuracy: 0.9706
# Epoch 121/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.1113 - val_accuracy: 0.9760
# Epoch 122/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.1063 - val_accuracy: 0.9764
# Epoch 123/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.1127 - val_accuracy: 0.9769
# Epoch 124/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.1253 - val_accuracy: 0.9742
# Epoch 125/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.1065 - val_accuracy: 0.9795
# Epoch 126/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.1157 - val_accuracy: 0.9786
# Epoch 127/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.1185 - val_accuracy: 0.9782
# Epoch 128/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0213 - accuracy: 0.9924 - val_loss: 0.1674 - val_accuracy: 0.9617
# Epoch 129/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0279 - accuracy: 0.9892 - val_loss: 0.1345 - val_accuracy: 0.9568
# Epoch 130/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0606 - accuracy: 0.9797 - val_loss: 0.1567 - val_accuracy: 0.9644
# Epoch 131/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0243 - accuracy: 0.9908 - val_loss: 0.1144 - val_accuracy: 0.9742
# Epoch 132/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.1619 - val_accuracy: 0.9680
# Epoch 133/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0150 - accuracy: 0.9941 - val_loss: 0.1215 - val_accuracy: 0.9733
# Epoch 134/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.1352 - val_accuracy: 0.9720
# Epoch 135/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.1006 - val_accuracy: 0.9777
# Epoch 136/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.1533 - val_accuracy: 0.9711
# Epoch 137/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.1216 - val_accuracy: 0.9755
# Epoch 138/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.1226 - val_accuracy: 0.9742
# Epoch 139/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.1421 - val_accuracy: 0.9746
# Epoch 140/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.1063 - val_accuracy: 0.9791
# Epoch 141/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0952 - val_accuracy: 0.9791
# Epoch 142/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.1784 - val_accuracy: 0.9657
# Epoch 143/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.1444 - val_accuracy: 0.9706
# Epoch 144/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0177 - accuracy: 0.9930 - val_loss: 0.1859 - val_accuracy: 0.9693
# Epoch 145/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.1052 - val_accuracy: 0.9782
# Epoch 146/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.1193 - val_accuracy: 0.9795
# Epoch 147/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.1600 - val_accuracy: 0.9702
# Epoch 148/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.1859 - val_accuracy: 0.9653
# Epoch 149/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0513 - accuracy: 0.9838 - val_loss: 0.2592 - val_accuracy: 0.9546
# Epoch 150/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0459 - accuracy: 0.9848 - val_loss: 0.1230 - val_accuracy: 0.9675
# Epoch 151/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.1122 - val_accuracy: 0.9769
# Epoch 152/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.1170 - val_accuracy: 0.9804
# Epoch 153/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.1095 - val_accuracy: 0.9782
# Epoch 154/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.1177 - val_accuracy: 0.9786
# Epoch 155/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1343 - val_accuracy: 0.9742
# Epoch 156/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.1242 - val_accuracy: 0.9777
# Epoch 157/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.1162 - val_accuracy: 0.9795
# Epoch 158/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1208 - val_accuracy: 0.9777
# Epoch 159/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9751
# Epoch 160/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1161 - val_accuracy: 0.9782
# Epoch 161/500
# 71/71 [==============================] - 4s 56ms/step - loss: 9.7450e-04 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9813
# Epoch 162/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.8148e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9795
# Epoch 163/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1193 - val_accuracy: 0.9795
# Epoch 164/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9804
# Epoch 165/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.1328 - val_accuracy: 0.9764
# Epoch 166/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0267 - accuracy: 0.9898 - val_loss: 0.2508 - val_accuracy: 0.9488
# Epoch 167/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0722 - accuracy: 0.9762 - val_loss: 0.1486 - val_accuracy: 0.9648
# Epoch 168/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0300 - accuracy: 0.9889 - val_loss: 0.1060 - val_accuracy: 0.9746
# Epoch 169/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.1340 - val_accuracy: 0.9737
# Epoch 170/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.1287 - val_accuracy: 0.9737
# Epoch 171/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.1200 - val_accuracy: 0.9773
# Epoch 172/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1403 - val_accuracy: 0.9742
# Epoch 173/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.1481 - val_accuracy: 0.9742
# Epoch 174/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.1598 - val_accuracy: 0.9764
# Epoch 175/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1306 - val_accuracy: 0.9769
# Epoch 176/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.8070e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9773
# Epoch 177/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.6771e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9782
# Epoch 178/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9773
# Epoch 179/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.7063e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9800
# Epoch 180/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.6749e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9782
# Epoch 181/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.2619e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9769
# Epoch 182/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.2130e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9786
# Epoch 183/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.2859e-04 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9777
# Epoch 184/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.0214e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9786
# Epoch 185/500
# 71/71 [==============================] - 4s 56ms/step - loss: 9.3964e-04 - accuracy: 0.9999 - val_loss: 0.1250 - val_accuracy: 0.9769
# Epoch 186/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.0303e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9777
# Epoch 187/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1284 - val_accuracy: 0.9773
# Epoch 188/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.1636 - val_accuracy: 0.9711
# Epoch 189/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0873 - accuracy: 0.9740 - val_loss: 0.1358 - val_accuracy: 0.9577
# Epoch 190/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0496 - accuracy: 0.9823 - val_loss: 0.1561 - val_accuracy: 0.9702
# Epoch 191/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.1254 - val_accuracy: 0.9733
# Epoch 192/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.1363 - val_accuracy: 0.9751
# Epoch 193/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0963 - val_accuracy: 0.9760
# Epoch 194/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.1098 - val_accuracy: 0.9782
# Epoch 195/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9795
# Epoch 196/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.1075 - val_accuracy: 0.9786
# Epoch 197/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.1118 - val_accuracy: 0.9791
# Epoch 198/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.4702e-04 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9773
# Epoch 199/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.4275e-04 - accuracy: 1.0000 - val_loss: 0.1126 - val_accuracy: 0.9777
# Epoch 200/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.1875e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9786
# Epoch 201/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.2743e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9773
# Epoch 202/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.0002e-04 - accuracy: 0.9999 - val_loss: 0.1219 - val_accuracy: 0.9786
# Epoch 203/500
# 71/71 [==============================] - 4s 57ms/step - loss: 5.5538e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9795
# Epoch 204/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.5611e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9777
# Epoch 205/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 0.1218 - val_accuracy: 0.9769
# Epoch 206/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0214 - accuracy: 0.9921 - val_loss: 0.1539 - val_accuracy: 0.9711
# Epoch 207/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0276 - accuracy: 0.9925 - val_loss: 0.2675 - val_accuracy: 0.9430
# Epoch 208/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.1168 - accuracy: 0.9676 - val_loss: 0.1763 - val_accuracy: 0.9533
# Epoch 209/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0307 - accuracy: 0.9891 - val_loss: 0.1336 - val_accuracy: 0.9688
# Epoch 210/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 0.1043 - val_accuracy: 0.9751
# Epoch 211/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.1096 - val_accuracy: 0.9773
# Epoch 212/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1106 - val_accuracy: 0.9773
# Epoch 213/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.1021 - val_accuracy: 0.9791
# Epoch 214/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.3992e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9782
# Epoch 215/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.6202e-04 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9773
# Epoch 216/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.3826e-04 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9769
# Epoch 217/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.0863e-04 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9782
# Epoch 218/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.8714e-04 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 0.9791
# Epoch 219/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.8865e-04 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9782
# Epoch 220/500
# 71/71 [==============================] - 4s 57ms/step - loss: 4.6898e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9786
# Epoch 221/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.9058e-04 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9773
# Epoch 222/500
# 71/71 [==============================] - 4s 56ms/step - loss: 3.9209e-04 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9782
# Epoch 223/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.2907e-04 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9760
# Epoch 224/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.1223 - val_accuracy: 0.9795
# Epoch 225/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1226 - val_accuracy: 0.9773
# Epoch 226/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.1135 - val_accuracy: 0.9786
# Epoch 227/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.7651e-04 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9773
# Epoch 228/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1218 - val_accuracy: 0.9764
# Epoch 229/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0540 - accuracy: 0.9835 - val_loss: 0.1633 - val_accuracy: 0.9533
# Epoch 230/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0377 - accuracy: 0.9856 - val_loss: 0.1795 - val_accuracy: 0.9640
# Epoch 231/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.1192 - val_accuracy: 0.9755
# Epoch 232/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.1104 - val_accuracy: 0.9764
# Epoch 233/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1329 - val_accuracy: 0.9804
# Epoch 234/500
# 71/71 [==============================] - 4s 56ms/step - loss: 9.2813e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9782
# Epoch 235/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.6510e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9800
# Epoch 236/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1318 - val_accuracy: 0.9782
# Epoch 237/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.1497e-04 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 0.9769
# Epoch 238/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.1889e-04 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9773
# Epoch 239/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.1480e-04 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 0.9786
# Epoch 240/500
# 71/71 [==============================] - 4s 56ms/step - loss: 3.9554e-04 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9782
# Epoch 241/500
# 71/71 [==============================] - 4s 56ms/step - loss: 3.0537e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9795
# Epoch 242/500
# 71/71 [==============================] - 4s 56ms/step - loss: 3.4416e-04 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9773
# Epoch 243/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.4380e-04 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9795
# Epoch 244/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.0812e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9777
# Epoch 245/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.3968e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9782
# Epoch 246/500
# 71/71 [==============================] - 4s 56ms/step - loss: 3.6803e-04 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9795
# Epoch 247/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.8005e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9804
# Epoch 248/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.5127e-04 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9800
# Epoch 249/500
# 71/71 [==============================] - 4s 59ms/step - loss: 6.9507e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9804
# Epoch 250/500
# 71/71 [==============================] - 4s 57ms/step - loss: 2.2199e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9782
# Epoch 251/500
# 71/71 [==============================] - 4s 58ms/step - loss: 1
500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.1043 - val_accuracy: 0.9755
# Epoch 417/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.0207 - accuracy: 0.9927 - val_loss: 0.1674 - val_accuracy: 0.9680
# Epoch 418/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.1180 - val_accuracy: 0.9777
# Epoch 419/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.1032 - val_accuracy: 0.9777
# Epoch 420/500
# 71/71 [==============================] - 4s 56ms/step - loss: 9.6630e-04 - accuracy: 0.9999 - val_loss: 0.0977 - val_accuracy: 0.9804
# Epoch 421/500
# 71/71 [==============================] - 4s 56ms/step - loss: 3.8408e-04 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 0.9809
# Epoch 422/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.7461e-04 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9804
# Epoch 423/500
# 71/71 [==============================] - 4s 56ms/step - loss: 3.3110e-04 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9813
# Epoch 424/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.6651e-04 - accuracy: 1.0000 - val_loss: 0.1078 - val_accuracy: 0.9813
# Epoch 425/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.2851e-04 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9813
# Epoch 426/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.3406e-04 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9818
# Epoch 427/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.1223e-04 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9818
# Epoch 428/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.1722e-04 - accuracy: 1.0000 - val_loss: 0.1106 - val_accuracy: 0.9809
# Epoch 429/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.8004e-04 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9809
# Epoch 430/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.6784e-04 - accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9804
# Epoch 431/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.1305e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9813
# Epoch 432/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.3542e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9813
# Epoch 433/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.3849e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9804
# Epoch 434/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.5441e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9818
# Epoch 435/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.3729e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9813
# Epoch 436/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.2629e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9809
# Epoch 437/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.1720e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9809
# Epoch 438/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.2602e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9795
# Epoch 439/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.4476e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9804
# Epoch 440/500
# 71/71 [==============================] - 4s 56ms/step - loss: 9.2262e-05 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9813
# Epoch 441/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.0657e-05 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9813
# Epoch 442/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.0250e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9809
# Epoch 443/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.8804e-05 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9804
# Epoch 444/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.5880e-05 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9795
# Epoch 445/500
# 71/71 [==============================] - 4s 56ms/step - loss: 9.1865e-05 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9795
# Epoch 446/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.3152e-05 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9818
# Epoch 447/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.7937e-05 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9804
# Epoch 448/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.5583e-05 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9818
# Epoch 449/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.2836e-05 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9813
# Epoch 450/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.8219e-05 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9813
# Epoch 451/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.4179e-05 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9813
# Epoch 452/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.1987e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9800
# Epoch 453/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.3005e-05 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9795
# Epoch 454/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.1108e-05 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9813
# Epoch 455/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.1794e-05 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9822
# Epoch 456/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.2200e-05 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9818
# Epoch 457/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.2026e-05 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9804
# Epoch 458/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.5572e-05 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9822
# Epoch 459/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.2664e-05 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9818
# Epoch 460/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.1702e-05 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9813
# Epoch 461/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.7892e-05 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9804
# Epoch 462/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.3321e-04 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9809
# Epoch 463/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0620 - accuracy: 0.9840 - val_loss: 0.2619 - val_accuracy: 0.9413
# Epoch 464/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0422 - accuracy: 0.9858 - val_loss: 0.1322 - val_accuracy: 0.9720
# Epoch 465/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.1141 - val_accuracy: 0.9795
# Epoch 466/500
# 71/71 [==============================] - 4s 56ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.1190 - val_accuracy: 0.9786
# Epoch 467/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.6386e-04 - accuracy: 1.0000 - val_loss: 0.1106 - val_accuracy: 0.9800
# Epoch 468/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.8371e-04 - accuracy: 0.9998 - val_loss: 0.1174 - val_accuracy: 0.9809
# Epoch 469/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.3061e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9809
# Epoch 470/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.9585e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9800
# Epoch 471/500
# 71/71 [==============================] - 4s 56ms/step - loss: 2.3738e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9795
# Epoch 472/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.8796e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9800
# Epoch 473/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.7735e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9804
# Epoch 474/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.7946e-04 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9791
# Epoch 475/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.7855e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9800
# Epoch 476/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.2994e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9809
# Epoch 477/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.1511e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9809
# Epoch 478/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.4064e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9804
# Epoch 479/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.4903e-04 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9800
# Epoch 480/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.5953e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9813
# Epoch 481/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.5886e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9813
# Epoch 482/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.1926e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9804
# Epoch 483/500
# 71/71 [==============================] - 4s 56ms/step - loss: 1.3454e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9800
# Epoch 484/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.9604e-05 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9795
# Epoch 485/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.0433e-05 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9804
# Epoch 486/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.9519e-05 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9809
# Epoch 487/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.0959e-05 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9804
# Epoch 488/500
# 71/71 [==============================] - 4s 56ms/step - loss: 8.7724e-05 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9813
# Epoch 489/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.6185e-05 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9813
# Epoch 490/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.6936e-05 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9809
# Epoch 491/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.4689e-05 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9822
# Epoch 492/500
# 71/71 [==============================] - 4s 56ms/step - loss: 6.6428e-05 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9813
# Epoch 493/500
# 71/71 [==============================] - 4s 56ms/step - loss: 7.5059e-05 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9800
# Epoch 494/500
# 71/71 [==============================] - 4s 57ms/step - loss: 4.4062e-05 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9809
# Epoch 495/500
# 71/71 [==============================] - 4s 57ms/step - loss: 5.5463e-05 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9813
# Epoch 496/500
# 71/71 [==============================] - 4s 56ms/step - loss: 5.6060e-05 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9813
# Epoch 497/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.8500e-05 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9809
# Epoch 498/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.5135e-05 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9818
# Epoch 499/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.2716e-05 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9813
# Epoch 500/500
# 71/71 [==============================] - 4s 56ms/step - loss: 4.6274e-05 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9813

# %% [markdown]
# # Evaluate the Model using test data

# %%
Test_DATADIR = "D:/Project2022/res/split_dataset/original/test"
dataset_df = pre_process_dataset(Test_DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/1430 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/1379 [00:00<?, ?it/s]

# %%
print("No of test sample:", len(dataset_df))
# Out:
# No of test sample: 2809

# %%
X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test, Y_test = process_data(dataset_df)
# Out:
# X1 shape (2809, 512, 1)
# X2 shape (2809, 512, 1)
# X3 shape (2809, 256, 1)
# Mid rows shape (2809, 256, 1)
# X4 shape (2809, 256, 1)
# X5 shape (2809, 256, 1)
# Mid Cols shape (2809, 256, 1)
# X6 shape (2809, 256, 1)
# y shape (2809, 1)

# %%
# test loss, test accuracy
accuracy = model.evaluate([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test], Y_test, batch_size=100, verbose=0)

# %%
print("Test acuuracy", accuracy[1])
print("Test loss", accuracy[0])
# Out:
# Test acuuracy 0.9861160516738892
# Test loss 0.10374238342046738

# %%
#y_pred = model.predict_classes(X_test)
y_pred = (model.predict([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test]) > 0.5).astype("int32")
# Out:
# 88/88 [==============================] - 2s 13ms/step

# %%
print(classification_report(Y_test, y_pred, target_names=["covid", "Normal"]))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.99      0.98      0.99      1430
#       Normal       0.98      0.99      0.99      1379
#
#     accuracy                           0.99      2809
#    macro avg       0.99      0.99      0.99      2809
# weighted avg       0.99      0.99      0.99      2809

# %%
cm = confusion_matrix(Y_test, y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=["Covid","Normal"])
disp.plot()
plt.show()

# %%
s = "12:40:22AM"

# %%
def timeConversion(s):
    
    hr = int(s[:2])
    
    if "AM" in s:
        if hr == 12:
            return "00"+s[2:8]
        else:
            return s[:8]

    if "PM" in s:
        if hr == 12:
            return s[:8]
        else:
            hr = hr+12
            return str(hr)+s[2:8]

# %%
res = timeConversion(s) 
print(res)
# Out:
# 00:40:22

# %%
pip install tf-explain
# Out:
# Requirement already satisfied: tf-explain in c:\users\ranji\anaconda3\envs\tensorflow\lib\site-packages (0.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tensorflow\lib\site-packages (from opencv-python) (1.20.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
import tf_explain as tf_g
