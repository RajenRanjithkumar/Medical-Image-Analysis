# %%
#mask
import json
import cv2
import os
import pandas as pd 
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
import keras
from keras.preprocessing import image
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers, models

from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical

from keras.layers import Input
from keras.models import Model
from keras.layers import concatenate
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten 
from keras.layers import Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import to_categorical
import xml.etree.ElementTree as ET
from tensorflow.keras.callbacks import TensorBoard

from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (from h5py) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
model_name = "mutiple_Conv1D_8_inputs_scaled_modified"
model = keras.models.load_model("D:/Project2022/models/"+model_name+".h5")

# %%
import time
model_name = "32_inputs_raw"
NAME = model_name+"-{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir = 'logs/{}'.format(NAME))

# %%
CATEGORIES = ["covid", "normal"]
DATADIR = "D:/Project2022/res/split_dataset/original/train"

# %%
def split_image_vertical(img_array):

    mid_v = int(img_array.shape[1]/4)
    LH_img = img_array[: , :int(img_array.shape[1]/2)]
    #plt.imshow(LH_img, cmap="gray")
    #plt.show()

     # mid vertical
    mid_ver = img_array[:, int((img_array.shape[1]/2)-mid_v):int((img_array.shape[1]/2)+mid_v)]
    #plt.imshow(mid_ver, cmap="gray")
    #plt.show()
    
    #Right half
    RH_img = img_array[: , int(img_array.shape[1]/2):]
    #plt.imshow(RH_img, cmap="gray")
    #plt.show()

    #print("----------------------------------------------------------")
    return [LH_img, mid_ver, RH_img]

# %%
def split_image_horizontal(img_array):
    mid_h = int(img_array.shape[0]/4)
    #top half
    TC_img = img_array[:int(img_array.shape[0]/2) , :]
    #plt.imshow(TC_img, cmap="gray")
    #plt.show()

    #mid horizontal
    mid_hor = img_array[int((img_array.shape[0]/2)-mid_h):int((img_array.shape[0]/2)+mid_h), :]
    #plt.imshow(mid_hor, cmap="gray")
    #plt.show()

    #bottom half
    BC_img =  img_array[int(img_array.shape[0]/2): , :]
    #plt.imshow(BC_img, cmap="gray")
    #plt.show()

    #print("############################################################")

    return [TC_img, mid_hor, BC_img]

# %%
def get_image(img_array):
    raw_data = []
    
    raw_data.append(img_array.sum(axis=0))
    raw_data.append(img_array.sum(axis=1))

    #print("Vetical splits")
    first_split_ver = split_image_vertical(img_array)


    for img in first_split_ver:
        raw_data.append(img.sum(axis=1))
        temp = split_image_vertical(img)
        for subset in temp:
            raw_data.append(subset.sum(axis=1))


    #print("Horizontal splits")
    first_split_hor = split_image_horizontal(img_array)
    for img in first_split_hor:
        raw_data.append(img.sum(axis=0))
        temp = split_image_horizontal(img)
        for subset in temp:
            raw_data.append(subset.sum(axis=0))
        
    return raw_data

# %%
for categoty in CATEGORIES:
    path = os.path.join(DATADIR, categoty)  # path to Covid or Nprmal
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
        plt.imshow(img_array, cmap="gray")
        plt.show()

    
        temp = get_image(img_array)
        print(len(temp))

        break
    break
# Out:
# 26

# %%
def pre_process_dataset(dataset_path):

    df_data = pd.DataFrame()
    dataset = []
    label = []

    for categoty in CATEGORIES:
        path = os.path.join(dataset_path, categoty)  
        
        class_num = CATEGORIES.index(categoty)
        
        print("Loading dataset: class",categoty)
        for img in tqdm(os.listdir(path)):

            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
                data = get_image(img_array)
                            
                dataset.append(data)
                label.append(class_num)
                
            except Exception as e:
                pass
    df_data["data_26"] = dataset
    df_data["label"] = label

    return df_data

# %%
dataset_df = pre_process_dataset(DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/5719 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/5514 [00:00<?, ?it/s]

# %%
dataset_df.head()
# Out:
#                                              data_26  label
# 0  [[4576, 8086, 10445, 12245, 14048, 15508, 1667...      0
# 1  [[12508, 12672, 12653, 12882, 13104, 13177, 13...      0
# 2  [[2156, 2300, 2172, 2163, 2207, 2268, 2194, 23...      0
# 3  [[2417, 2502, 2556, 2661, 2882, 3103, 3152, 30...      0
# 4  [[3923, 3983, 4025, 4110, 4234, 4291, 4367, 49...      0

# %%
df_train, df_val = train_test_split(dataset_df, test_size=0.3, random_state=0)

# %%
df_train["label"].value_counts()
# Out:
# 0    4041
# 1    3822
# Name: label, dtype: int64

# %%
print("No of Training samples:",len(df_train))
print("No of Validation samples:",len(df_val))
# Out:
# No of Training samples: 7863
# No of Validation samples: 3370

# %%
for sample in dataset_df["data_26"]:
    print(len(sample[0]))
    break
# Out:
# 512

# %%
X1 = [img[0] for img in dataset_df["data_26"]]
X1 = np.array(X1)
X1 = preprocessing.normalize(X1)
X1 = np.expand_dims(X1, axis=-1)

# %%
from sklearn import preprocessing
def type_conversion(feature):

    X = [img[feature] for img in df_val["data_26"]]
    X = np.array(X)
    X = preprocessing.normalize(X)
    X = np.expand_dims(X, axis=-1)

    return X

# %%
from sklearn import preprocessing

def process_data(dataset_df):
    
    
    # global
    X1 = type_conversion(0)
    X2 = type_conversion(1)
    X3 = type_conversion(2)
    X4 = type_conversion(3)
    X5 = type_conversion(4)
    X6 = type_conversion(5)
    X7 = type_conversion(6)
    X8 = type_conversion(7)
    X9 = type_conversion(8)
    X10 = type_conversion(9)
    X11 = type_conversion(10)
    X12 = type_conversion(11)
    X13 = type_conversion(12)
    X14 = type_conversion(13)
    X15 = type_conversion(14)
    X16 = type_conversion(15)
    X17 = type_conversion(16)
    X18 = type_conversion(17)
    X19 = type_conversion(18)
    X20 = type_conversion(19)
    X21 = type_conversion(20)
    X22 = type_conversion(21)
    X23 = type_conversion(22)
    X24 = type_conversion(23)
    X25 = type_conversion(24)
    X26 = type_conversion(25)
    
    y = np.array(dataset_df["label"].values)
    y = np.expand_dims(y, axis=-1)


    print("X1 shape", X1.shape)
    print("X2 shape", X2.shape)
    print("X3 shape", X3.shape)
    print("X4 shape", X4.shape)
    print("X5 shape", X5.shape)
    print("X6 shape", X6.shape)
    print("X7 shape", X7.shape)
    print("X8 shape", X8.shape)
    print("X9 shape", X9.shape)
    print("X10 shape", X10.shape)
    print("X11 shape", X11.shape)
    print("X12 shape", X12.shape)
    print("X13 shape", X13.shape)
    print("X14 shape", X14.shape)
    print("X15 shape", X15.shape)
    print("X16 shape", X16.shape)
    print("X17 shape", X17.shape)
    print("X18 shape", X18.shape)
    print("X19 shape", X19.shape)
    print("X20 shape", X20.shape)
    print("X21 shape", X21.shape)
    print("X22 shape", X22.shape)
    print("X23 shape", X23.shape)
    print("X24 shape", X24.shape)
    print("X25 shape", X25.shape)
    print("X26 shape", X26.shape)
    

    print("y shape", y.shape)
            #X 0 t0 25
            #y 26
    return [X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X20, X21, X22, X23, X24, X25, X26, y]

# %%
print("Training samples:")
train_data = process_data(df_train)
# Out:
# Training samples:
# X1 shape (7863, 512, 1)
# X2 shape (7863, 512, 1)
# X3 shape (7863, 512, 1)
# X4 shape (7863, 512, 1)
# X5 shape (7863, 512, 1)
# X6 shape (7863, 512, 1)
# X7 shape (7863, 512, 1)
# X8 shape (7863, 512, 1)
# X9 shape (7863, 512, 1)
# X10 shape (7863, 512, 1)
# X11 shape (7863, 512, 1)
# X12 shape (7863, 512, 1)
# X13 shape (7863, 512, 1)
# X14 shape (7863, 512, 1)
# X15 shape (7863, 512, 1)
# X16 shape (7863, 512, 1)
# X17 shape (7863, 512, 1)
# X18 shape (7863, 512, 1)
# X19 shape (7863, 512, 1)
# X20 shape (7863, 512, 1)
# X21 shape (7863, 512, 1)
# X22 shape (7863, 512, 1)
# X23 shape (7863, 512, 1)
# X24 shape (7863, 512, 1)
# X25 shape (7863, 512, 1)
# X26 shape (7863, 512, 1)
# y shape (7863, 1)

# %%
print("Validation samples:")
val_data = process_data(df_val)
# Out:
# Validation samples:
# X1 shape (3370, 512, 1)
# X2 shape (3370, 512, 1)
# X3 shape (3370, 512, 1)
# X4 shape (3370, 512, 1)
# X5 shape (3370, 512, 1)
# X6 shape (3370, 512, 1)
# X7 shape (3370, 512, 1)
# X8 shape (3370, 512, 1)
# X9 shape (3370, 512, 1)
# X10 shape (3370, 512, 1)
# X11 shape (3370, 512, 1)
# X12 shape (3370, 512, 1)
# X13 shape (3370, 512, 1)
# X14 shape (3370, 512, 1)
# X15 shape (3370, 512, 1)
# X16 shape (3370, 512, 1)
# X17 shape (3370, 512, 1)
# X18 shape (3370, 512, 1)
# X19 shape (3370, 512, 1)
# X20 shape (3370, 512, 1)
# X21 shape (3370, 512, 1)
# X22 shape (3370, 512, 1)
# X23 shape (3370, 512, 1)
# X24 shape (3370, 512, 1)
# X25 shape (3370, 512, 1)
# X26 shape (3370, 512, 1)
# y shape (3370, 1)

# %%
def conv1D_layer(input, nodes):
    #Input(shape=(367,1))
    #input_layer = Input(shape=inputSize)
    #kernel size- 5
    # nodes - 16
    conv1 = Conv1D(nodes, kernel_size=5, activation='relu')(input)
    drop1 = Dropout(0.25)(conv1)
    pool1 = MaxPooling1D(pool_size=2)(drop1)
    flat = Flatten()(pool1)
    return flat

# %% [markdown]
# ## Modified

# %%
# first input model
X1 = Input(shape=(512,1))
flat1 = conv1D_layer(X1, 16)

# second input model
X2 = Input(shape=(512,1))
flat2 = conv1D_layer(X2, 16)

#####################################################################

X3 = Input(shape=(512,1))
flat3 = conv1D_layer(X3, 16)

X4 = Input(shape=(512,1))
flat4 = conv1D_layer(X4, 16)

X5 = Input(shape=(512,1))
flat5 = conv1D_layer(X5, 16)

X6 = Input(shape=(512,1))
flat6 = conv1D_layer(X6, 16)

X7 = Input(shape=(512,1))
flat7 = conv1D_layer(X7, 16)

X8 = Input(shape=(512,1))
flat8 = conv1D_layer(X8, 16)

X9 = Input(shape=(512,1))
flat9 = conv1D_layer(X9, 16)

X10 = Input(shape=(512,1))
flat10 = conv1D_layer(X10, 16)

X11 = Input(shape=(512,1))
flat11 = conv1D_layer(X11, 16)

X12 = Input(shape=(512,1))
flat12 = conv1D_layer(X12, 16)







LH = Input(shape=(512,1))
flat3 = conv1D_layer(LH, 16)

row_mid = Input(shape=(252,1))
flat4 = conv1D_layer(row_mid, 16)

RH = Input(shape=(512,1))
flat5 = conv1D_layer(RH, 16)


TC = Input(shape=(512,1))
flat6 = conv1D_layer(LH, 16)

col_mid = Input(shape=(512,1))
flat7 = conv1D_layer(col_mid, 16)

BC = Input(shape=(512,1))
flat8 = conv1D_layer(BC, 16)


merge_all = concatenate([flat_row, flat_col, flat3, flat4, flat5, flat6, flat7,flat8])
#32
hidden_all_1 = Dense(32, activation='relu')(merge_all)
#16
hidden_all_2 = Dense(16, activation='relu')(hidden_all_1)

output = Dense(1, activation='sigmoid')(hidden_all_2)
model = Model(inputs=[row, col, LH, row_mid, RH, TC, col_mid, BC], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Project2022\Code\project2022\simplified\26_inputs copy.ipynb Cell 24 in <cell line: 61>()
#      <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/26_inputs%20copy.ipynb#X24sZmlsZQ%3D%3D?line=56'>57</a> BC = Input(shape=(512,1))
#      <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/26_inputs%20copy.ipynb#X24sZmlsZQ%3D%3D?line=57'>58</a> flat8 = conv1D_layer(BC, 16)
# ---> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/26_inputs%20copy.ipynb#X24sZmlsZQ%3D%3D?line=60'>61</a> merge_all = concatenate([flat_row, flat_col, flat3, flat4, flat5, flat6, flat7,flat8])
#      <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/26_inputs%20copy.ipynb#X24sZmlsZQ%3D%3D?line=61'>62</a> #32
#      <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/26_inputs%20copy.ipynb#X24sZmlsZQ%3D%3D?line=62'>63</a> hidden_all_1 = Dense(32, activation='relu')(merge_all)
#
# NameError: name 'flat_row' is not defined

# %%
BATCH_SIZE = 128
EPOCHS = 500
history = model.fit(
    [X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train],
    Y_train,
    BATCH_SIZE,
    EPOCHS,
    validation_data=([X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val], Y_val),
    callbacks=[tensorboard])

model.save("D:/Project2022/models/"+model_name+".h5")
# Out:
# Epoch 1/500
# 71/71 [==============================] - 19s 83ms/step - loss: 0.5968 - accuracy: 0.7210 - val_loss: 0.5300 - val_accuracy: 0.7980
# Epoch 2/500
# 71/71 [==============================] - 5s 67ms/step - loss: 0.4757 - accuracy: 0.7901 - val_loss: 0.4622 - val_accuracy: 0.8051
# Epoch 3/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.4381 - accuracy: 0.8041 - val_loss: 0.4318 - val_accuracy: 0.8166
# Epoch 4/500
# 71/71 [==============================] - 5s 67ms/step - loss: 0.4250 - accuracy: 0.8106 - val_loss: 0.4322 - val_accuracy: 0.8184
# Epoch 5/500
# 71/71 [==============================] - 5s 67ms/step - loss: 0.4052 - accuracy: 0.8198 - val_loss: 0.4035 - val_accuracy: 0.8322
# Epoch 6/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3890 - accuracy: 0.8314 - val_loss: 0.3932 - val_accuracy: 0.8389
# Epoch 7/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3862 - accuracy: 0.8283 - val_loss: 0.3940 - val_accuracy: 0.8478
# Epoch 8/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3703 - accuracy: 0.8440 - val_loss: 0.3788 - val_accuracy: 0.8540
# Epoch 9/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3698 - accuracy: 0.8416 - val_loss: 0.3704 - val_accuracy: 0.8518
# Epoch 10/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3671 - accuracy: 0.8462 - val_loss: 0.3598 - val_accuracy: 0.8580
# Epoch 11/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3582 - accuracy: 0.8492 - val_loss: 0.3695 - val_accuracy: 0.8487
# Epoch 12/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3517 - accuracy: 0.8540 - val_loss: 0.3556 - val_accuracy: 0.8634
# Epoch 13/500
# 71/71 [==============================] - 5s 67ms/step - loss: 0.3492 - accuracy: 0.8544 - val_loss: 0.3499 - val_accuracy: 0.8647
# Epoch 14/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3380 - accuracy: 0.8580 - val_loss: 0.3559 - val_accuracy: 0.8629
# Epoch 15/500
# 71/71 [==============================] - 5s 67ms/step - loss: 0.3604 - accuracy: 0.8469 - val_loss: 0.3529 - val_accuracy: 0.8625
# Epoch 16/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3368 - accuracy: 0.8573 - val_loss: 0.3489 - val_accuracy: 0.8652
# Epoch 17/500
# 71/71 [==============================] - 5s 67ms/step - loss: 0.3332 - accuracy: 0.8610 - val_loss: 0.3346 - val_accuracy: 0.8696
# Epoch 18/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3276 - accuracy: 0.8632 - val_loss: 0.3333 - val_accuracy: 0.8696
# Epoch 19/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3325 - accuracy: 0.8620 - val_loss: 0.3302 - val_accuracy: 0.8714
# Epoch 20/500
# 71/71 [==============================] - 5s 66ms/step - loss: 0.3260 - accuracy: 0.8648 - val_loss: 0.3272 - val_accuracy: 0.8678
# Epoch 21/500
# 71/71 [==============================] - 5s 67ms/step - loss: 0.3149 - accuracy: 0.8706 - val_loss: 0.3299 - val_accuracy: 0.8638
# Epoch 22/500
# 71/71 [==============================] - 5s 68ms/step - loss: 0.3130 - accuracy: 0.8722 - val_loss: 0.3227 - val_accuracy: 0.8767
# Epoch 23/500
# 71/71 [==============================] - 5s 69ms/step - loss: 0.3103 - accuracy: 0.8774 - val_loss: 0.3550 - val_accuracy: 0.8514
# Epoch 24/500
# 71/71 [==============================] - 5s 68ms/step - loss: 0.3198 - accuracy: 0.8673 - val_loss: 0.3270 - val_accuracy: 0.8705
# Epoch 25/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.3092 - accuracy: 0.8764 - val_loss: 0.3189 - val_accuracy: 0.8789
# Epoch 26/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2999 - accuracy: 0.8778 - val_loss: 0.3087 - val_accuracy: 0.8816
# Epoch 27/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.3034 - accuracy: 0.8770 - val_loss: 0.3133 - val_accuracy: 0.8812
# Epoch 28/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2982 - accuracy: 0.8788 - val_loss: 0.3419 - val_accuracy: 0.8563
# Epoch 29/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2929 - accuracy: 0.8800 - val_loss: 0.3214 - val_accuracy: 0.8767
# Epoch 30/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2893 - accuracy: 0.8817 - val_loss: 0.3162 - val_accuracy: 0.8763
# Epoch 31/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.3018 - accuracy: 0.8804 - val_loss: 0.2934 - val_accuracy: 0.8865
# Epoch 32/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2859 - accuracy: 0.8855 - val_loss: 0.3180 - val_accuracy: 0.8803
# Epoch 33/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2756 - accuracy: 0.8895 - val_loss: 0.2908 - val_accuracy: 0.8856
# Epoch 34/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2820 - accuracy: 0.8860 - val_loss: 0.2899 - val_accuracy: 0.8954
# Epoch 35/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2845 - accuracy: 0.8852 - val_loss: 0.3003 - val_accuracy: 0.8838
# Epoch 36/500
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2666 - accuracy: 0.8968 - val_loss: 0.2984 - val_accuracy: 0.8847
# Epoch 37/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2627 - accuracy: 0.8956 - val_loss: 0.2873 - val_accuracy: 0.8972
# Epoch 38/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2635 - accuracy: 0.8948 - val_loss: 0.2973 - val_accuracy: 0.8910
# Epoch 39/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2680 - accuracy: 0.8931 - val_loss: 0.2867 - val_accuracy: 0.8923
# Epoch 40/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2550 - accuracy: 0.9001 - val_loss: 0.2731 - val_accuracy: 0.8941
# Epoch 41/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2493 - accuracy: 0.9035 - val_loss: 0.2998 - val_accuracy: 0.8821
# Epoch 42/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2522 - accuracy: 0.9010 - val_loss: 0.2585 - val_accuracy: 0.9034
# Epoch 43/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2519 - accuracy: 0.9014 - val_loss: 0.2676 - val_accuracy: 0.9025
# Epoch 44/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2415 - accuracy: 0.9071 - val_loss: 0.2765 - val_accuracy: 0.8887
# Epoch 45/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2538 - accuracy: 0.9003 - val_loss: 0.2922 - val_accuracy: 0.8781
# Epoch 46/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2420 - accuracy: 0.9070 - val_loss: 0.2501 - val_accuracy: 0.9074
# Epoch 47/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2394 - accuracy: 0.9054 - val_loss: 0.2685 - val_accuracy: 0.9043
# Epoch 48/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2298 - accuracy: 0.9103 - val_loss: 0.2787 - val_accuracy: 0.9021
# Epoch 49/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2302 - accuracy: 0.9083 - val_loss: 0.2545 - val_accuracy: 0.9074
# Epoch 50/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2207 - accuracy: 0.9156 - val_loss: 0.2433 - val_accuracy: 0.9159
# Epoch 51/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2165 - accuracy: 0.9166 - val_loss: 0.2428 - val_accuracy: 0.9101
# Epoch 52/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2165 - accuracy: 0.9187 - val_loss: 0.2436 - val_accuracy: 0.9128
# Epoch 53/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2324 - accuracy: 0.9106 - val_loss: 0.2460 - val_accuracy: 0.9043
# Epoch 54/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2176 - accuracy: 0.9165 - val_loss: 0.2492 - val_accuracy: 0.9070
# Epoch 55/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2242 - accuracy: 0.9118 - val_loss: 0.2996 - val_accuracy: 0.8781
# Epoch 56/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2206 - accuracy: 0.9134 - val_loss: 0.2590 - val_accuracy: 0.9070
# Epoch 57/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2092 - accuracy: 0.9168 - val_loss: 0.2666 - val_accuracy: 0.8945
# Epoch 58/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2123 - accuracy: 0.9175 - val_loss: 0.2434 - val_accuracy: 0.9159
# Epoch 59/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2083 - accuracy: 0.9195 - val_loss: 0.2610 - val_accuracy: 0.8990
# Epoch 60/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2022 - accuracy: 0.9215 - val_loss: 0.2196 - val_accuracy: 0.9217
# Epoch 61/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2102 - accuracy: 0.9193 - val_loss: 0.2323 - val_accuracy: 0.9217
# Epoch 62/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1984 - accuracy: 0.9249 - val_loss: 0.2257 - val_accuracy: 0.9199
# Epoch 63/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1932 - accuracy: 0.9270 - val_loss: 0.2728 - val_accuracy: 0.8923
# Epoch 64/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2034 - accuracy: 0.9248 - val_loss: 0.2265 - val_accuracy: 0.9154
# Epoch 65/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1970 - accuracy: 0.9261 - val_loss: 0.2225 - val_accuracy: 0.9212
# Epoch 66/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1869 - accuracy: 0.9298 - val_loss: 0.2388 - val_accuracy: 0.9105
# Epoch 67/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1939 - accuracy: 0.9238 - val_loss: 0.2280 - val_accuracy: 0.9199
# Epoch 68/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1863 - accuracy: 0.9316 - val_loss: 0.2314 - val_accuracy: 0.9114
# Epoch 69/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2039 - accuracy: 0.9227 - val_loss: 0.2091 - val_accuracy: 0.9261
# Epoch 70/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1798 - accuracy: 0.9331 - val_loss: 0.2213 - val_accuracy: 0.9163
# Epoch 71/500
# 71/71 [==============================] - 4s 57ms/step - loss: 0.1817 - accuracy: 0.9290 - val_loss: 0.2131 - val_accuracy: 0.9270
# Epoch 72/500
# 48/71 [===================>..........] - ETA: 1s - loss: 0.1805 - accuracy: 0.9295
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Project2022\Code\project2022\simplified\6_inputs.ipynb Cell 19 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> BATCH_SIZE = 128
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> EPOCHS = 500
# ----> <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> history = model.fit(
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     [X1_train, X2_train, X3_train,  X4_train, X5_train,  X6_train],
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     Y_train,
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a>     BATCH_SIZE,
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a>     EPOCHS,
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a>     validation_data=([X1_val, X2_val, X3_val,  X4_val, X5_val,  X6_val], Y_val),
#       <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=8'>9</a>     callbacks=[tensorboard])
#      <a href='vscode-notebook-cell:/d%3A/Project2022/Code/project2022/simplified/6_inputs.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a> model.save("D:/Project2022/models/"+model_name+".h5")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:1555, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1551 with data_handler.catch_stop_iteration():
#    1552     data_handler._initial_step = data_handler._initial_step or (
#    1553         self._maybe_load_initial_step_from_ckpt()
#    1554     )
# -> 1555     for step in data_handler.steps():
#    1556         with tf.profiler.experimental.Trace(
#    1557             "train",
#    1558             epoch_num=epoch,
#    (...)
#    1561             _r=1,
#    1562         ):
#    1563             callbacks.on_train_batch_begin(step)
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\data_adapter.py:1374, in DataHandler.steps(self)
#    1372 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1373     break
# -> 1374 original_spe = self._steps_per_execution.numpy().item()
#    1375 can_run_full_execution = (
#    1376     original_spe == 1
#    1377     or self._inferred_steps is None
#    1378     or self._inferred_steps - self._current_step >= original_spe
#    1379 )
#    1381 if can_run_full_execution:
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     635 def numpy(self):
#     636   if context.executing_eagerly():
# --> 637     return self.read_value().numpy()
#     638   raise NotImplementedError(
#     639       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\ranji\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\ranji\appdata\roaming\python\python39\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (from h5py) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
model_name = "mutiple_Conv1D_8_inputs_scaled_modified"
model = keras.models.load_model("D:/Project2022/models/"+model_name+".h5")

# %%
model_name
# Out:
# 'mutiple_Conv1D_8_inputs_scaled_modified'

# %% [markdown]
# # Evaluate the Model using test data

# %%
Test_DATADIR = "D:/Project2022/res/split_dataset/original/test"
dataset_df = pre_process_dataset(Test_DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/1430 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/1379 [00:00<?, ?it/s]

# %%
print("No of test sample:", len(dataset_df))
# Out:
# No of test sample: 2809

# %%
X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test, Y_test = process_data(dataset_df)
# Out:
# X1 shape (2809, 367, 1)
# X2 shape (2809, 252, 1)
# X3 shape (2809, 252, 1)
# Mid rows shape (2809, 252, 1)
# X4 shape (2809, 252, 1)
# X5 shape (2809, 367, 1)
# Mid Cols shape (2809, 367, 1)
# X6 shape (2809, 367, 1)
# y shape (2809, 1)

# %%
# test loss, test accuracy
accuracy = model.evaluate([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test], Y_test, batch_size=100, verbose=0)

# %%
print("Test acuuracy", accuracy[1])
print("Test loss", accuracy[0])
# Out:
# Test acuuracy 0.9619081616401672
# Test loss 0.20270198583602905

# %%
#y_pred = model.predict_classes(X_test)
y_pred = (model.predict([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test]) > 0.5).astype("int32")
# Out:
# 88/88 [==============================] - 2s 10ms/step

# %%
print(classification_report(Y_test, y_pred, target_names=["covid", "Normal"]))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.97      0.96      0.96      1430
#       Normal       0.96      0.97      0.96      1379
#
#     accuracy                           0.96      2809
#    macro avg       0.96      0.96      0.96      2809
# weighted avg       0.96      0.96      0.96      2809

# %%
cm = confusion_matrix(Y_test, y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=["Covid","Normal"])
disp.plot()
plt.show()
