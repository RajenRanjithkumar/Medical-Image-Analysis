# %%
#mask
import json
import cv2
import os
import pandas as pd 
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import numpy as np
import keras
from keras.preprocessing import image
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers, models

from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.utils import to_categorical

from keras.layers import Input
from keras.models import Model
from keras.layers import concatenate
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten 
from keras.layers import Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import to_categorical
import xml.etree.ElementTree as ET
from tensorflow.keras.callbacks import TensorBoard

from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ranji\anaconda3\envs\tf_gpu\lib\site-packages (from h5py) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
model_name = "mutiple_Conv1D_8_inputs_scaled_modified"
model = keras.models.load_model("D:/Project2022/models/"+model_name+".h5")

# %%
model = ""

# %%
import time
model_name = "8_inputs_raw"
NAME = model_name+"-{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir = 'logs/{}'.format(NAME))

# %%
CATEGORIES = ["covid", "normal"]
DATADIR = "D:/Project2022/res/split_dataset/original/train"

# %%
for categoty in CATEGORIES:
    path = os.path.join(DATADIR, categoty)  # path to Covid or Nprmal
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
        plt.imshow(img_array, cmap="gray")
        plt.show()

        mid_h = int(img_array.shape[1]/4)
        mid_v = int(img_array.shape[0]/4)


        #left half
        LH_img = img_array[: , :int(img_array.shape[1]/2)]
        plt.imshow(LH_img, cmap="gray")
        plt.show()
        
        #Right half
        RH_img = img_array[: , int(img_array.shape[1]/2):]
        plt.imshow(RH_img, cmap="gray")
        plt.show()

        # mid vertical
        mid_ver = img_array[:, int((img_array.shape[1]/2)-mid_h):int((img_array.shape[1]/2)+mid_h)]
        plt.imshow(mid_ver, cmap="gray")
        plt.show()

        #top half
        TC_img = img_array[:int(img_array.shape[0]/2) , :]
        plt.imshow(TC_img, cmap="gray")
        plt.show()

        #bottom half
        BC_img =  img_array[int(img_array.shape[0]/2): , :]
        plt.imshow(BC_img, cmap="gray")
        plt.show()

        #mid horizontal
        mid_hor = img_array[int((img_array.shape[0]/2)-mid_v):int((img_array.shape[0]/2)+mid_v), :]
        plt.imshow(mid_hor, cmap="gray")
        plt.show()


        break
    break

# %%
def pre_process_dataset(dataset_path):

    df_data = pd.DataFrame()
    #raw_image = []
    row_sum = []
    coloumn_sum = []
    
    LH_sum = []
    Row_mid = []
    RH_sum = []
    
    TC_sum = []
    Col_mid = []
    BC_sum =[]

    label = []

    for categoty in CATEGORIES:
        path = os.path.join(dataset_path, categoty)  
        
        class_num = CATEGORIES.index(categoty)
        

        print("Loading dataset: class",categoty)
        for img in tqdm(os.listdir(path)):

            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                img_array = cv2.resize(img_array, (512,512), interpolation= cv2.INTER_LINEAR)
                row = img_array.sum(axis=0)
                coloumn = img_array.sum(axis=1)

                 #Global inputs
                row_sum.append(row)
                coloumn_sum.append(coloumn)


                mid_h = int(img_array.shape[1]/4)
                mid_v = int(img_array.shape[0]/4)


                #row inputs
                LH_img = img_array[: , :int(img_array.shape[1]/2)]
                LH_sum.append(LH_img.sum(1))

                row_mid = img_array[:, int((img_array.shape[1]/2)-mid_h):int((img_array.shape[1]/2)+mid_h)]
                Row_mid.append(row_mid.sum(1))

                RH_img = img_array[: , int(img_array.shape[1]/2):]
                RH_sum.append(RH_img.sum(1))

                #coloumn inputs
                TC_img = img_array[:int(img_array.shape[0]/2) , :]
                TC_sum.append(TC_img.sum(0))

                col_mid = img_array[int((img_array.shape[0]/2)-mid_v):int((img_array.shape[0]/2)+mid_v), :]
                Col_mid.append(col_mid.sum(0)) 

                BC_img = img_array[int(img_array.shape[0]/2): , :]
                BC_sum.append(BC_img.sum(0))

                
                #raw_image.append(img_array)             

                label.append(class_num)
                
            except Exception as e:
                pass
    
    #df_data["raw data"] = raw_image
    df_data["row_sum"] = row_sum
    df_data["coloumn_sum"] = coloumn_sum

    df_data["LH_sum"] = LH_sum
    df_data["Row_mid"] = Row_mid
    df_data["RH_sum"] = RH_sum


    df_data["TC_sum"] = TC_sum
    df_data["Col_mid"] = Col_mid
    df_data["BC_sum"] = BC_sum

    df_data["label"] = label
    

    return df_data

# %%
dataset_df = pre_process_dataset(DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/5719 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/5514 [00:00<?, ?it/s]

# %%
dataset_df.head(-1)
# Out:
#                                                  row_sum  \
# 0      [26099, 25676, 25188, 24716, 24349, 24010, 236...
# 1      [73474, 73717, 73998, 74214, 74359, 74470, 746...
# 2      [76642, 76817, 77127, 77520, 77719, 77849, 779...
# 3      [53413, 53410, 53496, 53710, 53849, 54026, 542...
# 4      [48830, 49179, 49634, 50119, 50160, 50264, 503...
# ...                                                  ...
# 11227  [77073, 77674, 78399, 79040, 79015, 78901, 787...
# 11228  [68286, 68935, 69634, 70079, 69976, 69901, 699...
# 11229  [77895, 77209, 76363, 75413, 74768, 74269, 737...
# 11230  [68831, 68766, 68644, 68482, 68493, 68598, 688...
# 11231  [72012, 72076, 72155, 72206, 72260, 72365, 725...
#
#                                              coloumn_sum  \
# 0      [15188, 15165, 15034, 14946, 14851, 14789, 147...
# 1      [78050, 78059, 78168, 78281, 78422, 78550, 786...
# 2      [75406, 75193, 74807, 74522, 74382, 74313, 743...
# 3      [49764, 49674, 49607, 49614, 49681, 49754, 498...
# 4      [40579, 40502, 40367, 40241, 40157, 40100, 400...
# ...                                                  ...
# 11227  [69335, 69057, 68479, 67895, 67302, 66655, 659...
# 11228  [60614, 60424, 60035, 59813, 59764, 59777, 598...
# 11229  [65379, 64215, 61859, 59863, 58356, 57253, 566...
# 11230  [76030, 76013, 76063, 76113, 76181, 76248, 763...
# 11231  [39739, 39940, 40313, 40945, 41858, 42883, 440...
#
#                                                   LH_sum  \
# 0      [26099, 25676, 25188, 24716, 24349, 24010, 236...
# 1      [73474, 73717, 73998, 74214, 74359, 74470, 746...
# 2      [76642, 76817, 77127, 77520, 77719, 77849, 779...
# 3      [53413, 53410, 53496, 53710, 53849, 54026, 542...
# 4      [48830, 49179, 49634, 50119, 50160, 50264, 503...
# ...                                                  ...
# 11227  [77073, 77674, 78399, 79040, 79015, 78901, 787...
# 11228  [68286, 68935, 69634, 70079, 69976, 69901, 699...
# 11229  [77895, 77209, 76363, 75413, 74768, 74269, 737...
# 11230  [68831, 68766, 68644, 68482, 68493, 68598, 688...
# 11231  [72012, 72076, 72155, 72206, 72260, 72365, 725...
#
#                                                  Row_mid  \
# 0      [17257, 17308, 17206, 16999, 16791, 16593, 164...
# 1      [77740, 77757, 77889, 77900, 77824, 77769, 776...
# 2      [57051, 56886, 56925, 57015, 56670, 56043, 552...
# 3      [16925, 16914, 16893, 16670, 16451, 16281, 162...
# 4      [24655, 24666, 24556, 24521, 24443, 24219, 237...
# ...                                                  ...
# 11227  [50968, 51052, 51157, 51223, 51262, 51273, 511...
# 11228  [59468, 59371, 59349, 59337, 59307, 59343, 594...
# 11229  [45475, 46049, 46538, 46848, 47072, 47252, 473...
# 11230  [65699, 65613, 65534, 65435, 65288, 65150, 650...
# 11231  [51712, 51868, 52117, 52330, 52463, 52565, 525...
#
#                                                   RH_sum  \
# 0      [55047, 55336, 55679, 55849, 55961, 55943, 558...
# 1      [85422, 85439, 85490, 85738, 86159, 86663, 871...
# 2      [79862, 79614, 79340, 79161, 79080, 78984, 790...
# 3      [56771, 56859, 57095, 57166, 57177, 57220, 575...
# 4      [60037, 60186, 60265, 60663, 61459, 62813, 645...
# ...                                                  ...
# 11227  [79387, 78864, 78314, 77927, 77636, 77320, 770...
# 11228  [74329, 74503, 74887, 75443, 76056, 76493, 766...
# 11229  [74458, 74633, 74934, 75155, 75397, 75540, 756...
# 11230  [78803, 78765, 78653, 78493, 78316, 78102, 779...
# 11231  [74675, 74960, 75309, 75533, 75714, 75841, 760...
#
#                                                   TC_sum  \
# 0      [15188, 15165, 15034, 14946, 14851, 14789, 147...
# 1      [78050, 78059, 78168, 78281, 78422, 78550, 786...
# 2      [75406, 75193, 74807, 74522, 74382, 74313, 743...
# 3      [49764, 49674, 49607, 49614, 49681, 49754, 498...
# 4      [40579, 40502, 40367, 40241, 40157, 40100, 400...
# ...                                                  ...
# 11227  [69335, 69057, 68479, 67895, 67302, 66655, 659...
# 11228  [60614, 60424, 60035, 59813, 59764, 59777, 598...
# 11229  [65379, 64215, 61859, 59863, 58356, 57253, 566...
# 11230  [76030, 76013, 76063, 76113, 76181, 76248, 763...
# 11231  [39739, 39940, 40313, 40945, 41858, 42883, 440...
#
#                                                  Col_mid  \
# 0      [21553, 21452, 21389, 21353, 21375, 21402, 214...
# 1      [80761, 80846, 80960, 81062, 81138, 81227, 812...
# 2      [67445, 67451, 67515, 67602, 67720, 67816, 678...
# 3      [29631, 29718, 29789, 29884, 29953, 30033, 301...
# 4      [47174, 46966, 46706, 46388, 46022, 45673, 454...
# ...                                                  ...
# 11227  [58016, 58131, 58269, 58323, 58281, 58228, 581...
# 11228  [66958, 66770, 66528, 66328, 66130, 65942, 658...
# 11229  [53799, 53779, 53802, 53828, 53904, 53993, 541...
# 11230  [77646, 77611, 77659, 77713, 77779, 77813, 778...
# 11231  [56733, 56699, 56601, 56525, 56458, 56439, 564...
#
#                                                   BC_sum  label
# 0      [21073, 20901, 20722, 20493, 20225, 19897, 194...      0
# 1      [80046, 79912, 79781, 79654, 79494, 79366, 792...      0
# 2      [66811, 66740, 66607, 66396, 66054, 65654, 651...      0
# 3      [28171, 28202, 28304, 28359, 28393, 28397, 283...      0
# 4      [17165, 16952, 16759, 16618, 16559, 16619, 168...      0
# ...                                                  ...    ...
# 11227  [56939, 56877, 56834, 56809, 56732, 56732, 567...      1
# 11228  [46095, 46168, 46242, 46313, 46377, 46450, 465...      1
# 11229  [51190, 50941, 50566, 50164, 49703, 49345, 491...      1
# 11230  [72727, 72652, 72607, 72591, 72664, 72721, 727...      1
# 11231  [53085, 53073, 53085, 53114, 53119, 53148, 531...      1
#
# [11232 rows x 9 columns]

# %%
df_train, df_val = train_test_split(dataset_df, test_size=0.3, random_state=0)

# %%
df_train["label"].value_counts()
# Out:
# 0    4041
# 1    3822
# Name: label, dtype: int64

# %%
print("No of Training samples:",len(df_train))
print("No of Validation samples:",len(df_val))
# Out:
# No of Training samples: 7863
# No of Validation samples: 3370

# %%
df_train["row_sum"][0].shape
# Out:
# (512,)

# %%
from sklearn import preprocessing

def process_data(dataset_df):
    
    row = dataset_df["row_sum"].values
    coloumn = dataset_df["coloumn_sum"].values

    LH = dataset_df["LH_sum"].values
    Row_mid = dataset_df["Row_mid"].values
    RH = dataset_df["RH_sum"].values


    TC = dataset_df["TC_sum"].values
    Col_mid = dataset_df["Col_mid"].values
    BC = dataset_df["BC_sum"].values

    # global
    X1 = [img.tolist() for img in row]
    X2 = [img.tolist() for img in coloumn]

    #row
    X3 = [img.tolist() for img in LH]
    X_row_mid = [img.tolist() for img in Row_mid]
    X4 = [img.tolist() for img in RH]

    #coloumn
    X5 = [img.tolist() for img in TC]
    X_col_mid = [img.tolist() for img in Col_mid]
    X6 = [img.tolist() for img in BC]


    X1 = np.array(X1)
    X2 = np.array(X2)

    X3 = np.array(X3)
    X_row_mid = np.array(X_row_mid)
    X4 = np.array(X4)


    X5 = np.array(X5)
    X_col_mid = np.array(X_col_mid)
    X6 = np.array(X6)

    #normalize the inputs
    X1 = preprocessing.normalize(X1)
    X2 = preprocessing.normalize(X2)

    X3 = preprocessing.normalize(X3)
    X_row_mid = preprocessing.normalize(X_row_mid)
    X4 = preprocessing.normalize(X4)

    X5 = preprocessing.normalize(X5)
    X_col_mid = preprocessing.normalize(X_col_mid)
    X6 = preprocessing.normalize(X6)

    #reshape the inputs
    X1 = np.expand_dims(X1, axis=-1)
    X2 = np.expand_dims(X2, axis=-1)

    X3 = np.expand_dims(X3, axis=-1)
    X_row_mid = np.expand_dims(X_row_mid, axis=-1)
    X4 = np.expand_dims(X4, axis=-1)

    X5 = np.expand_dims(X5, axis=-1)
    X_col_mid = np.expand_dims(X_col_mid, axis=-1)
    X6 = np.expand_dims(X6, axis=-1)



    y = np.array(dataset_df["label"].values)
    y = np.expand_dims(y, axis=-1)


    print("X1 shape", X1.shape)
    print("X2 shape", X2.shape)

    print("X3 shape", X3.shape)
    print("Mid rows shape", X_row_mid.shape)
    print("X4 shape", X4.shape)

    print("X5 shape", X5.shape)
    print("Mid Cols shape", X_col_mid.shape)
    print("X6 shape", X6.shape)

    print("y shape", y.shape)

    return X1, X2, X3, X_row_mid, X4, X5, X_col_mid, X6, y

# %%
print("Training samples:")
X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train, Y_train = process_data(df_train)

print("\nValidation samples:")
X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val, Y_val = process_data(df_val)
# Out:
# Training samples:
# X1 shape (7863, 512, 1)
# X2 shape (7863, 512, 1)
# X3 shape (7863, 512, 1)
# Mid rows shape (7863, 512, 1)
# X4 shape (7863, 512, 1)
# X5 shape (7863, 512, 1)
# Mid Cols shape (7863, 512, 1)
# X6 shape (7863, 512, 1)
# y shape (7863, 1)
#
# Validation samples:
# X1 shape (3370, 512, 1)
# X2 shape (3370, 512, 1)
# X3 shape (3370, 512, 1)
# Mid rows shape (3370, 512, 1)
# X4 shape (3370, 512, 1)
# X5 shape (3370, 512, 1)
# Mid Cols shape (3370, 512, 1)
# X6 shape (3370, 512, 1)
# y shape (3370, 1)

# %%
def conv1D_layer(input, nodes):
    #Input(shape=(367,1))
    #input_layer = Input(shape=inputSize)
    #kernel size- 5
    # nodes - 16
    conv1 = Conv1D(nodes, kernel_size=5, activation='relu')(input)
    drop1 = Dropout(0.25)(conv1)
    pool1 = MaxPooling1D(pool_size=2)(drop1)
    flat = Flatten()(pool1)
    return flat

# %% [markdown]
# ## Modified

# %%
# first input model
row = Input(shape=(512,1))
flat_row = conv1D_layer(row, 16)

# second input model
col = Input(shape=(512,1))
flat_col = conv1D_layer(col, 16)

#####################################################################

LH = Input(shape=(512,1))
flat3 = conv1D_layer(LH, 16)

row_mid = Input(shape=(512,1))
flat4 = conv1D_layer(row_mid, 16)

RH = Input(shape=(512,1))
flat5 = conv1D_layer(RH, 16)


TC = Input(shape=(512,1))
flat6 = conv1D_layer(TC, 16)

col_mid = Input(shape=(512,1))
flat7 = conv1D_layer(col_mid, 16)

BC = Input(shape=(512,1))
flat8 = conv1D_layer(BC, 16)


merge_all = concatenate([flat_row, flat_col, flat3, flat4, flat5, flat6, flat7,flat8])
#32
hidden_all_1 = Dense(32, activation='relu')(merge_all)
#16
hidden_all_2 = Dense(16, activation='relu')(hidden_all_1)

output = Dense(1, activation='sigmoid')(hidden_all_2)
model = Model(inputs=[row, col, LH, row_mid, RH, TC, col_mid, BC], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_18 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_19 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_20 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_21 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_22 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_23 (InputLayer)          [(None, 512, 1)]     0           []
#
#  input_24 (InputLayer)          [(None, 512, 1)]     0           []
#
#  conv1d_16 (Conv1D)             (None, 508, 16)      96          ['input_17[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 508, 16)      96          ['input_18[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 508, 16)      96          ['input_19[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 508, 16)      96          ['input_20[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 508, 16)      96          ['input_21[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 508, 16)      96          ['input_22[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 508, 16)      96          ['input_23[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 508, 16)      96          ['input_24[0][0]']
#
#  dropout_16 (Dropout)           (None, 508, 16)      0           ['conv1d_16[0][0]']
#
#  dropout_17 (Dropout)           (None, 508, 16)      0           ['conv1d_17[0][0]']
#
#  dropout_18 (Dropout)           (None, 508, 16)      0           ['conv1d_18[0][0]']
#
#  dropout_19 (Dropout)           (None, 508, 16)      0           ['conv1d_19[0][0]']
#
#  dropout_20 (Dropout)           (None, 508, 16)      0           ['conv1d_20[0][0]']
#
#  dropout_21 (Dropout)           (None, 508, 16)      0           ['conv1d_21[0][0]']
#
#  dropout_22 (Dropout)           (None, 508, 16)      0           ['conv1d_22[0][0]']
#
#  dropout_23 (Dropout)           (None, 508, 16)      0           ['conv1d_23[0][0]']
#
#  max_pooling1d_16 (MaxPooling1D  (None, 254, 16)     0           ['dropout_16[0][0]']
#  )
#
#  max_pooling1d_17 (MaxPooling1D  (None, 254, 16)     0           ['dropout_17[0][0]']
#  )
#
#  max_pooling1d_18 (MaxPooling1D  (None, 254, 16)     0           ['dropout_18[0][0]']
#  )
#
#  max_pooling1d_19 (MaxPooling1D  (None, 254, 16)     0           ['dropout_19[0][0]']
#  )
#
#  max_pooling1d_20 (MaxPooling1D  (None, 254, 16)     0           ['dropout_20[0][0]']
#  )
#
#  max_pooling1d_21 (MaxPooling1D  (None, 254, 16)     0           ['dropout_21[0][0]']
#  )
#
#  max_pooling1d_22 (MaxPooling1D  (None, 254, 16)     0           ['dropout_22[0][0]']
#  )
#
#  max_pooling1d_23 (MaxPooling1D  (None, 254, 16)     0           ['dropout_23[0][0]']
#  )
#
#  flatten_16 (Flatten)           (None, 4064)         0           ['max_pooling1d_16[0][0]']
#
#  flatten_17 (Flatten)           (None, 4064)         0           ['max_pooling1d_17[0][0]']
#
#  flatten_18 (Flatten)           (None, 4064)         0           ['max_pooling1d_18[0][0]']
#
#  flatten_19 (Flatten)           (None, 4064)         0           ['max_pooling1d_19[0][0]']
#
#  flatten_20 (Flatten)           (None, 4064)         0           ['max_pooling1d_20[0][0]']
#
#  flatten_21 (Flatten)           (None, 4064)         0           ['max_pooling1d_21[0][0]']
#
#  flatten_22 (Flatten)           (None, 4064)         0           ['max_pooling1d_22[0][0]']
#
#  flatten_23 (Flatten)           (None, 4064)         0           ['max_pooling1d_23[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32512)        0           ['flatten_16[0][0]',
#                                                                   'flatten_17[0][0]',
#                                                                   'flatten_18[0][0]',
#                                                                   'flatten_19[0][0]',
#                                                                   'flatten_20[0][0]',
#                                                                   'flatten_21[0][0]',
#                                                                   'flatten_22[0][0]',
#                                                                   'flatten_23[0][0]']
#
#  dense_6 (Dense)                (None, 32)           1040416     ['concatenate_2[0][0]']
#
#  dense_7 (Dense)                (None, 16)           528         ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 1)            17          ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 1,041,729
# Trainable params: 1,041,729
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
BATCH_SIZE = 128
EPOCHS = 500
history = model.fit(
    [X1_train, X2_train, X3_train, X_row_mid, X4_train, X5_train, X_col_mid, X6_train],
    Y_train,
    BATCH_SIZE,
    EPOCHS,
    validation_data=([X1_val, X2_val, X3_val, X_row_mid_val, X4_val, X5_val, X_mid_col_val, X6_val], Y_val),
    callbacks=[tensorboard])

model.save("D:/Project2022/models/less_complex/"+model_name+".h5")
# Out:
# Epoch 1/500
# 62/62 [==============================] - 8s 38ms/step - loss: 0.6113 - accuracy: 0.7183 - val_loss: 0.5178 - val_accuracy: 0.7899
# Epoch 2/500
# 62/62 [==============================] - 2s 31ms/step - loss: 0.4655 - accuracy: 0.7969 - val_loss: 0.4473 - val_accuracy: 0.8139
# Epoch 3/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.4300 - accuracy: 0.8089 - val_loss: 0.4225 - val_accuracy: 0.8243
# Epoch 4/500
# 62/62 [==============================] - 2s 27ms/step - loss: 0.4038 - accuracy: 0.8253 - val_loss: 0.4042 - val_accuracy: 0.8326
# Epoch 5/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.3929 - accuracy: 0.8316 - val_loss: 0.3969 - val_accuracy: 0.8326
# Epoch 6/500
# 62/62 [==============================] - 2s 27ms/step - loss: 0.3795 - accuracy: 0.8359 - val_loss: 0.3760 - val_accuracy: 0.8457
# Epoch 7/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.3631 - accuracy: 0.8474 - val_loss: 0.3650 - val_accuracy: 0.8540
# Epoch 8/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.3494 - accuracy: 0.8546 - val_loss: 0.3679 - val_accuracy: 0.8558
# Epoch 9/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.3425 - accuracy: 0.8560 - val_loss: 0.3610 - val_accuracy: 0.8537
# Epoch 10/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.3450 - accuracy: 0.8523 - val_loss: 0.3699 - val_accuracy: 0.8442
# Epoch 11/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.3365 - accuracy: 0.8629 - val_loss: 0.3545 - val_accuracy: 0.8591
# Epoch 12/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.3239 - accuracy: 0.8682 - val_loss: 0.3687 - val_accuracy: 0.8454
# Epoch 13/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.3276 - accuracy: 0.8648 - val_loss: 0.3448 - val_accuracy: 0.8662
# Epoch 14/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.3234 - accuracy: 0.8680 - val_loss: 0.3256 - val_accuracy: 0.8715
# Epoch 15/500
# 62/62 [==============================] - 2s 24ms/step - loss: 0.3109 - accuracy: 0.8763 - val_loss: 0.3210 - val_accuracy: 0.8751
# Epoch 16/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.3099 - accuracy: 0.8722 - val_loss: 0.3358 - val_accuracy: 0.8659
# Epoch 17/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.3015 - accuracy: 0.8774 - val_loss: 0.3120 - val_accuracy: 0.8780
# Epoch 18/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2981 - accuracy: 0.8788 - val_loss: 0.3169 - val_accuracy: 0.8727
# Epoch 19/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2896 - accuracy: 0.8822 - val_loss: 0.3080 - val_accuracy: 0.8810
# Epoch 20/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2912 - accuracy: 0.8805 - val_loss: 0.2979 - val_accuracy: 0.8849
# Epoch 21/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2816 - accuracy: 0.8838 - val_loss: 0.3110 - val_accuracy: 0.8858
# Epoch 22/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2710 - accuracy: 0.8910 - val_loss: 0.2874 - val_accuracy: 0.8878
# Epoch 23/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2724 - accuracy: 0.8900 - val_loss: 0.2949 - val_accuracy: 0.8840
# Epoch 24/500
# 62/62 [==============================] - 1s 24ms/step - loss: 0.2691 - accuracy: 0.8900 - val_loss: 0.2991 - val_accuracy: 0.8819
# Epoch 25/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2745 - accuracy: 0.8901 - val_loss: 0.2789 - val_accuracy: 0.8926
# Epoch 26/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2705 - accuracy: 0.8896 - val_loss: 0.2787 - val_accuracy: 0.8932
# Epoch 27/500
# 62/62 [==============================] - 2s 24ms/step - loss: 0.2589 - accuracy: 0.8967 - val_loss: 0.2799 - val_accuracy: 0.8982
# Epoch 28/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2629 - accuracy: 0.8922 - val_loss: 0.2906 - val_accuracy: 0.8929
# Epoch 29/500
# 62/62 [==============================] - 2s 24ms/step - loss: 0.2462 - accuracy: 0.9017 - val_loss: 0.2702 - val_accuracy: 0.8935
# Epoch 30/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2389 - accuracy: 0.9053 - val_loss: 0.2603 - val_accuracy: 0.9006
# Epoch 31/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2399 - accuracy: 0.9061 - val_loss: 0.2882 - val_accuracy: 0.8914
# Epoch 32/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2335 - accuracy: 0.9083 - val_loss: 0.2598 - val_accuracy: 0.8976
# Epoch 33/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2353 - accuracy: 0.9079 - val_loss: 0.2571 - val_accuracy: 0.9042
# Epoch 34/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2267 - accuracy: 0.9103 - val_loss: 0.2586 - val_accuracy: 0.8944
# Epoch 35/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2303 - accuracy: 0.9077 - val_loss: 0.2759 - val_accuracy: 0.8985
# Epoch 36/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2211 - accuracy: 0.9144 - val_loss: 0.2442 - val_accuracy: 0.9071
# Epoch 37/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2183 - accuracy: 0.9199 - val_loss: 0.2465 - val_accuracy: 0.9059
# Epoch 38/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2154 - accuracy: 0.9177 - val_loss: 0.2377 - val_accuracy: 0.9110
# Epoch 39/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2113 - accuracy: 0.9194 - val_loss: 0.2608 - val_accuracy: 0.9012
# Epoch 40/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2106 - accuracy: 0.9167 - val_loss: 0.2697 - val_accuracy: 0.9071
# Epoch 41/500
# 62/62 [==============================] - 2s 24ms/step - loss: 0.2034 - accuracy: 0.9242 - val_loss: 0.2399 - val_accuracy: 0.9104
# Epoch 42/500
# 62/62 [==============================] - 2s 24ms/step - loss: 0.2039 - accuracy: 0.9224 - val_loss: 0.2325 - val_accuracy: 0.9154
# Epoch 43/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.1949 - accuracy: 0.9275 - val_loss: 0.2667 - val_accuracy: 0.8994
# Epoch 44/500
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1935 - accuracy: 0.9275 - val_loss: 0.2245 - val_accuracy: 0.9157
# Epoch 45/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.
500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0756 - accuracy: 0.9711 - val_loss: 0.2316 - val_accuracy: 0.9276
# Epoch 169/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0636 - accuracy: 0.9758 - val_loss: 0.1609 - val_accuracy: 0.9549
# Epoch 170/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.2135 - val_accuracy: 0.9297
# Epoch 171/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0415 - accuracy: 0.9863 - val_loss: 0.1743 - val_accuracy: 0.9510
# Epoch 172/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0434 - accuracy: 0.9836 - val_loss: 0.1694 - val_accuracy: 0.9543
# Epoch 173/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0399 - accuracy: 0.9863 - val_loss: 0.1504 - val_accuracy: 0.9558
# Epoch 174/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0393 - accuracy: 0.9866 - val_loss: 0.1499 - val_accuracy: 0.9582
# Epoch 175/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0459 - accuracy: 0.9826 - val_loss: 0.1641 - val_accuracy: 0.9534
# Epoch 176/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0430 - accuracy: 0.9837 - val_loss: 0.1539 - val_accuracy: 0.9599
# Epoch 177/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0365 - accuracy: 0.9874 - val_loss: 0.1804 - val_accuracy: 0.9519
# Epoch 178/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0441 - accuracy: 0.9847 - val_loss: 0.1607 - val_accuracy: 0.9555
# Epoch 179/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0356 - accuracy: 0.9884 - val_loss: 0.1631 - val_accuracy: 0.9540
# Epoch 180/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0335 - accuracy: 0.9887 - val_loss: 0.1542 - val_accuracy: 0.9570
# Epoch 181/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0352 - accuracy: 0.9875 - val_loss: 0.1756 - val_accuracy: 0.9510
# Epoch 182/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0515 - accuracy: 0.9799 - val_loss: 0.1846 - val_accuracy: 0.9484
# Epoch 183/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0361 - accuracy: 0.9875 - val_loss: 0.1787 - val_accuracy: 0.9516
# Epoch 184/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0389 - accuracy: 0.9860 - val_loss: 0.1551 - val_accuracy: 0.9570
# Epoch 185/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0318 - accuracy: 0.9891 - val_loss: 0.2192 - val_accuracy: 0.9460
# Epoch 186/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0474 - accuracy: 0.9811 - val_loss: 0.1749 - val_accuracy: 0.9484
# Epoch 187/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0449 - accuracy: 0.9824 - val_loss: 0.1718 - val_accuracy: 0.9540
# Epoch 188/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0386 - accuracy: 0.9860 - val_loss: 0.1736 - val_accuracy: 0.9525
# Epoch 189/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0420 - accuracy: 0.9855 - val_loss: 0.1606 - val_accuracy: 0.9552
# Epoch 190/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0293 - accuracy: 0.9908 - val_loss: 0.1476 - val_accuracy: 0.9614
# Epoch 191/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0367 - accuracy: 0.9869 - val_loss: 0.1544 - val_accuracy: 0.9591
# Epoch 192/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0316 - accuracy: 0.9889 - val_loss: 0.1660 - val_accuracy: 0.9570
# Epoch 193/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0543 - accuracy: 0.9791 - val_loss: 0.1692 - val_accuracy: 0.9510
# Epoch 194/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0326 - accuracy: 0.9877 - val_loss: 0.1563 - val_accuracy: 0.9593
# Epoch 195/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0351 - accuracy: 0.9877 - val_loss: 0.1572 - val_accuracy: 0.9611
# Epoch 196/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0260 - accuracy: 0.9920 - val_loss: 0.1586 - val_accuracy: 0.9602
# Epoch 197/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0351 - accuracy: 0.9868 - val_loss: 0.1789 - val_accuracy: 0.9519
# Epoch 198/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0307 - accuracy: 0.9891 - val_loss: 0.1769 - val_accuracy: 0.9570
# Epoch 199/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.1771 - val_accuracy: 0.9496
# Epoch 200/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0324 - accuracy: 0.9882 - val_loss: 0.1793 - val_accuracy: 0.9564
# Epoch 201/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0385 - accuracy: 0.9855 - val_loss: 0.1672 - val_accuracy: 0.9576
# Epoch 202/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0342 - accuracy: 0.9873 - val_loss: 0.1911 - val_accuracy: 0.9522
# Epoch 203/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0283 - accuracy: 0.9907 - val_loss: 0.1554 - val_accuracy: 0.9629
# Epoch 204/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0312 - accuracy: 0.9898 - val_loss: 0.1789 - val_accuracy: 0.9564
# Epoch 205/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0401 - accuracy: 0.9859 - val_loss: 0.1717 - val_accuracy: 0.9602
# Epoch 206/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0288 - accuracy: 0.9894 - val_loss: 0.1543 - val_accuracy: 0.9650
# Epoch 207/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0243 - accuracy: 0.9925 - val_loss: 0.1571 - val_accuracy: 0.9638
# Epoch 208/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0259 - accuracy: 0.9906 - val_loss: 0.1712 - val_accuracy: 0.9585
# Epoch 209/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0359 - accuracy: 0.9861 - val_loss: 0.1673 - val_accuracy: 0.9534
# Epoch 210/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0316 - accuracy: 0.9875 - val_loss: 0.1785 - val_accuracy: 0.9534
# Epoch 211/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0286 - accuracy: 0.9898 - val_loss: 0.1573 - val_accuracy: 0.9591
# Epoch 212/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.1599 - val_accuracy: 0.9623
# Epoch 213/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0328 - accuracy: 0.9889 - val_loss: 0.1604 - val_accuracy: 0.9582
# Epoch 214/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.1690 - val_accuracy: 0.9555
# Epoch 215/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0216 - accuracy: 0.9934 - val_loss: 0.1731 - val_accuracy: 0.9591
# Epoch 216/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 0.1568 - val_accuracy: 0.9644
# Epoch 217/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0342 - accuracy: 0.9878 - val_loss: 0.1839 - val_accuracy: 0.9496
# Epoch 218/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0388 - accuracy: 0.9850 - val_loss: 0.1802 - val_accuracy: 0.9516
# Epoch 219/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0570 - accuracy: 0.9781 - val_loss: 0.1976 - val_accuracy: 0.9445
# Epoch 220/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0334 - accuracy: 0.9870 - val_loss: 0.1764 - val_accuracy: 0.9591
# Epoch 221/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0247 - accuracy: 0.9920 - val_loss: 0.1810 - val_accuracy: 0.9561
# Epoch 222/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.1829 - val_accuracy: 0.9525
# Epoch 223/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.1726 - val_accuracy: 0.9620
# Epoch 224/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0276 - accuracy: 0.9903 - val_loss: 0.1642 - val_accuracy: 0.9629
# Epoch 225/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0190 - accuracy: 0.9939 - val_loss: 0.1650 - val_accuracy: 0.9662
# Epoch 226/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.1850 - val_accuracy: 0.9602
# Epoch 227/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.1645 - val_accuracy: 0.9635
# Epoch 228/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.1806 - val_accuracy: 0.9573
# Epoch 229/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.1712 - val_accuracy: 0.9599
# Epoch 230/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.1772 - val_accuracy: 0.9596
# Epoch 231/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0191 - accuracy: 0.9950 - val_loss: 0.1663 - val_accuracy: 0.9620
# Epoch 232/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.1572 - val_accuracy: 0.9635
# Epoch 233/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0330 - accuracy: 0.9878 - val_loss: 0.2787 - val_accuracy: 0.9214
# Epoch 234/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0404 - accuracy: 0.9858 - val_loss: 0.1748 - val_accuracy: 0.9582
# Epoch 235/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0218 - accuracy: 0.9934 - val_loss: 0.1983 - val_accuracy: 0.9576
# Epoch 236/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0357 - accuracy: 0.9863 - val_loss: 0.1904 - val_accuracy: 0.9599
# Epoch 237/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.1708 - val_accuracy: 0.9608
# Epoch 238/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 0.1837 - val_accuracy: 0.9591
# Epoch 239/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0243 - accuracy: 0.9921 - val_loss: 0.1689 - val_accuracy: 0.9608
# Epoch 240/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.1741 - val_accuracy: 0.9632
# Epoch 241/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0183 - accuracy: 0.9940 - val_loss: 0.2310 - val_accuracy: 0.9421
# Epoch 242/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0269 - accuracy: 0.9905 - val_loss: 0.1736 - val_accuracy: 0.9635
# Epoch 243/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.2015 - val_accuracy: 0.9582
# Epoch 244/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0174 - accuracy: 0.9939 - val_loss: 0.1801 - val_accuracy: 0.9626
# Epoch 245/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0205 - accuracy: 0.9934 - val_loss: 0.2069 - val_accuracy: 0.9525
# Epoch 246/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0177 - accuracy: 0.9952 - val_loss: 0.2008 - val_accuracy: 0.9585
# Epoch 247/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0180 - accuracy: 0.9936 - val_loss: 0.1803 - val_accuracy: 0.9614
# Epoch 248/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 0.2203 - val_accuracy: 0.9466
# Epoch 249/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0293 - accuracy: 0.9889 - val_loss: 0.2009 - val_accuracy: 0.9501
# Epoch 250/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0416 - accuracy: 0.9842 - val_loss: 0.1728 - val_accuracy: 0.9617
# Epoch 251/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.1831 - val_accuracy: 0.9596
# Epoch 252/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0245 - accuracy: 0.9910 - val_loss: 0.2035 - val_accuracy: 0.9567
# Epoch 253/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.1914 - val_accuracy: 0.9632
# Epoch 254/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 0.1914 - val_accuracy: 0.9602
# Epoch 255/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.1817 - val_accuracy: 0.9665
# Epoch 256/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0196 - accuracy: 0.9935 - val_loss: 0.2002 - val_accuracy: 0.9588
# Epoch 257/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0401 - accuracy: 0.9854 - val_loss: 0.2084 - val_accuracy: 0.9516
# Epoch 258/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0249 - accuracy: 0.9911 - val_loss: 0.1717 - val_accuracy: 0.9623
# Epoch 259/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.1875 - val_accuracy: 0.9614
# Epoch 260/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0248 - accuracy: 0.9903 - val_loss: 0.1923 - val_accuracy: 0.9599
# Epoch 261/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0234 - accuracy: 0.9919 - val_loss: 0.1985 - val_accuracy: 0.9623
# Epoch 262/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.1898 - val_accuracy: 0.9632
# Epoch 263/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0.2457 - val_accuracy: 0.9490
# Epoch 264/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0377 - accuracy: 0.9852 - val_loss: 0.2081 - val_accuracy: 0.9611
# Epoch 265/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0261 - accuracy: 0.9898 - val_loss: 0.1960 - val_accuracy: 0.9585
# Epoch 266/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.2179 - val_accuracy: 0.9534
# Epoch 267/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0218 - accuracy: 0.9929 - val_loss: 0.1814 - val_accuracy: 0.9626
# Epoch 268/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0112 - accuracy: 0.9976 - val_loss: 0.1853 - val_accuracy: 0.9653
# Epoch 269/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 0.2264 - val_accuracy: 0.9561
# Epoch 270/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.1860 - val_accuracy: 0.9665
# Epoch 271/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0154 - accuracy: 0.9958 - val_loss: 0.1961 - val_accuracy: 0.9620
# Epoch 272/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.1988 - val_accuracy: 0.9593
# Epoch 273/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0126 - accuracy: 0.9964 - val_loss: 0.2110 - val_accuracy: 0.9611
# Epoch 274/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.1945 - val_accuracy: 0.9656
# Epoch 275/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0166 - accuracy: 0.9939 - val_loss: 0.2056 - val_accuracy: 0.9596
# Epoch 276/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0290 - accuracy: 0.9892 - val_loss: 0.2221 - val_accuracy: 0.9510
# Epoch 277/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.2017 - val_accuracy: 0.9596
# Epoch 278/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.1942 - val_accuracy: 0.9632
# Epoch 279/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.2000 - val_accuracy: 0.9644
# Epoch 280/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.2056 - val_accuracy: 0.9638
# Epoch 281/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.2012 - val_accuracy: 0.9552
# Epoch 282/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0228 - accuracy: 0.9922 - val_loss: 0.2061 - val_accuracy: 0.9540
# Epoch 283/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0244 - accuracy: 0.9924 - val_loss: 0.2020 - val_accuracy: 0.9614
# Epoch 284/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0220 - accuracy: 0.9920 - val_loss: 0.1971 - val_accuracy: 0.9629
# Epoch 285/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0
500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0121 - accuracy: 0.9955 - val_loss: 0.2404 - val_accuracy: 0.9558
# Epoch 327/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0430 - accuracy: 0.9835 - val_loss: 0.2688 - val_accuracy: 0.9507
# Epoch 328/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0274 - accuracy: 0.9900 - val_loss: 0.2297 - val_accuracy: 0.9582
# Epoch 329/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.1912 - val_accuracy: 0.9626
# Epoch 330/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.2278 - val_accuracy: 0.9638
# Epoch 331/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0137 - accuracy: 0.9953 - val_loss: 0.2154 - val_accuracy: 0.9596
# Epoch 332/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.2040 - val_accuracy: 0.9662
# Epoch 333/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.2382 - val_accuracy: 0.9510
# Epoch 334/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0385 - accuracy: 0.9844 - val_loss: 0.2121 - val_accuracy: 0.9638
# ...
# Epoch 390/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.2637 - val_accuracy: 0.9588
# Epoch 391/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.2522 - val_accuracy: 0.9626
# Epoch 392/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.2579 - val_accuracy: 0.9608
# Epoch 393/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.2109 - val_accuracy: 0.9659
# Epoch 394/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 0.2325 - val_accuracy: 0.9623
# Epoch 395/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0184 - accuracy: 0.9935 - val_loss: 0.2570 - val_accuracy: 0.9585
# Epoch 396/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0232 - accuracy: 0.9919 - val_loss: 0.2296 - val_accuracy: 0.9656
# Epoch 397/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.2226 - val_accuracy: 0.9635
# Epoch 398/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.2590 - val_accuracy: 0.9620
# Epoch 399/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.2408 - val_accuracy: 0.9620
# Epoch 400/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.2888 - val_accuracy: 0.9564
# Epoch 401/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0441 - accuracy: 0.9844 - val_loss: 0.2226 - val_accuracy: 0.9558
# Epoch 402/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0147 - accuracy: 0.9959 - val_loss: 0.2303 - val_accuracy: 0.9659
# Epoch 403/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.2180 - val_accuracy: 0.9659
# Epoch 404/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.2199 - val_accuracy: 0.9671
# Epoch 405/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.2431 - val_accuracy: 0.9629
# Epoch 406/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.2244 - val_accuracy: 0.9656
# Epoch 407/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.2315 - val_accuracy: 0.9611
# Epoch 408/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.2818 - val_accuracy: 0.9576
# Epoch 409/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0507 - accuracy: 0.9827 - val_loss: 0.2539 - val_accuracy: 0.9510
# Epoch 410/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0342 - accuracy: 0.9892 - val_loss: 0.2815 - val_accuracy: 0.9531
# Epoch 411/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0313 - accuracy: 0.9902 - val_loss: 0.2106 - val_accuracy: 0.9644
# Epoch 412/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 0.2261 - val_accuracy: 0.9650
# Epoch 413/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.2098 - val_accuracy: 0.9665
# Epoch 414/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.2160 - val_accuracy: 0.9680
# Epoch 415/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.2172 - val_accuracy: 0.9682
# Epoch 416/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.2117 - val_accuracy: 0.9682
# Epoch 417/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.2142 - val_accuracy: 0.9653
# Epoch 418/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0026 - accuracy: 0.9999 - val_loss: 0.2148 - val_accuracy: 0.9688
# Epoch 419/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.2184 - val_accuracy: 0.9677
# Epoch 420/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.2243 - val_accuracy: 0.9662
# Epoch 421/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.2311 - val_accuracy: 0.9674
# Epoch 422/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.2128 - val_accuracy: 0.9688
# Epoch 423/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.2247 - val_accuracy: 0.9680
# Epoch 424/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.2624 - val_accuracy: 0.9602
# Epoch 425/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.2247 - val_accuracy: 0.9632
# Epoch 426/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.2304 - val_accuracy: 0.9650
# Epoch 427/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.2438 - val_accuracy: 0.9593
# Epoch 428/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0276 - accuracy: 0.9886 - val_loss: 0.2567 - val_accuracy: 0.9591
# Epoch 429/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0429 - accuracy: 0.9846 - val_loss: 0.2515 - val_accuracy: 0.9596
# Epoch 430/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0165 - accuracy: 0.9934 - val_loss: 0.2345 - val_accuracy: 0.9653
# Epoch 431/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.2747 - val_accuracy: 0.9632
# Epoch 432/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.2535 - val_accuracy: 0.9638
# Epoch 433/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 0.2325 - val_accuracy: 0.9677
# Epoch 434/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.2223 - val_accuracy: 0.9647
# Epoch 435/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.2312 - val_accuracy: 0.9647
# Epoch 436/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.2402 - val_accuracy: 0.9665
# Epoch 437/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.2426 - val_accuracy: 0.9647
# Epoch 438/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.9650
# Epoch 439/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.2368 - val_accuracy: 0.9638
# Epoch 440/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.2289 - val_accuracy: 0.9653
# Epoch 441/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.2282 - val_accuracy: 0.9674
# Epoch 442/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.2824 - val_accuracy: 0.9585
# Epoch 443/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0145 - accuracy: 0.9949 - val_loss: 0.2333 - val_accuracy: 0.9668
# Epoch 444/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.2201 - val_accuracy: 0.9671
# Epoch 445/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.2477 - val_accuracy: 0.9644
# Epoch 446/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.2401 - val_accuracy: 0.9644
# Epoch 447/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.3908 - val_accuracy: 0.9246
# Epoch 448/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0379 - accuracy: 0.9882 - val_loss: 0.2407 - val_accuracy: 0.9602
# Epoch 449/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0675 - accuracy: 0.9802 - val_loss: 0.2652 - val_accuracy: 0.9507
# Epoch 450/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0151 - accuracy: 0.9944 - val_loss: 0.2331 - val_accuracy: 0.9635
# Epoch 451/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0095 - accuracy: 0.9963 - val_loss: 0.2190 - val_accuracy: 0.9641
# Epoch 452/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.2242 - val_accuracy: 0.9659
# Epoch 453/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.2327 - val_accuracy: 0.9629
# Epoch 454/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.2454 - val_accuracy: 0.9644
# Epoch 455/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.2250 - val_accuracy: 0.9665
# Epoch 456/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.2318 - val_accuracy: 0.9650
# Epoch 457/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.2265 - val_accuracy: 0.9644
# Epoch 458/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.2318 - val_accuracy: 0.9665
# Epoch 459/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.2366 - val_accuracy: 0.9650
# Epoch 460/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.2400 - val_accuracy: 0.9647
# Epoch 461/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.2479 - val_accuracy: 0.9641
# Epoch 462/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.2477 - val_accuracy: 0.9665
# Epoch 463/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.2629 - val_accuracy: 0.9617
# Epoch 464/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.2455 - val_accuracy: 0.9677
# Epoch 465/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 0.2469 - val_accuracy: 0.9644
# Epoch 466/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.2176 - val_accuracy: 0.9680
# Epoch 467/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.2367 - val_accuracy: 0.9703
# Epoch 468/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.2644 - val_accuracy: 0.9650
# Epoch 469/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.2558 - val_accuracy: 0.9644
# Epoch 470/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.2250 - val_accuracy: 0.9668
# Epoch 471/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0176 - accuracy: 0.9930 - val_loss: 0.2802 - val_accuracy: 0.9588
# Epoch 472/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.2351 - val_accuracy: 0.9668
# Epoch 473/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.2422 - val_accuracy: 0.9665
# Epoch 474/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.2364 - val_accuracy: 0.9662
# Epoch 475/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.2279 - val_accuracy: 0.9668
# Epoch 476/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.2396 - val_accuracy: 0.9659
# Epoch 477/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.2456 - val_accuracy: 0.9647
# Epoch 478/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 0.2522 - val_accuracy: 0.9656
# Epoch 479/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.2407 - val_accuracy: 0.9638
# Epoch 480/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.2406 - val_accuracy: 0.9638
# Epoch 481/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.3837 - val_accuracy: 0.9499
# Epoch 482/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0690 - accuracy: 0.9781 - val_loss: 0.2554 - val_accuracy: 0.9504
# Epoch 483/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0289 - accuracy: 0.9893 - val_loss: 0.2775 - val_accuracy: 0.9591
# Epoch 484/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.2599 - val_accuracy: 0.9620
# Epoch 485/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.2386 - val_accuracy: 0.9685
# Epoch 486/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.2365 - val_accuracy: 0.9682
# Epoch 487/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.2481 - val_accuracy: 0.9644
# Epoch 488/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.2240 - val_accuracy: 0.9697
# Epoch 489/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.2302 - val_accuracy: 0.9682
# Epoch 490/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.2509 - val_accuracy: 0.9656
# Epoch 491/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2391 - val_accuracy: 0.9656
# Epoch 492/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.2634 - val_accuracy: 0.9626
# Epoch 493/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0180 - accuracy: 0.9924 - val_loss: 0.2878 - val_accuracy: 0.9549
# Epoch 494/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 0.2263 - val_accuracy: 0.9638
# Epoch 495/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.2712 - val_accuracy: 0.9561
# Epoch 496/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.2365 - val_accuracy: 0.9632
# Epoch 497/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0296 - accuracy: 0.9903 - val_loss: 0.2493 - val_accuracy: 0.9591
# Epoch 498/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.2847 - val_accuracy: 0.9570
# Epoch 499/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.2423 - val_accuracy: 0.9605
# Epoch 500/500
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.2276 - val_accuracy: 0.9662

# %%
model_name
# Out:
# 'mutiple_Conv1D_8_inputs_scaled_modified'

# %% [markdown]
# # Evaluate the Model using test data

# %%
Test_DATADIR = "D:/Project2022/res/split_dataset/original/test"
dataset_df = pre_process_dataset(Test_DATADIR)
# Out:
# Loading dataset: class covid
#   0%|          | 0/1430 [00:00<?, ?it/s]
# Loading dataset: class normal
#   0%|          | 0/1379 [00:00<?, ?it/s]

# %%
print("No of test sample:", len(dataset_df))
# Out:
# No of test sample: 2809

# %%
X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test, Y_test = process_data(dataset_df)
# Out:
# X1 shape (2809, 512, 1)
# X2 shape (2809, 512, 1)
# X3 shape (2809, 512, 1)
# Mid rows shape (2809, 512, 1)
# X4 shape (2809, 512, 1)
# X5 shape (2809, 512, 1)
# Mid Cols shape (2809, 512, 1)
# X6 shape (2809, 512, 1)
# y shape (2809, 1)

# %%
# test loss, test accuracy
accuracy = model.evaluate([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test], Y_test, batch_size=100, verbose=0)

# %%
print("Test acuuracy", accuracy[1])
print("Test loss", accuracy[0])
# Out:
# Test acuuracy 0.9708080887794495
# Test loss 0.17019984126091003

# %%
#y_pred = model.predict_classes(X_test)
y_pred = (model.predict([X1_test, X2_test, X3_test, X_row_mid_test, X4_test, X5_test, X_col_mid_test, X6_test]) > 0.5).astype("int32")
# Out:
# 88/88 [==============================] - 1s 6ms/step

# %%
print(classification_report(Y_test, y_pred, target_names=["covid", "Normal"]))
# Out:
#               precision    recall  f1-score   support
#
#        covid       0.96      0.98      0.97      1430
#       Normal       0.98      0.96      0.97      1379
#
#     accuracy                           0.97      2809
#    macro avg       0.97      0.97      0.97      2809
# weighted avg       0.97      0.97      0.97      2809

# %%
cm = confusion_matrix(Y_test, y_pred, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=["Covid","Normal"])
disp.plot()
plt.show()
